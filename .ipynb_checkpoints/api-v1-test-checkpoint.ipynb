# %% [markdown]
# # api-v1-test

# %% [markdown]
# New API test!!

# %%
import plotly.plotly as py       # how you communicate with plotly's servers
import plotly.tools as tls       # useful tools, e.g., get_sublots()
from plotly.graph_objs import *  # objects you'll use to piece together plots
import numpy as np
# Out:
# OrderedDict([('plotlylist', OrderedDict()), ('data', OrderedDict()), ('annotations', OrderedDict()), ('plotlydict', OrderedDict()), ('plotlytrace', OrderedDict()), ('trace', OrderedDict([('x', OrderedDict()), ('y', OrderedDict()), ('z', OrderedDict()), ('r', OrderedDict()), ('t', OrderedDict()), ('text', OrderedDict()), ('name', OrderedDict()), ('mode', OrderedDict()), ('marker', OrderedDict([('type', 'object')])), ('line', OrderedDict([('type', 'object')])), ('fill', OrderedDict()), ('fillcolor', OrderedDict()), ('opacity', OrderedDict()), ('showlegend', OrderedDict()), ('xaxis', OrderedDict()), ('yaxis', OrderedDict()), ('angularAxis', OrderedDict()), ('radialAxis', OrderedDict()), ('error_y', OrderedDict([('type', 'object')])), ('textfont', OrderedDict([('type', 'object')])), ('type', OrderedDict()), ('bardir', OrderedDict()), ('boxpoints', OrderedDict()), ('jitter', OrderedDict()), ('pointpos', OrderedDict()), ('boxmean', OrderedDict()), ('whiskerwidth', OrderedDict()), ('scl', O
# ...

# %%
py.sign_in('etpinard','a35m7g6el5')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-5875285cdbb3> in <module>()
# ----> 1 py.sign_in('etpinard','a35m7g6el5')
#
# AttributeError: class plotly has no attribute 'sign_in'

# %%
x, y = [np.random.randn(300) for iii in range(5)], [np.random.randn(300) for iii in range(3)]
data = Data([Scatter(mode='markers', opacity=.5, x=x[iii], y=y[iii]) for iii in range(3)])
py.iplot(data, filename='scatter-brained')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~etpinard/146" height="525" width="100%"></iframe>

# %%
help(Histogramy)
# Out:
# Help on class Histogramy in module plotly.graph_objs:
#
# class Histogramy(_PlotlyTrace)
#  |  A dictionary-like object for representing a histogramy plot in plotly.
#  |
#  |      Example:
#  |
#  |          py.plot([Histogramy(bardir='h', y=[1,1,2,3,2,3,3,3,4,4,5,1,3,4])])
#  |
#  |
#  |  Quick method reference:
#  |
#  |      Histogramy.update(dict1, **dict2)
#  |      Histogramy.strip_style()
#  |      Histogramy.get_data()
#  |      Histogramy.to_graph_objs()
#  |      Histogramy.validate()
#  |      Histogramy.force_clean()
#  |
#  |  Valid keys:
#  |
#  |      y [required=True] (value=array_like of numbers, strings, datetimes):
#  |          The y data that is binned and plotted as bars along the y-axis.
#  |
#  |      name [required=False] (value=string):
#  |          The label associated with this trace. This name will appear in the
#  |          legend, in the column header in the spreadsheet, and on hover.
#  |
# ...

# %%
nice_fig = py.get_figure('etpinard', '25')

nice_fig
# Out:
# {'data': [{'line': {'color': 'rgb(0,0,0)'},
#    'mode': 'lines',
#    'name': '',
#    'type': 'scatter',
#    'x': [-180.0,
#     -179.99844360351562,
#     -175.25674438476562,
#     -173.9450225830078,
#     -174.62588500976562,
#     -173.6300506591797,
#     -171.66668701171875,
#     -169.6739959716797,
#     -170.5650634765625,
#     -171.44345092773438,
#     -171.050048828125,
#     -173.00921630859375,
#     -172.0858612060547,
#     -172.1193389892578,
#     -173.21092224121094,
#     -172.23583984375,
#     -173.1500244140625,
#     -173.3249969482422,
#     -173.6533966064453,
#     -175.43508911132812,
#     -176.49513244628906,
#     -178.44515991210938,
#     -178.45103454589844,
#     -179.38174438476562,
#     -179.27590942382812,
#     -180.0],
#    'y': [68.9937744140625,
#     68.992919921875,
#     67.65877532958984,
#     66.14458465576172,
#     67.05169677734375,
#     67.11708068847656,
#     66.944580078125,
#     66.13652801513672,
# ...

# %%
py.__version__
# Out:
# '1.0.0'

# %%
tls.get_credentials_file()
# Out:
# {u'api_key': u'a35m7g6el5', u'username': u'etpinard'}
