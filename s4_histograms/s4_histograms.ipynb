# %% [markdown]
# # Section 4: Histograms & Box Plots

# %% [markdown]
# Welcome to Plotly's *Python API User Guide*.
#
# > Links to the other sections can be found on the User Guide's [homepage](http://nbviewer.ipython.org/github/etpinard/plotly-python-doc/tree/1.0/s00_homepage/s00_homepage.ipynb) <br>
# and the Github repository is available
# <a href="https://github.com/etpinard/plotly-python-doc/tree/1.0" target="_blank">here</a>.
#
# <hr>

# %%
import plotly

# Check Plolty version (if not 1.0, please upgrade)
plotly.__version__
# Out:
# '1.0.0'

# %% [markdown]
# .... Introduce here

# %%
import plotly.plotly as py  # (New syntax!) tools to communicate with Plotly's server
import plotly.tools as tls  # (NEW!) useful Python/Plotly tools 

# (NEW!) objects to piece together plots
from plotly.graph_objs import Data, Layout, Figure

import numpy as np  # numpy (for math functions and arrays, here)
import csv          # csv file read/write

my_creds = tls.get_credentials_file()                  # read credentials
py.sign_in(my_creds['username'], my_creds['api_key'])  # (New syntax!) Plotly sign in

# %% [markdown]
# In similar fashion to section 2 (Bar Charts and Error Bars), we read and plot data from a csv file.
# The csv file in question `grades.csv` can be found in the section's Github <a href="https://github.com/etpinard/plotly-python-doc/tree/1.0/s4_histograms" target="_blank">folder</a>.
#
# It contains students grades in percent.
# In this file, each row corresponds to a student and each column corresponds to a particular component of the total grade. These components (Final, Midterm and Homeworks) are labelled in the top row of the file:

# %%
# !head -n 1 grades.csv  # for Unix-like users
# Out:
# Final Exam,Midterm Exam,Homeworks

# %% [markdown]
# In order to use the data according, let's first define a csv *column* reader function.

# %%
# Define a csv column reader function
def get_csv_col(filepath, col_id):
    ''' 
    Read column of csv file, return a Numpy array where
    each entry corresp. to a particular student
    1) filepath: relative path to csv file 
    2) col_id: id of column requested, found in first row (a string)
    '''
    with open(filepath,'r') as data_file:
        reader = csv.reader(data_file)         # define reader object
        the_col = reader.next().index(col_id)  # look for 'col_id' row 1, skip row
        # Retrieve all entry of column 'the_col', put in Numpy array
        return np.array([float(row[the_col]) for row in reader])
    
# -- note that the 'with' statement automatically closes  
#    'filepath' at the end of its block of code

# %% [markdown]
# The data in `grades.csv` contains some NaNs (not a number) entries. For example,

# %%
# !head grades.csv -n 20 | tail -n 7  # for Unix-like users
# Out:
# 82.0,85.0,90.0
# 52.0,75.0,68.0
# 80.0,72.0,85.0
# nan,nan,nan
# 78.0,80.0,82.0
# 57.0,42.0,40.0
# 88.0,80.0,100.0

# %% [markdown]
# That said, Plotly makes plotting histograms and box plots with arrays containing NaNs a breeze.
# Please note that:
#
# * All NaNs and string entries are ignored in Plotly's built-in computations.
#
# Now, let's extract each column and check how many (non-NaN) grades they contain:

# %%
# Extract columns for 'grades.csv' 
homeworks = get_csv_col('grades.csv','Homeworks')
midterm = get_csv_col('grades.csv','Midterm Exam')
final = get_csv_col('grades.csv','Final Exam')

# Compare number of non-NaN entries to total number of entries in column
def check_nan(X,X_name):
    X_no_nan = X[~np.isnan(X)]
    print "%s: %i grades out of %i entries" % (X_name, len(X_no_nan), len(X))

check_nan(homeworks,'Homeworks')
check_nan(midterm,'Midterm Exam')
check_nan(final,'Final Exam')
# Out:
# Homeworks: 62 grades out of 68 entries
# Midterm Exam: 64 grades out of 68 entries
# Final Exam: 63 grades out of 68 entries

# %% [markdown]
# #### 4.1 Overlaid histograms

# %% [markdown]
# In our first histogram plot, we will compare the grade distributions of the midterm exam and final exam.
# Plot customization for the histogram plot type (called with the `'histogramx'` value) is analoguous to the bar plot type:
#
# * Users can select different bar modes (the `'barmode'` key in the layout dictionary). As for the bar plot type, the available values are `'stack'` (default), `'overlay'` or `'group'`.
#
# * Spacing between bars can be modify using `'bargap'` and `'bargroupgap'` in the layout dictionary.
#
# * Users can make an histogram with horizontal bars by setting `'bardir'` to `'h'` in each trace dictionary.
#
# * Note that `'text'` key not valid for this plot type unfortunately (just like in Section 2)
#
# More importantly, Plotly allows users to choose the histogram normalization (i.e. the units of the generated y-axis).
# The trace dictionary key `'histnorm'` is set to `'count'` by default, the other possibilities are:
# `'percent'`, `'probability'`, `'density'`, `'probability density'` (all in lower case). We will compare the different `'histnorm'` values later in Fig. 10.
#
# But now, for our firt histogram plot will feature:
#
# * Two histograms overlaid and partly transparent (with the `'opacity'` key in each trace dictionary);
# * `'histnorm'` set to `'count'`, as well as all other histogram options set to their default value.
#
# ** Update with new terminology of course **

# %%
# (*) Graph objects required for the following plot
from plotly.graph_objs import Histogramx, Marker, Font, XAxis, YAxis, Legend

# %%
# Trace-generating function (return and Histogramx object)
def make_trace(x_in,name_in,col_in):
    x_in_cnt = len(x_in[~np.isnan(x_in)])     # find number of non-NaNs grades
    my_text = " ("+str(x_in_cnt)+" grades)"   # add to legend and hover text
    return Histogramx(x=x_in,                   # distribution to be plotted
                      histnorm='count',         # histogram norm. (default)
                      name='<b>'+name_in+'</b>'+my_text,  # set legend and hover text 
                      opacity= 0.55,                      # N.B partly transparent bars
                      marker= Marker(color=col_in)        # bar color
                     )
                        
# Define colors for the midterm and final histograms
col_midterm = 'rgb(231,41,138)'  # a nice fuchsia
col_final = 'rgb(230,171,2)'     # a nice yellow

# Make data object using make_trace()
my_data = Data([make_trace(midterm,'Midterm',col_midterm),
                make_trace(final,'Final',col_final)])

# Make layout object
my_layout = Layout(barmode='overlay',                     # N.B. overlay barmode
                   title='Fig 4.1: Midterm and \
                          Final Exam Grade Distribution', # set plot title
                   font= Font(family='Georgia, serif',    # set global font family
                             color='#635F5D'),            #   and color
                   plot_bgcolor='#EFECEA',                # set plot color to grey
                   xaxis= XAxis(title='<b>Grade [%]</b>'),   # x-axis title
                   yaxis= YAxis(title='<b>Count</b>'),       # y-axis title 
                   legend= Legend(x=0, y=1)   # legend at upper left corner of plot
                  ) 

# Define dictionary of axis options
my_axes = dict(zeroline=False,       # remove thick zero line
               gridcolor='#FFFFFF',  # white grid lines
               ticks='outside',      # draw ticks outside axes 
               ticklen=8,            # tick length
               tickwidth=1.5         #   and width
              )

# Set these axis options to both axes 
my_layout['xaxis'].update(my_axes)
my_layout['yaxis'].update(my_axes)
                           
# Make Figure object, send to Plotly and show in notebook
my_fig = Figure(data=my_data, layout=my_layout)
py.iplot(my_fig, filename='s4_midterm-final')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~etpinard/88" height="525" width="100%"></iframe>

# %% [markdown]
# #### 4.2 Histogram normalization

# %% [markdown]
# In this subsection, we compare Plotly's histogram normalizations.
#
# Let
# $y_{\text{count}}(i)$ be the number of non-NaN data points in bin $i$,
# $w_i$ be the width of bin $i$ and
# $N$ be the number of data points in the sample. Then, Plotly's available histogram normalizations are:
#
# $$ y_{\text{probability}}(i) = \frac{1}{N} y_{\text{count}}(i) $$
#
# $$ y_{\text{percent}}(i) = \frac{1}{N} y_{\text{count}}(i) \times 100 $$
#
# $$ y_{\text{density}}(i) = \frac{1}{w_i} y_{\text{count}}(i) $$
#
# $$ y_{\text{prob. density}}(i) = \frac{1}{N} \frac{1}{w_i} y_{\text{count}} $$
#
# With the same data as the previous plot, let's compare these four histogram normalizations in a 2 by 2 plot. So, first we define the subplot grid:

# %%
#  ??? what to say here ??? 
my_fig = tls.get_subplots(rows=2, columns=2, 
                          horizontal_spacing=0.12,
                          vertical_spacing=0.12,
                          print_grid=True)

# must be fig to have nested updates!
# Out:
# This is the format of your plot grid!
# [3]	[4]
# [1]	[2]

# %%
# List of subplot [1],[2],[3],[4] labels
sbplts = range(1,5)

# Dictionary of histogram normalization (values of the histnorm key)
histnorms = {1: 'percent', 2: 'probability',
             3: 'density', 4: 'probability density'}

# Trace-generating function (returns a Histogramx object)
def make_trace(x_in,histnorm_in,name_in,sbplt_in,col_in):
    showlegend_flag = {1: True, 2: False, 
                       3: False, 4: False}   # only show subplot[1] items on legend
    return Histogramx(x=x_in,                # distribution to be plotted
                      histnorm=histnorm_in,  # N.B. histogram normalization
                      name='<b>'+name_in+'</b>',  # label for legend and hover text
                      opacity=0.55,                 # partly transparent bars
                      marker= Marker(color=col_in), # bar color
                      showlegend=showlegend_flag[sbplt_in], # N.B. Only show 2 traces in legend
                      xaxis='x'+str(sbplt_in),  # N.B. plot on x-axis of 'sbplt_in'
                      yaxis='y'+str(sbplt_in),  # N.B. plot on y-axis of 'sbplt_in'
                     )

# Make 2 traces for each subplot (using arrays and colors defined previously), 
#   make Data object and update 'data' key in Figure object
my_fig['data'] = Data([make_trace(midterm,histnorms[sbplt],'Midterm',sbplt,col_midterm)
                       for sbplt in sbplts]+
                      [make_trace(final,histnorms[sbplt],'Final',sbplt,col_final)
                       for sbplt in sbplts])

# Update x and y axis of all subplots
#   using the my_axes dictionary defined in subsection 4.1
my_fig['layout'].update({'xaxis{}'.format(sbplt): my_axes for sbplt in sbplts})
my_fig['layout'].update({'yaxis{}'.format(sbplt): my_axes for sbplt in sbplts})

# Add title to the 2 bottom x axes
my_fig['layout'].update({'xaxis{}'.format(sbplt): {'title': '<b>Grade [%]</b>'} 
                      for sbplt in sbplts[0:2]})

# Make yaxis title correspond to 'histnorm' key (returns a string)
def make_yaxis_title(histnorm_in):
    return '<b>'+histnorm_in[0].upper()+histnorm_in[1:]+'</b>' # with 1st letter in upper case

# Update y axes of all subplots
my_fig['layout'].update({'yaxis{}'.format(sbplt): {'title': make_yaxis_title(histnorms[sbplt])} 
                      for sbplt in sbplts})

# Set barmode, plot title, global font, plot background and legend
my_fig['layout'].update(dict(barmode='overlay',  # N.B. overlay barmode
                             title='Fig 4.2: Midterm and \
                                    Final Exam Grade Distribution<br><br>',  # set plot title
                             font= Font(family='Georgia, serif',        # set global font family
                                        color='#635F5D'),               #   and color
                             plot_bgcolor='#EFECEA',      # set plot color to grey
                             legend= Legend(x=0, y=100)   # legend at upper left corner
                           ))  
                        
# Send figure object to Plotly and show in notebook
py.iplot(my_fig, filename='s4_midterm-final-histnorm')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~etpinard/90" height="525" width="100%"></iframe>

# %% [markdown]
# * Show legend in trace dictionary
#
# * Comment on subplor anchor and domain ... if first time

# %% [markdown]
# #### 4.3 Customizing histogram bins

# %% [markdown]
# * Note on Plotly's autobinx
# * autobinx=False
# * add Guassian fits to both (maybe ...)
#
# * 4 row, Midterm above Final, one shared 'x' axis
# * grid on mean, median, max, min

# %%
# Some formula to compute the course grade (ignoring NaNs in sum)
def course_grade_formula(h_in,m_in,f_in):
    N_student = len(h_in)      # number of students, or len(m_in), len(f_in)
    w = {'h': 0.3, 'm': 0.3, 'f': 0.4}  # weight dictionary
    tmp = [ np.nansum([w['h']*h_in[i], w['m']*m_in[i], w['f']*f_in[i]]) 
               for i in range(N_student) ] # compute using np.nansum()
    return np.array(tmp)                   # convert to np array

# Compute course grade
course = course_grade_formula(homeworks,midterm,final)

# Check how many NaN 'course' array
check_nan(course,'Course Grade')
# Out:
# Course Grade: 64 grades out of 68 entries

# %% [markdown]
# ...

# %%
#  ??? what to say here ??? 
my_fig = tls.get_subplots(rows=4, columns=1, 
                          vertical_spacing=0.07,
                          print_grid=True)

# must be fig to have nested updates!
# Out:
# This is the format of your plot grid!
# [4]
# [3]
# [2]
# [1]

# %%
my_fig
# Out:
# {'data': [],
#  'layout': {'xaxis1': {'anchor': 'y1', 'domain': [0.0, 1.0]},
#   'xaxis2': {'anchor': 'y2', 'domain': [0.0, 1.0]},
#   'xaxis3': {'anchor': 'y3', 'domain': [0.0, 1.0]},
#   'xaxis4': {'anchor': 'y4', 'domain': [0.0, 1.0]},
#   'yaxis1': {'anchor': 'x1', 'domain': [0.0, 0.1975]},
#   'yaxis2': {'anchor': 'x2', 'domain': [0.2675, 0.465]},
#   'yaxis3': {'anchor': 'x3', 'domain': [0.535, 0.7325]},
#   'yaxis4': {'anchor': 'x4', 'domain': [0.8025, 1.0]}}}

# %%
# (*) Other graph objects required for the following plot
from plotly.graph_objs import XBins, Scatter, Line, Annotation, Annotations

#help(Scatter)
#help(Line)
#help(Histogramx)
#help(py.iplot)
#help(XAxis)

# %% [markdown]
# The following code require the `scipy` module

# %%
## (1) A few definitions

# (1.1) First some global variables
xbin_start = np.nanmin(np.concatenate((homeworks,midterm,final,course)))
xbin_end = 100
xbin_size = 2
my_histnorm = 'probability density'
my_color = 'rgb(106,204,101)'
x_range = [5,105]
y_range = [-0.009,0.109]  # N.B. Plotly does not include tick at range limits
plot_width = 650
plot_height = 800

# (1.2) Trace-generating function of histograms (returns a Histogramx object)
def make_trace(x_in,name_in,sbplt_in):

    #x_in_cnt = len(x_in[~np.isnan(x_in)])     # find number of non-NaNs grades
    #my_text = " ("+str(x_in_cnt)+" grades)"   # add to legend and hover text
    showlegend_flag = {1: True, 2: False, 
                       3: False, 4: False}   # 
    return Histogramx(x=x_in,                # distribution to be plotted
                      histnorm=my_histnorm,  # histogram normalization
                      name='<b>Grades</b>',  # label for legend
                      marker= Marker(color=my_color),     # bar color
                      showlegend=showlegend_flag[sbplt_in], # N.B. Only show 2 traces in legend
                      autobinx=False,
                      xbins= XBins(start=xbin_start,  #
                                   end=xbin_end,    #
                                   size=xbin_size),  #
                      xaxis='x'+str(sbplt_in),  # N.B. plot on x-axis of 'sbplt_in'
                      yaxis='y'+str(sbplt_in),  # N.B. plot on y-axis of 'sbplt_in'
                     )

# (1.3a) Import from scipy to compute the mode
from scipy.stats import mode 

# (1.3b) Trace-generating function of vertical line (return a Scatter object)
def make_vert_trace(x_in,key_in,sbplt_in):
    x_nonan = x_in[~np.isnan(x_in)]                    # remove NaNs from array
    compute_dict = {'mode': (lambda x: mode(x)[0][0]),
                    'mean': (lambda x: np.mean(x))}
    text_dict = {'mode': 'Mode', 'mean': 'Mean'}
    line_dict = {'mode': ('rgb(72,120,207.1)',2,'dash'), 
                 'mean': ('rgb(72,120,207.1)',2,'dot')}   # line color, width and dash sytle
    return Scatter(x=[compute_dict[key_in](x_nonan)]*2,
                   y=[0,x_nonan.max()],
                   mode='lines+text',
                   text='<b>'+text_dict[key_in]+'</b>',
                  # textposition='top right',
                   name='',
                   showlegend=False,
                   line= Line(color=line_dict[key_in],   # line color,
                              width=line_dict[key_in],    #  width
                              dash=line_dict[key_in]),  #  and dash sytle
                   xaxis='x'+str(sbplt_in),  # N.B. plot on x-axis of 'sbplt_in'
                   yaxis='y'+str(sbplt_in),  # N.B. plot on y-axis of 'sbplt_in'
                  )

# (3.4a) Function for updating up each of the 4 axes (return a dictionary)
def update_xaxis(anchor_in):
     return XAxis(anchor=anchor_in,          # N.B. axis anchor, leave empty in none
                  range=x_range,   
                  tickfont= Font(size=14),   # default is 12
                  zeroline=False,            # remove thick zero line
                  ticks='outside',      # tick outside axis frame
                  ticklen=8,            # tick length
                  tickwidth=1.5,        #   and width
                  autotick=False,       # overwrite default tick options
                  dtick=10,             # distance in between ticks
                 )
    
# (3.4b) Function for updating up each of the 4 axes (return a dictionary)
def update_yaxis():
     return YAxis(anchor='',          # N.B. axis anchor, leave empty in none
                  range=y_range,   
                  tickfont= Font(size=14),   # default is 12
                  gridcolor='#FFFFFF',       # white grid lines
                  zeroline=False             # remove thick zero line
                 )
    
# (3.5) Function generating the title and source annotations (returns an Annotation object)
def make_anno(text_in,fontsize_in,pos_in):
    return Annotation(text=text_in,  # annotation text
                      xref='paper',  # use paper coordinates
                      yref='paper',  #   for both x and y coords
                      x=pos_in[0],   # x and y position 
                      y=pos_in[1],   #   in norm. coord. 
                      font= Font(size= fontsize_in),  # text font size
                      showarrow=False,       # no arrow (default is True)
                      bgcolor='#F5F3F2',     # light grey background color
                      bordercolor='#FFFFFF', # white borders
                      borderwidth=1,         # border width
                      borderpad=fontsize_in  # space between border and text set to 1 fontsize
                     )
   
def make_anno_onplot():
    return 'ad'

def make_anno_splt():
    return 'dada'

def make_legend():
    return Legend('dadas'
                 )

## (2) Update the Figure object

# (2.1) Update data
my_fig['data'] = Data([make_trace(homeworks,'Homeworks',1),
                       make_trace(midterm,'Midterm',2),
                       make_trace(final,'Final',3),
                       make_trace(course,'Course Grade',4)]+
                      [make_vert_trace(i_data,'mode',i+1) 
                        for i,i_data in enumerate([homeworks,midterm,final,course])]+
                      [make_vert_trace(i_data,'mean',i+1) 
                        for i,i_data in enumerate([homeworks,midterm,final,course])]
                     )

# (2.2) Update 
my_fig['layout'].update(dict(bargap=0.01,     # norm. spacing between bars
                             title='',        # set title to empty (title is in 'annotations')
                             font= Font(family='Georgia, serif',    # global font family
                                        color='#635F5D'),           #   and color
                             autosize=False,       # turn off autosize 
                             height=plot_height,   # plot's height in pixels 
                             width=plot_width,     # plot's width in pixels
                             margin={'t':100,'b':100,'r':25,'l':70},  # frame and axes margin
                             plot_bgcolor='#EFECEA',  # plot and 
                             paper_bgcolor='#EFECEA', #   frame background color
                        ))

# (2.) Initialize annotation list with plot title
my_annotations = Annotations([make_anno('Fig. 3.4: <b>Course Grade Distributions</b>',
                                        22,[0.04,1.12])])

# (2.) 
sbplt_title = ['<b>Homework</b> (30% of course grade)','<b>Midterm Exam</b> (30%)',
               '<b>Final Exam</b> (40%)','<b>Course Grade</b>']
sbplt_pos = [my_fig['layout']['yaxis{}'.format(i)]['domain'][1]-0.02 for i in sbplts]

my_annotations += Annotations([make_anno(sbplt_title[i],
                                         12,[0.04,sbplt_pos[i]]) for i in range(4)])

    # (3.8) Add annotation list to Layout object
my_fig['layout'].update({'annotations': my_annotations})
    
# (2.3) Update
my_fig['layout'].update({'xaxis1': update_xaxis('')})
my_fig['layout'].update({'xaxis{}'.format(sbplt): update_xaxis('x1') for sbplt in sbplts[1:]})
my_fig['layout'].update({'yaxis{}'.format(sbplt): update_yaxis() for sbplt in sbplts})




# legend

## (3) Send figure object to Plotly and show in notebook
py.iplot(my_fig, filename='s4_grades-bins', width=plot_width, height=plot_height)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~etpinard/156/625/775" height="800" width="650"></iframe>

# %%
my_fig['data']

#### text, textposition in Scatter

my_fig['layout']['annotations']

#help(XAxis)
# Out:
# [{'bgcolor': '#F5F3F2',
#   'bordercolor': '#FFFFFF',
#   'borderpad': 22,
#   'borderwidth': 1,
#   'font': {'size': 22},
#   'showarrow': False,
#   'text': 'Fig. 3.4: <b>Course Grade Distributions</b>',
#   'x': 0.04,
#   'xref': 'paper',
#   'y': 1.12,
#   'yref': 'paper'},
#  {'bgcolor': '#F5F3F2',
#   'bordercolor': '#FFFFFF',
#   'borderpad': 12,
#   'borderwidth': 1,
#   'font': {'size': 12},
#   'showarrow': False,
#   'text': '<b>Homework</b> (30% of course grade)',
#   'x': 0.04,
#   'xref': 'paper',
#   'y': 0.17750000000000002,
#   'yref': 'paper'},
#  {'bgcolor': '#F5F3F2',
#   'bordercolor': '#FFFFFF',
#   'borderpad': 12,
#   'borderwidth': 1,
#   'font': {'size': 12},
#   'showarrow': False,
#   'text': '<b>Midterm Exam</b> (30%)',
#   'x': 0.04,
#   'xref': 'paper',
#   'y': 0.445,
#   'yref': 'paper'},
#  {'bgcolor': '#F5F3F2',
#   'bordercolor': '#FFFFFF',
#   'borderpad': 12,
#   'borderwidth': 1,
#   'font': {'size': 12},
#   'showarrow': False,
#   'text': '<b>Final Exam</b> (40%)',
#   'x': 0.04,
#   'xref': 'paper',
#   'y': 0.7125,
#   'yref': 'paper'},
#  {'bgcolor': '#F5F3F2',
#   'bordercolor': '#FFFFFF',
#   'borderpad': 12,
#   'borderwidth': 1,
#   'font': {'size': 12},
#   'showarrow': False,
#   'text': '<b>Course Grade</b>',
#   'x': 0.04,
#   'xref': 'paper',
#   'y': 0.98,
#   'yref': 'paper'}]

# %% [markdown]
# #### 4.4 Box plots

# %% [markdown]
# Box plots are useful for ...
#
#
# Plotly makes it easy to add *jitter* to the scatter

# %%
from plotly.graph_objs import Box

help(Box)
# Out:
# Help on class Box in module plotly.graph_objs.graph_objs:
#
# class Box(PlotlyTrace)
#  |  A dictionary-like object for representing a box plot in plotly.
#  |
#  |      Example:
#  |
#  |          py.plot([Box(name='boxy', y=[1,3,9,2,4,2,3,5,2])])
#  |
#  |
#  |  Quick method reference:
#  |
#  |      Box.update(dict1, **dict2)
#  |      Box.strip_style()
#  |      Box.get_data()
#  |      Box.to_graph_objs()
#  |      Box.validate()
#  |      Box.force_clean()
#  |
#  |  Valid keys:
#  |
#  |      y [required=True] (value=array_like of numbers, strings, datetimes):
#  |          This array is used to define the an individual box plot. Statistics
#  |          from these numbers define the bounds of the box, the length of the
#  |          whiskers, etc.
#  |
#  |      name [required=False] (value=string):
#  |          The label associated with this trace. This name will appear in the
#  |          legend, in the column header in the spreadsheet, and on hover.
#  |
#  |      boxpoints [required=False] (value='all' | 'outliers' | False):
#  |          If 'all' then the 'y' points are shown with the box. If 'outliers'
#  |          then only the 'outliers' of the 'y' points are shown. If False then
#  |          no points are shown
#  |
#  |      jitter [required=False] (value=number in [0, 1]):
#  |          Width of the jittered scatter. If 0, then the boxpoints are aligned
#  |          vertically, if 1 then the points are randomly jittered horizontally
#  |          up to the width of the box.
#  |
#  |      pointpos [required=False] (value=number in [-2, 2]):
#  |          Horizontal position of the center of the boxpoints relative to the
#  |          center and width of the box.
#  |
#  |      boxmean [required=False] (value=Aw, snap! Undocumented!):
#  |          If True then the mean of the y-points is shown as a dashed line in
#  |          the box. If 'sd', then the standard deviation is also shown. If
#  |          False, then no line shown.
#  |
#  |      whiskerwidth [required=False] (value=Aw, snap! Undocumented!):
#  |          Width of the whisker of the box.
#  |
#  |      fillcolor [required=False] (value=str describing color):
#  |          Color of the box interior.
#  |
#  |          Examples:
#  |              ["'green'", "'rgb(0, 255, 0)'", "'rgba(0, 255, 0, 0.3)'",
#  |              "'hsl(120,100%,50%)'", "'hsla(120,100%,50%,0.3)'"]
#  |
#  |      marker [required=Aw, snap! Undocumented!] (value=Aw, snap!
#  |      Undocumented!):
#  |          Aw, snap! Undocumented!
#  |
#  |          For more, run `help(plotly.graph_objs.Marker)`
#  |
#  |      line [required=Aw, snap! Undocumented!] (value=Aw, snap! Undocumented!):
#  |          Aw, snap! Undocumented!
#  |
#  |          For more, run `help(plotly.graph_objs.Line)`
#  |
#  |      showlegend [required=False] (value=bool: True | False):
#  |          Toggle whether or not this trace will show up in the legend.
#  |
#  |      stream [required=False] (value=dictionary-like):
#  |          The stream dict that initializes traces as writable-streams, for use
#  |          with the real-time streaming API. See examples here:
#  |          http://nbviewer.ipython.org/github/plotly/Streaming-Demos
#  |
#  |      xaxis [required=False] (value=string: 'y1' | 'y2' | 'y3' | etc.):
#  |          This key determines which yaxis the y coordinates in this trace will
#  |          reference in the figure. 'y' references layout['yaxis'] and 'y2'
#  |          references layout['yaxis2']. 'y1' will always refer to
#  |          layout['yaxis'] or layout['yaxis1'], they are the same.
#  |
#  |      visible [required=False] (value=bool: True | False):
#  |          Toggles whether this will actually be visible in the rendered
#  |          figure.
#  |
#  |      type [required=True] (value=box):
#  |          Plotly identifier for this data's trace type. This defines how this
#  |          data dictionary will be handled.
#  |
#  |  Method resolution order:
#  |      Box
#  |      PlotlyTrace
#  |      PlotlyDict
#  |      __builtin__.dict
#  |      __builtin__.object
#  |
#  |  Methods inherited from PlotlyTrace:
#  |
#  |  __init__(self, *args, **kwargs)
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from PlotlyDict:
#  |
#  |  force_clean(self)
#  |      Attempts to convert to graph_objs and call force_clean() on values.
#  |
#  |      Calling force_clean() on a PlotlyDict will ensure that the object is
#  |      valid and may be sent to plotly. This process will also remove any
#  |      entries that end up with a length == 0.
#  |
#  |      Careful! This will delete any invalid entries *silently*.
#  |
#  |  get_data(self)
#  |      Returns the JSON for the plot with non-data elements stripped.
#  |
#  |  strip_style(self)
#  |      Strip style from the current representation.
#  |
#  |      All PlotlyDicts and PlotlyLists are guaranteed to survive the
#  |      stripping process, though they made be left empty. This is allowable.
#  |
#  |      Keys that will be stripped in this process are tagged with
#  |      `'type': 'style'` in the INFO dictionary listed in graph_objs_meta.py.
#  |
#  |      This process first attempts to convert nested collections from dicts
#  |      or lists to subclasses of PlotlyList/PlotlyDict. This process forces
#  |      a validation, which may throw exceptions.
#  |
#  |      Then, each of these objects call `strip_style` on themselves and so
#  |      on, recursively until the entire structure has been validated and
#  |      stripped.
#  |
#  |  to_graph_objs(self)
#  |      Walk obj, convert dicts and lists to plotly graph objs.
#  |
#  |      For each key in the object, if it corresponds to a special key that
#  |      should be associated with a graph object, the ordinary dict or list
#  |      will be reinitialized as a special PlotlyDict or PlotlyList of the
#  |      appropriate `kind`.
#  |
#  |  update(self, dict1=None, **dict2)
#  |      Update current dict with changed_dict.
#  |
#  |      This recursively updates the structure of the original dictionary-like
#  |      object with the new entries in the second object. This allows users
#  |      to update with large, nested structures.
#  |
#  |      Example:
#  |      obj = Layout(title='my title', xaxis=XAxis(range=[0,1], domain=[0,1]))
#  |      obj.update(dict(title='new title', xaxis=dict(domain=[0,.8])))
#  |      obj
#  |      {'title': 'new title', 'xaxis': {'range': [0,1], 'domain': [0,.8]}}
#  |
#  |      This `somewhat` supports duck-typing. It will accept the standard
#  |      call to `update` like any dict object, however, it only supports
#  |      updating from ONE new dictionary, a second dictionary will simply be
#  |      ignored and the user will be warned.
#  |
#  |  validate(self)
#  |      Recursively check the validity of the keys in a PlotlyDict.
#  |
#  |      The valid keys constitute the entries in each object
#  |      dictionary in INFO stored in graph_objs_meta.py.
#  |
#  |      The validation process first requires that all nested collections be
#  |      converted to the appropriate subclass of PlotlyDict/PlotlyList. Then,
#  |      each of these objects call `validate` and so on, recursively,
#  |      until the entire object has been validated.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from PlotlyDict:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes inherited from PlotlyDict:
#  |
#  |  __metaclass__ = <class 'plotly.graph_objs.graph_objs.DictMeta'>
#  |      A meta class for PlotlyDict class creation.
#  |
#  |      The sole purpose of this meta class is to properly create the __doc__
#  |      attribute so that running help(Obj), where Obj is a subclass of PlotlyDict,
#  |      will return information about key-value pairs for that object.
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from __builtin__.dict:
#  |
#  |  __cmp__(...)
#  |      x.__cmp__(y) <==> cmp(x,y)
#  |
#  |  __contains__(...)
#  |      D.__contains__(k) -> True if D has a key k, else False
#  |
#  |  __delitem__(...)
#  |      x.__delitem__(y) <==> del x[y]
#  |
#  |  __eq__(...)
#  |      x.__eq__(y) <==> x==y
#  |
#  |  __ge__(...)
#  |      x.__ge__(y) <==> x>=y
#  |
#  |  __getattribute__(...)
#  |      x.__getattribute__('name') <==> x.name
#  |
#  |  __getitem__(...)
#  |      x.__getitem__(y) <==> x[y]
#  |
#  |  __gt__(...)
#  |      x.__gt__(y) <==> x>y
#  |
#  |  __iter__(...)
#  |      x.__iter__() <==> iter(x)
#  |
#  |  __le__(...)
#  |      x.__le__(y) <==> x<=y
#  |
#  |  __len__(...)
#  |      x.__len__() <==> len(x)
#  |
#  |  __lt__(...)
#  |      x.__lt__(y) <==> x<y
#  |
#  |  __ne__(...)
#  |      x.__ne__(y) <==> x!=y
#  |
#  |  __repr__(...)
#  |      x.__repr__() <==> repr(x)
#  |
#  |  __setitem__(...)
#  |      x.__setitem__(i, y) <==> x[i]=y
#  |
#  |  __sizeof__(...)
#  |      D.__sizeof__() -> size of D in memory, in bytes
#  |
#  |  clear(...)
#  |      D.clear() -> None.  Remove all items from D.
#  |
#  |  copy(...)
#  |      D.copy() -> a shallow copy of D
#  |
#  |  fromkeys(...)
#  |      dict.fromkeys(S[,v]) -> New dict with keys from S and values equal to v.
#  |      v defaults to None.
#  |
#  |  get(...)
#  |      D.get(k[,d]) -> D[k] if k in D, else d.  d defaults to None.
#  |
#  |  has_key(...)
#  |      D.has_key(k) -> True if D has a key k, else False
#  |
#  |  items(...)
#  |      D.items() -> list of D's (key, value) pairs, as 2-tuples
#  |
#  |  iteritems(...)
#  |      D.iteritems() -> an iterator over the (key, value) items of D
#  |
#  |  iterkeys(...)
#  |      D.iterkeys() -> an iterator over the keys of D
#  |
#  |  itervalues(...)
#  |      D.itervalues() -> an iterator over the values of D
#  |
#  |  keys(...)
#  |      D.keys() -> list of D's keys
#  |
#  |  pop(...)
#  |      D.pop(k[,d]) -> v, remove specified key and return the corresponding value.
#  |      If key is not found, d is returned if given, otherwise KeyError is raised
#  |
#  |  popitem(...)
#  |      D.popitem() -> (k, v), remove and return some (key, value) pair as a
#  |      2-tuple; but raise KeyError if D is empty.
#  |
#  |  setdefault(...)
#  |      D.setdefault(k[,d]) -> D.get(k,d), also set D[k]=d if k not in D
#  |
#  |  values(...)
#  |      D.values() -> list of D's values
#  |
#  |  viewitems(...)
#  |      D.viewitems() -> a set-like object providing a view on D's items
#  |
#  |  viewkeys(...)
#  |      D.viewkeys() -> a set-like object providing a view on D's keys
#  |
#  |  viewvalues(...)
#  |      D.viewvalues() -> an object providing a view on D's values
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes inherited from __builtin__.dict:
#  |
#  |  __hash__ = None
#  |
#  |  __new__ = <built-in method __new__ of type object>
#  |      T.__new__(S, ...) -> a new object with type S, a subtype of T

# %%
# (*) Other graph objects required for the following plot
from plotly.graph_objs import Box

# Trace-generating function (returns a Box object)
def make_trace(y_in,name_in):
    return Box(y=y_in, 
               name=name_in,
               boxpoints='all',  # ---
               jitter=0.1,          # width of jittered scatter
               pointpos=-1.5,       # scatter offset from box plot
               marker= Marker(size=10)
              ) 

# change color ...

my_data = Data([make_trace(homeworks,'Homeworks'),
                make_trace(midterm,'Midterm Exam'),
                make_trace(final,'Final Exam'),
                make_trace(course,'Course Grade')])

my_layout = Layout(title='Fig 4.4a: Course Grade Distribution',
                   yaxis= YAxis(title='Grade [%]'),
                   showlegend=False
                  ) 
                   
# Make Figure object, send to Plotly and show in notebook
my_fig = Figure(data=my_data, layout=my_layout)
py.iplot(my_fig, filename='s4_grades-box')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~etpinard/91" height="525" width="100%"></iframe>

# %%
# try other option ...

# with std thing, outliers etc ...

# %% [markdown]
# <hr>
#
# **Go to** [previous section](http://nbviewer.ipython.org/github/etpinard/plotly-python-doc/blob/master/s3_bubble-charts/s3_bubble-charts.ipynb)
#
# **Go to** [next section](http://nbviewer.ipython.org/github/etpinard/plotly-python-doc/blob/master/s5_heatmaps/s5_heatmaps.ipynb)
#
# **Go back to** [top of page](http://nbviewer.ipython.org/github/etpinard/plotly-python-doc/tree/1.0/s4_histograms/s4_histograms.ipynb#)
#
# **Go back to User Guide's** [homepage](http://nbviewer.ipython.org/github/etpinard/plotly-python-doc/blob/master/s00_homepage/s00_homepage.ipynb)
#
# <hr>

# %% [markdown]
# <div style="float:right; \">
#     <img src="http://i.imgur.com/4vwuxdJ.png"
#  align=right style="float:right; margin-left: 5px; margin-top: -10px" />
# </div>
#
# <h4>Got Questions and Feedback? </h4>
#
# About <a href="https://plot.ly" target="_blank">Plotly</a>
#
# * email: feedback@plot.ly
# * tweet:
# <a href="https://twitter.com/plotlygraphs" target="_blank">@plotlygraphs</a>
#
# About the <a href="https://github.com/etpinard/plotly-python-doc" target="_blank">User Guide</a>
#
# * email: etienne@plot.ly
# * tweet: <a href="https://twitter.com/etpinard" target="_blank">@etpinard</a>
#
# <h4 style="margin-top:30px;">Notebook styling ideas</h4>
#
# Big thanks to
#
# * <a href="http://nbviewer.ipython.org/github/CamDavidsonPilon/Probabilistic-Programming-and-Bayesian-Methods-for-Hackers/blob/master/Prologue/Prologue.ipynb" target="_blank">Cam Davidson-Pilon</a>
# * <a href="http://lorenabarba.com/blog/announcing-aeropython/#.U1ULXdX1LJ4.google_plusone_share" target="_blank">Lorena A. Barba</a>

# %%
from IPython.core.display import HTML
def css_styling():
    styles = open("../plotly-python-doc.css", "r").read()
    return HTML(styles)
css_styling()
# Out:
# <style>
#     @font-face {
#         font-family: "Computer Modern";
#         src: url('http://9dbb143991406a7c655e-aa5fcb0a5a4ec34cff238a2d56ca4144.r56.cf5.rackcdn.com/cmunss.otf');
#     }
#     @font-face {
#         font-family: "Computer Modern";
#         font-weight: bold;
#         src: url('http://9dbb143991406a7c655e-aa5fcb0a5a4ec34cff238a2d56ca4144.r56.cf5.rackcdn.com/cmunsx.otf');
#     }
#     @font-face {
#         font-family: "Computer Modern";
#         font-style: oblique;
#         src: url('http://9dbb143991406a7c655e-aa5fcb0a5a4ec34cff238a2d56ca4144.r56.cf5.rackcdn.com/cmunsi.otf');
#     }
#     @font-face {
#         font-family: "Computer Modern";
#         font-weight: bold;
#         font-style: oblique;
#         src: url('http://9dbb143991406a7c655e-aa5fcb0a5a4ec34cff238a2d56ca4144.r56.cf5.rackcdn.com/cmunso.otf');
#     }
#     div.cell{
#         width:800px;
#         margin-left:16% !important;
#         margin-right:auto;
#     }
#     h1 {
#         /* font-family: Computer Modern, serif; */
#         color: #333333;
#         font-family: ‘Lucida Console’, Monaco, monospace;
#     }
#     h4{
#         color: #333333;
#         font-family: ‘Lucida Console’, Monaco, monospace;
#         margin-top:15px;
#         margin-bottom: 3px;
#        }
#     div.text_cell_render{
#      /*   font-family: Computer Modern, "Helvetica Neue", Arial, Helvetica, Geneva, sans-serif; */
#         color: #333333;
#      /*   font-family: ‘Palatino Linotype’, ‘Book Antiqua’, Palatino, serif; */
#      /*   font-family: ‘Trebuchet MS’, Helvetica, sans-serif; */
#         font-family: ‘Lucida Sans Unicode’, ‘Lucida Grande’, sans-serif;
#         line-height: 145%;
#         font-size: 130%;
#         width: 800px;
#         margin-left:auto;
#         margin-right:auto;
#         text-align:justify;
#         text-justify:inter-word;
#     }
#     code{
#           font-size: 85%;
#     }
#     ul{
#         margin: 2em;
#     }
#     ul li{
#            padding-left: 0.5em;
#            margin-bottom: 0.5em;
#            margin-top: 0.5em;
#     }
#     a:link{
#        text-decoration: none;
#        font-weight: bold;
#     }
#     a:visited{
#        text-decoration: none;
#        font-weight: bold;
#     }
#     a:hover{
#        text-decoration: none;
#        font-weight: bold;
#     }
#     a:focus{
#        text-decoration: none;
#        font-weight: bold;
#     }
#     a:active{
#        text-decoration: none;
#        font-weight: bold;
#     }
#     .CodeMirror{
#             font-family: "Source Code Pro", source-code-pro,Consolas, monospace;
#     }
#     .prompt{
#         display: None;
#     }
#     .text_cell_render h5 {
#         font-weight: 300;
#         font-size: 22pt;
#         color: #4057A1;
#         font-style: italic;
#         margin-bottom: .5em;
#         margin-top: 0.5em;
#         display: block;
#     }
#     .warning{
#         color: rgb( 240, 20, 20 )
#         }
# </style>
# <script>
#     MathJax.Hub.Config({
#                         TeX: {
#                            extensions: ["AMSmath.js"]
#                            },
#                 tex2jax: {
#                     inlineMath: [ ['$','$'], ["\\(","\\)"] ],
#                     displayMath: [ ['$$','$$'], ["\\[","\\]"] ]
#                 },
#                 displayAlign: 'center', // Change this to 'center' to center equations.
#                 "HTML-CSS": {
#                     styles: {'.MathJax_Display': {"margin": 4}}
#                 }
#         });
# </script>
