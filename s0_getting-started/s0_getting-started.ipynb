# %% [markdown]
# # Plotly's Python API User Guide

# %% [markdown]
# ## Section 0: Getting Started with Plotly

# %% [markdown]
# Welcome to Plotly's Python API User Guide.
#
# > Links to the other sections are on the User Guide's [homepage](http://nbviewer.ipython.org/github/plotly/python-user-guide/blob/master/s00_homepage/s00_homepage.ipynb#Table-of-Contents:) <br>
# The Github repository is available
# <a href="https://github.com/plotly/python-user-guide" target="_blank">here</a>

# %% [markdown]
# Section 0 is divided as follows:
#
# * [0.1 The Plotly philosophy](#0.1-The-Plotly-Philosophy)
#
# * [0.2 Set up Plotly to start making plots](#0.2-Set-up-Ploty-to-start-making-plots)
#
# * [0.3 A first Plotly plot](#0.3-A-first-Plotly-plot)
#
# * [0.4 Plotly's graph objects](#0.4-Plotly's-graph-objects)
#
# * [0.5 Graph object methods](#0.5-Graph-object-methods)
#
# * [0.6 Get figure and new possible workflows](#0.6-Get-figure-and-new-possible-workflows)
#
# * [0.7 Subplots and other version 1.0 additions](#0.7-Subplots-and-other-version-1.0-additions)
#
# <hr>

# %% [markdown]
# ### 0.1 The Plotly Philosophy

# %% [markdown]
# Python gives users access to easy-to-use, serializible data structures. Namely, these are  lists and dictionaries.
#
# Plotly let's you use what you already know about handling these data structures to make beautiful visualizations of your data. The figures you make in Plotly are nothing more than an organized, nested dictionary.
#
# > Working with Plotly's Python API sums up to working with Python lists and dictionaries.
#
# If you are new to Python or in need of a brush up, we recommand looking over the User Guide's [Appendix A](http://nbviewer.ipython.org/github/plotly/python-user-guide/blob/master/sA_python-basics/sA_python-basics.ipynb), where we present valuable information about the Python features most used in the User Guide.
#
# The latest version (v 1.0) of Plotly's Python API verison features many improvements.
#
# * A *get* function, to import data and styles from public figures on Plotly's servers,
#
# * Easier manipulation and customization of Python lists and dictionaries through *graph objects*,
#
# * Running the help function on Plotly objects is now actually helpful,
#
# * Local validation happens on your machine, points directly to errors, and offers suggestions,
#
# * The API now supports local configuration files for saving and retrieving account *credentials*,
#
# * A *save_as* function to save Plotly figures as <a href="http://en.wikipedia.org/wiki/Portable_Network_Graphics" target="_blank">.png</a> figures on your computer from a Python/IPython session,
#
# * The API now has a subplot generating function.
#
# And as before, making Plotly figures is a *declarative* process that requires no *getter* nor *setter* functions that you need to memorize.

# %% [markdown]
# ### 0.2 Set up Ploty to start making plots

# %% [markdown]
# The User Guide's <a href="http://nbviewer.ipython.org/github/plotly/python-user-guide/blob/master/s00_homepage/s00_homepage.ipynb#Installation-guidelines" target="_blank">homepage</a> walks you through the Plotly installation/sign up process.
#
# Note that experienced Plotly user may need to upgrade to version 1.0. To check which Plotly version is installed on your machine, run (inside Python or IPython):

# %%
# Check Plotly version
import plotly
plotly.__version__
# Out:
# '1.0.22'

# %% [markdown]
# If not latest version (`1.0.22` and up), run in a terminal:
#
#   * `$ pip install plotly --upgrade`
#
# If you have issues upgrading and installing Plotly, please contact us at feedback@plot.ly
#
# The content of version 1.0.\* of the Plotly Python package is split into three modules:
#
# * `plotly.plotly`
# * `plotly.tools`
# * `plotly.graph_objs`
#
# Loosley speaking, the `plotly.plotly` module contains functions that require a response from Plotly's servers. Functions in this module are the liaison between your local machine and Plotly.
#
# The `plotly.tools` module is a set of helpful (new) functions facilitating and enhancing the Plotly experience. Functions for subplot generation, embedding Plotly plots in IPython notebooks, saving and retrieving your credentials are now at your finger tips.
#
# And finally, the `plotly.graph_objs` module contains all of the class definitions for the objects that make up the plots you see. These *graph objects* are for instance: Figure, Data, Layout, Scatter,  etc. Graph objects are an important addition to version 1.0 of Plotly's Python API. They are  dictionary- and list-like objects used to generate and/or modify every feature of a Plotly plot. Graph objects are covered in details in [subsection 0.4](#0.4-Plotly's-graph-objects).

# %% [markdown]
# But for now, let's sign in to Plotly and get ready to make a simple first plot:

# %%
# How you communicate with Plotly's servers
import plotly.plotly as py

# %% [markdown]
# In version 1.0.\* of Plotly's Python API, once you have set up your credentials file, the above line of code is all you need to sign in to Plotly's servers. *That's right, you are now signed in!*
#
# How does that work? While being imported, the `plotly.plotly` module looks for your credentials file on your machine and automatically uses it to sign in to Plotly's servers.
#
# Using credentials files allows users to share code without having to type in (let alone remember) their own username and API key every time they want to generate a new Plotly plot or modify an existing Plotly plot.
#
# For information on how to set up your credentials file (don't panic, it is a two-line process), refer to the User Guide's <a href="http://nbviewer.ipython.org/github/plotly/python-user-guide/blob/master/s00_homepage/s00_homepage.ipynb#Step-6" target="_blank">homepage</a>
#
# That said, if more convenient, users can still manually sign in to Plotly by typing:
#
#     >>> py.sign_in('your_username','your_api_key')
#
# Note that the syntax has been modified form version 0.5.\* of Plotly's Python package.

# %% [markdown]
# Next, to enhance our Plotly plotting experience, we import the `plotly.tools` module:

# %%
# Useful tools, e.g., get_sublots(), embed()
import plotly.tools as tls

# %% [markdown]
# The `py` and `tls` are the recommended references for the `plotly.plotly` and `plotly.tools` modules respectively. They are used throughout the User Guide.

# %% [markdown]
# ### 0.3 A first Plotly plot

# %% [markdown]
# For our first plot, let's take two lists of numbers and plot them against each other.
# In later sections, we use real data files, but for now this will do.
#
# Plot data and style options are sent to Plotly through the first argument of the `plot()` function of the (you guessed it) `plotly.plotly` module.
#
# That's right, data AND style options make up only one argument in Plotly, which is packaged in one Python dictionary.
# More specifically, this `plot()` function anticipates one and only one *figure object* (more in [subsection 0.4](#0.4-Plotly's-graph-objects)).
#
# Consider the following code:

# %%
# Two lists of numbers
my_x0 = [1,2,3,5,6]
my_y0 = [1,4.5,7,24,38]

# Make dictionary linking x and y coordinate lists to 'x' and 'y' keys
#  (mandatory in plotly v.1.0.8 and up)
my_trace = dict(x=my_x0, y=my_y0)

# Make list of 1 trace, to be sent to Plotly
#  (mandatory in 1.0.8 and up)
my_data = [my_trace]

# %%
# Call the plot() function of the plotly.plotly submodule,
#  save figure as 's0_first_plot'
py.plot(my_data, filename='s0_first_plot')
# Out:
# u'https://plot.ly/~etpinard/157'

# %% [markdown]
# Good.
#
# We need to mention that, by default, the `plot()` function prints the unique URL that identifies the figure on the stdout and opens a new tab in your browser showing the plot just generated on the Plotly website.
#
# Here's a snapshot:
#
# <img src="http://i.imgur.com/Kbw7GLg.png" />
#
# <br>
#
# If you don't like having Plotly open a new tab every time you make a plot, you can turn this feature off simply by adding one keyword argument to `plot()`:

# %%
# Make Plotly plot but do no open a new tab
py.plot(my_data, filename='s0_first_plot', auto_open=False)
# Out:
# u'https://plot.ly/~etpinard/157'

# %% [markdown]
# The keyword argument `filename` is used to name our Plotly plot. Here, the generated figure is saved in your own Plotly directory as `s0_first_plot`.
#
# By default, this figure is accessible for all. If you want to keep your plots private, add the following keyword argument in the `plot()` call:
#
#     world_readable=False
#
# But careful! Users with a free account have a limiting number of private figures that they can save on the Plotly servers. For more info, see our <a href="https://plot.ly/plans" target="_blank">plans and pricing</a>.

# %% [markdown]
# For IPython notebook users (like us here in the User Guide), Plotly makes it easy to incorporate Plotly plots inside IPython notebooks. By calling the `iplot()` function instead of the `plot()`, Plotly embeds the generated plot directly in the cell, similar to the IPython `%matplotlib inline` magic:

# %%
# Sent data to Plotly and show result in notebook 
py.iplot(my_data, filename='s0_first_plot')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~etpinard/157" height="525" width="100%"></iframe>

# %% [markdown]
# Fantastic and convenient, the `iplot()` function is used throughout the User Guide.
#
# Plotly plots are fully interactive (even inside IPython notebooks):
#
# * Users can check the x and y coordinates of every point on the plot by hovering with the cursor.
# * By clicking and dragging the cursor over a region, Plotly zooms in on the plot and resizes lines, points and axes (not just a static zoom, try it!).
# * Hold the shift key while clicking and dragging to pan.
# * Finally, a double click on the plot zooms back out to the original version.
#
#
# <!-- mention the 'data and graph' button here?? -->
#
# In brief, Plotly is great for quick and simple data visualization. It turns lists of numbers into plots very easily. That said, for custom and professional-looking plots (with titles among other things), we need to learn how to use Plotly in conjunction with Python lists and dictionaries as well as (now in version 1.0) Plotly graph objects.

# %% [markdown]
# ### 0.4 Plotly's graph objects

# %% [markdown]
# <h4>Question:</h4>
# What are these Plotly graph objects?
#
# <h4>Answer 1:</h4>
# Very simply, Plotly graph objects are Python dictionaries and lists.
#
# <h4>Answer 2:</h4>
# More precisely, Plotly's Python API inherits from Python's native dictionary and list data structures. Then, by defining the Plotly graph objects as new classes, users can have access to class-specific help, validation, and functionality.
#
# <h4>Answer 3:</h4>
# And for the really technical among us, each Plotly graph object is represented by a sub-dictionary in a JSON structure that stores every bit of information of a Plotly plot, that is rendered by your browser.

# %% [markdown]
# > All bits of information of a Plotly plot are stored in a figure object. Specifically, the `Figure` object is the first required argument for the `plot()` and `iplot()` functions.
#
# A `Figure` object contains one `Data` graph object and one `Layout` graph object:
#
# * `Data` stores data and style options associated with traces (as a convention, we use the term *trace* to refer to any collection of data points meant to be plotted as a whole. For example in our first plot, the `my_x0`-`my_y0` list represents one trace).
#
# * `Layout` stores data and style options associated witht plot's layout features.
#
# For example, setting the line color is made via `Data` while setting the title of the plot is made via `Layout`.
#
# Plotly's Python API helps you create these objects by now offering up tons of help documentation, doing validation for you and offering tools to make the manipulation of these structures simpler.

# %% [markdown]
# So, let's start playing around with graph objects by importing `Data`, `Layout` and `Figure` from the `plotly.graph_objs` module:

# %%
# (NEW!) graph objects to piece together plots
from plotly.graph_objs import Data, Layout, Figure

# %% [markdown]
# Admire the extensive help documentation:

# %%
help(Figure)  # run help()!
# Out:
# Help on class Figure in module plotly.graph_objs.graph_objs:
#
# class Figure(PlotlyDict)
#  |  A dictionary-like object representing a figure to be rendered in plotly.
#  |
#  |      This is the container for all things to be rendered in a figure.
#  |
#  |      For help with setting up subplots, run:
#  |      `help(plotly.tools.get_subplots)`
#  |
#  |
#  |  Quick method reference:
#  |
#  |      Figure.update(changes)
#  |      Figure.strip_style()
#  |      Figure.get_data()
#  |      Figure.to_graph_objs()
#  |      Figure.validate()
#  |      Figure.to_string()
#  |      Figure.force_clean()
#  |
#  |  Valid keys:
#  |
#  |      data [required=False] (value=Data object | dictionary-like):
#  |          A list-like array of the data that is to be visualized.
#  |
#  |          For more, run `help(plotly.graph_objs.Data)`
#  |
#  |      layout [required=False] (value=Layout object | dictionary-like):
#  |          The layout dictionary-like object contains axes information, global
#  |          settings, and layout information related to the rendering of the
#  |          figure.
#  |
#  |          For more, run `help(plotly.graph_objs.Layout)`
#  |
#  |  Method resolution order:
#  |      Figure
#  |      PlotlyDict
#  |      __builtin__.dict
#  |      __builtin__.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, *args, **kwargs)
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from PlotlyDict:
#  |
#  |  force_clean(self, caller=True)
#  |      Attempts to convert to graph_objs and call force_clean() on values.
#  |
#  |      Calling force_clean() on a PlotlyDict will ensure that the object is
#  |      valid and may be sent to plotly. This process will also remove any
#  |      entries that end up with a length == 0.
#  |
#  |      Careful! This will delete any invalid entries *silently*.
#  |
#  |  get_data(self)
#  |      Returns the JSON for the plot with non-data elements stripped.
#  |
#  |  get_ordered(self, caller=True)
#  |
#  |  strip_style(self)
#  |      Strip style from the current representation.
#  |
#  |      All PlotlyDicts and PlotlyLists are guaranteed to survive the
#  |      stripping process, though they made be left empty. This is allowable.
#  |
#  |      Keys that will be stripped in this process are tagged with
#  |      `'type': 'style'` in the INFO dictionary listed in graph_objs_meta.py.
#  |
#  |      This process first attempts to convert nested collections from dicts
#  |      or lists to subclasses of PlotlyList/PlotlyDict. This process forces
#  |      a validation, which may throw exceptions.
#  |
#  |      Then, each of these objects call `strip_style` on themselves and so
#  |      on, recursively until the entire structure has been validated and
#  |      stripped.
#  |
#  |  to_graph_objs(self, caller=True)
#  |      Walk obj, convert dicts and lists to plotly graph objs.
#  |
#  |      For each key in the object, if it corresponds to a special key that
#  |      should be associated with a graph object, the ordinary dict or list
#  |      will be reinitialized as a special PlotlyDict or PlotlyList of the
#  |      appropriate `kind`.
#  |
#  |  to_string(self, level=0, indent=4, eol='\n', pretty=True, max_chars=80)
#  |      Returns a formatted string showing graph_obj constructors.
#  |
#  |              Example:
#  |
#  |                  print obj.to_string()
#  |
#  |              Keyword arguments:
#  |              level (default = 0) -- set number of indentations to start with
#  |              indent (default = 4) -- set indentation amount
#  |              eol (default = '
#  |      ') -- set end of line character(s)
#  |              pretty (default = True) -- curtail long list output with a '...'
#  |              max_chars (default = 80) -- set max characters per line
#  |
#  |  update(self, dict1=None, **dict2)
#  |      Update current dict with dict1 and then dict2.
#  |
#  |      This recursively updates the structure of the original dictionary-like
#  |      object with the new entries in the second and third objects. This
#  |      allows users to update with large, nested structures.
#  |
#  |      Note, because the dict2 packs up all the keyword arguments, you can
#  |      specify the changes as a list of keyword agruments.
#  |
#  |      Examples:
#  |      # update with dict
#  |      obj = Layout(title='my title', xaxis=XAxis(range=[0,1], domain=[0,1]))
#  |      update_dict = dict(title='new title', xaxis=dict(domain=[0,.8]))
#  |      obj.update(update_dict)
#  |      obj
#  |      {'title': 'new title', 'xaxis': {'range': [0,1], 'domain': [0,.8]}}
#  |
#  |      # update with list of keyword arguments
#  |      obj = Layout(title='my title', xaxis=XAxis(range=[0,1], domain=[0,1]))
#  |      obj.update(title='new title', xaxis=dict(domain=[0,.8]))
#  |      obj
#  |      {'title': 'new title', 'xaxis': {'range': [0,1], 'domain': [0,.8]}}
#  |
#  |      This 'fully' supports duck-typing in that the call signature is
#  |      identical, however this differs slightly from the normal update
#  |      method provided by Python's dictionaries.
#  |
#  |  validate(self, caller=True)
#  |      Recursively check the validity of the keys in a PlotlyDict.
#  |
#  |      The valid keys constitute the entries in each object
#  |      dictionary in INFO stored in graph_objs_meta.py.
#  |
#  |      The validation process first requires that all nested collections be
#  |      converted to the appropriate subclass of PlotlyDict/PlotlyList. Then,
#  |      each of these objects call `validate` and so on, recursively,
#  |      until the entire object has been validated.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from PlotlyDict:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes inherited from PlotlyDict:
#  |
#  |  __metaclass__ = <class 'plotly.graph_objs.graph_objs.DictMeta'>
#  |      A meta class for PlotlyDict class creation.
#  |
#  |      The sole purpose of this meta class is to properly create the __doc__
#  |      attribute so that running help(Obj), where Obj is a subclass of PlotlyDict,
#  |      will return information about key-value pairs for that object.
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from __builtin__.dict:
#  |
#  |  __cmp__(...)
#  |      x.__cmp__(y) <==> cmp(x,y)
#  |
#  |  __contains__(...)
#  |      D.__contains__(k) -> True if D has a key k, else False
#  |
#  |  __delitem__(...)
#  |      x.__delitem__(y) <==> del x[y]
#  |
#  |  __eq__(...)
#  |      x.__eq__(y) <==> x==y
#  |
#  |  __ge__(...)
#  |      x.__ge__(y) <==> x>=y
#  |
#  |  __getattribute__(...)
#  |      x.__getattribute__('name') <==> x.name
#  |
#  |  __getitem__(...)
#  |      x.__getitem__(y) <==> x[y]
#  |
#  |  __gt__(...)
#  |      x.__gt__(y) <==> x>y
#  |
#  |  __iter__(...)
#  |      x.__iter__() <==> iter(x)
#  |
#  |  __le__(...)
#  |      x.__le__(y) <==> x<=y
#  |
#  |  __len__(...)
#  |      x.__len__() <==> len(x)
#  |
#  |  __lt__(...)
#  |      x.__lt__(y) <==> x<y
#  |
#  |  __ne__(...)
#  |      x.__ne__(y) <==> x!=y
#  |
#  |  __repr__(...)
#  |      x.__repr__() <==> repr(x)
#  |
#  |  __setitem__(...)
#  |      x.__setitem__(i, y) <==> x[i]=y
#  |
#  |  __sizeof__(...)
#  |      D.__sizeof__() -> size of D in memory, in bytes
#  |
#  |  clear(...)
#  |      D.clear() -> None.  Remove all items from D.
#  |
#  |  copy(...)
#  |      D.copy() -> a shallow copy of D
#  |
#  |  fromkeys(...)
#  |      dict.fromkeys(S[,v]) -> New dict with keys from S and values equal to v.
#  |      v defaults to None.
#  |
#  |  get(...)
#  |      D.get(k[,d]) -> D[k] if k in D, else d.  d defaults to None.
#  |
#  |  has_key(...)
#  |      D.has_key(k) -> True if D has a key k, else False
#  |
#  |  items(...)
#  |      D.items() -> list of D's (key, value) pairs, as 2-tuples
#  |
#  |  iteritems(...)
#  |      D.iteritems() -> an iterator over the (key, value) items of D
#  |
#  |  iterkeys(...)
#  |      D.iterkeys() -> an iterator over the keys of D
#  |
#  |  itervalues(...)
#  |      D.itervalues() -> an iterator over the values of D
#  |
#  |  keys(...)
#  |      D.keys() -> list of D's keys
#  |
#  |  pop(...)
#  |      D.pop(k[,d]) -> v, remove specified key and return the corresponding value.
#  |      If key is not found, d is returned if given, otherwise KeyError is raised
#  |
#  |  popitem(...)
#  |      D.popitem() -> (k, v), remove and return some (key, value) pair as a
#  |      2-tuple; but raise KeyError if D is empty.
#  |
#  |  setdefault(...)
#  |      D.setdefault(k[,d]) -> D.get(k,d), also set D[k]=d if k not in D
#  |
#  |  values(...)
#  |      D.values() -> list of D's values
#  |
#  |  viewitems(...)
#  |      D.viewitems() -> a set-like object providing a view on D's items
#  |
#  |  viewkeys(...)
#  |      D.viewkeys() -> a set-like object providing a view on D's keys
#  |
#  |  viewvalues(...)
#  |      D.viewvalues() -> an object providing a view on D's values
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes inherited from __builtin__.dict:
#  |
#  |  __hash__ = None
#  |
#  |  __new__ = <built-in method __new__ of type object>
#  |      T.__new__(S, ...) -> a new object with type S, a subtype of T

# %%
help(Data)    # run help()!
# Out:
# Help on class Data in module plotly.graph_objs.graph_objs:
#
# class Data(PlotlyList)
#  |  A list of traces to be shown on a plot/graph.
#  |
#  |      Any operation that can be done with a standard list may be used with Data.
#  |      Instantiation requires an iterable (just like list does), for example:
#  |
#  |      Data([Scatter(), Heatmap(), Box()])
#  |
#  |      Valid entry types: (dict or any subclass of Trace, i.e., Scatter, Box, etc.)
#  |
#  |
#  |  Quick method reference:
#  |
#  |      Data.update(changes)
#  |      Data.strip_style()
#  |      Data.get_data()
#  |      Data.to_graph_objs()
#  |      Data.validate()
#  |      Data.to_string()
#  |      Data.force_clean()
#  |
#  |  Method resolution order:
#  |      Data
#  |      PlotlyList
#  |      __builtin__.list
#  |      __builtin__.object
#  |
#  |  Methods defined here:
#  |
#  |  to_graph_objs(self, caller=True)
#  |      Change any nested collections to subclasses of PlotlyDict/List.
#  |
#  |      Procedure:
#  |          1. Attempt to convert all entries to a subclass of PlotlyTrace.
#  |          2. Call `to_graph_objects` on each of these entries.
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from PlotlyList:
#  |
#  |  __init__(self, *args)
#  |
#  |  force_clean(self, caller=True)
#  |      Attempts to convert to graph_objs and calls force_clean() on entries.
#  |
#  |      Calling force_clean() on a PlotlyList will ensure that the object is
#  |      valid and may be sent to plotly. This process will remove any entries
#  |      that end up with a length == 0. It will also remove itself from
#  |      enclosing trivial structures if it is enclosed by a collection with
#  |      length 1, meaning the data is the ONLY object in the collection.
#  |
#  |      Careful! This will delete any invalid entries *silently*.
#  |
#  |  get_data(self)
#  |      Returns the JSON for the plot with non-data elements stripped.
#  |
#  |  get_ordered(self, caller=True)
#  |
#  |  strip_style(self)
#  |      Strip style from the current representation.
#  |
#  |      All PlotlyDicts and PlotlyLists are guaranteed to survive the
#  |      stripping process, though they made be left empty. This is allowable.
#  |
#  |      Keys that will be stripped in this process are tagged with
#  |      `'type': 'style'` in the INFO dictionary listed in graph_objs_meta.py.
#  |
#  |      This process first attempts to convert nested collections from dicts
#  |      or lists to subclasses of PlotlyList/PlotlyDict. This process forces
#  |      a validation, which may throw exceptions.
#  |
#  |      Then, each of these objects call `strip_style` on themselves and so
#  |      on, recursively until the entire structure has been validated and
#  |      stripped.
#  |
#  |  to_string(self, level=0, indent=4, eol='\n', pretty=True, max_chars=80)
#  |      Returns a formatted string showing graph_obj constructors.
#  |
#  |              Example:
#  |
#  |                  print obj.to_string()
#  |
#  |              Keyword arguments:
#  |              level (default = 0) -- set number of indentations to start with
#  |              indent (default = 4) -- set indentation amount
#  |              eol (default = '
#  |      ') -- set end of line character(s)
#  |              pretty (default = True) -- curtail long list output with a '...'
#  |              max_chars (default = 80) -- set max characters per line
#  |
#  |  update(self, changes)
#  |      Update current list with changed_list, which must be iterable.
#  |      The 'changes' should be a list of dictionaries, however,
#  |      it is permitted to be a single dict object.
#  |
#  |  validate(self, caller=True)
#  |      Recursively check the validity of the entries in a PlotlyList.
#  |
#  |      PlotlyList may only contain suclasses of PlotlyDict, or dictionary-like
#  |      objects that can be re-instantiated as subclasses of PlotlyDict.
#  |
#  |      The validation process first requires that all nested collections be
#  |      converted to the appropriate subclass of PlotlyDict/PlotlyList. Then,
#  |      each of these objects call `validate` and so on, recursively,
#  |      until the entire list has been validated.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from PlotlyList:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes inherited from PlotlyList:
#  |
#  |  __metaclass__ = <class 'plotly.graph_objs.graph_objs.ListMeta'>
#  |      A meta class for PlotlyList class creation.
#  |
#  |      The sole purpose of this meta class is to properly create the __doc__
#  |      attribute so that running help(Obj), where Obj is a subclass of PlotlyList,
#  |      will return useful information for that object.
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from __builtin__.list:
#  |
#  |  __add__(...)
#  |      x.__add__(y) <==> x+y
#  |
#  |  __contains__(...)
#  |      x.__contains__(y) <==> y in x
#  |
#  |  __delitem__(...)
#  |      x.__delitem__(y) <==> del x[y]
#  |
#  |  __delslice__(...)
#  |      x.__delslice__(i, j) <==> del x[i:j]
#  |
#  |      Use of negative indices is not supported.
#  |
#  |  __eq__(...)
#  |      x.__eq__(y) <==> x==y
#  |
#  |  __ge__(...)
#  |      x.__ge__(y) <==> x>=y
#  |
#  |  __getattribute__(...)
#  |      x.__getattribute__('name') <==> x.name
#  |
#  |  __getitem__(...)
#  |      x.__getitem__(y) <==> x[y]
#  |
#  |  __getslice__(...)
#  |      x.__getslice__(i, j) <==> x[i:j]
#  |
#  |      Use of negative indices is not supported.
#  |
#  |  __gt__(...)
#  |      x.__gt__(y) <==> x>y
#  |
#  |  __iadd__(...)
#  |      x.__iadd__(y) <==> x+=y
#  |
#  |  __imul__(...)
#  |      x.__imul__(y) <==> x*=y
#  |
#  |  __iter__(...)
#  |      x.__iter__() <==> iter(x)
#  |
#  |  __le__(...)
#  |      x.__le__(y) <==> x<=y
#  |
#  |  __len__(...)
#  |      x.__len__() <==> len(x)
#  |
#  |  __lt__(...)
#  |      x.__lt__(y) <==> x<y
#  |
#  |  __mul__(...)
#  |      x.__mul__(n) <==> x*n
#  |
#  |  __ne__(...)
#  |      x.__ne__(y) <==> x!=y
#  |
#  |  __repr__(...)
#  |      x.__repr__() <==> repr(x)
#  |
#  |  __reversed__(...)
#  |      L.__reversed__() -- return a reverse iterator over the list
#  |
#  |  __rmul__(...)
#  |      x.__rmul__(n) <==> n*x
#  |
#  |  __setitem__(...)
#  |      x.__setitem__(i, y) <==> x[i]=y
#  |
#  |  __setslice__(...)
#  |      x.__setslice__(i, j, y) <==> x[i:j]=y
#  |
#  |      Use  of negative indices is not supported.
#  |
#  |  __sizeof__(...)
#  |      L.__sizeof__() -- size of L in memory, in bytes
#  |
#  |  append(...)
#  |      L.append(object) -- append object to end
#  |
#  |  count(...)
#  |      L.count(value) -> integer -- return number of occurrences of value
#  |
#  |  extend(...)
#  |      L.extend(iterable) -- extend list by appending elements from the iterable
#  |
#  |  index(...)
#  |      L.index(value, [start, [stop]]) -> integer -- return first index of value.
#  |      Raises ValueError if the value is not present.
#  |
#  |  insert(...)
#  |      L.insert(index, object) -- insert object before index
#  |
#  |  pop(...)
#  |      L.pop([index]) -> item -- remove and return item at index (default last).
#  |      Raises IndexError if list is empty or index is out of range.
#  |
#  |  remove(...)
#  |      L.remove(value) -- remove first occurrence of value.
#  |      Raises ValueError if the value is not present.
#  |
#  |  reverse(...)
#  |      L.reverse() -- reverse *IN PLACE*
#  |
#  |  sort(...)
#  |      L.sort(cmp=None, key=None, reverse=False) -- stable sort *IN PLACE*;
#  |      cmp(x, y) -> -1, 0, 1
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes inherited from __builtin__.list:
#  |
#  |  __hash__ = None
#  |
#  |  __new__ = <built-in method __new__ of type object>
#  |      T.__new__(S, ...) -> a new object with type S, a subtype of T

# %%
help(Layout)  # run help()!
# Out:
# Help on class Layout in module plotly.graph_objs.graph_objs:
#
# class Layout(PlotlyDict)
#  |  A dictionary-like object holding plot settings for plotly figures.
#  |
#  |
#  |  Quick method reference:
#  |
#  |      Layout.update(changes)
#  |      Layout.strip_style()
#  |      Layout.get_data()
#  |      Layout.to_graph_objs()
#  |      Layout.validate()
#  |      Layout.to_string()
#  |      Layout.force_clean()
#  |
#  |  Valid keys:
#  |
#  |      title [required=False] (value=string):
#  |          The figure title.
#  |
#  |      xaxis [required=False] (value=XAxis object | dictionary-like):
#  |          The first 'xaxis' object can be entered into layout as 'xaxis' OR
#  |          'xaxis1', they're identical to plotly. After this, to create
#  |          references to new x-axes, you need to define them in the layout
#  |          dictionary.
#  |
#  |          For more, run `help(plotly.graph_objs.XAxis)`
#  |
#  |      yaxis [required=False] (value=YAxis object | dictionary-like):
#  |          The first 'yaxis' object can be entered into layout as 'yaxis' OR
#  |          'yaxis1', they're identical to plotly. After this, to create
#  |          references to new y-axes, you need to define them in the layout
#  |          dictionary.
#  |
#  |          For more, run `help(plotly.graph_objs.YAxis)`
#  |
#  |      legend [required=False] (value=Legend object | dictionary-like):
#  |          A dictionary-like object describing the legend settings for this
#  |          figure.
#  |
#  |          For more, run `help(plotly.graph_objs.Legend)`
#  |
#  |      width [required=False] (value=number: x > 0):
#  |          The width in pixels of the figure you're creating.
#  |
#  |      height [required=False] (value=number: x > 0):
#  |          The height in pixels of the figure you're creating.
#  |
#  |      autosize [required=False] (value=bool: True | False):
#  |          Toggle whether or not to let plotly autosize this figure for you.
#  |
#  |      categories [required=False] (value=Aw, snap! Undocumented!):
#  |          Aw, snap! Undocumented!
#  |
#  |      margin [required=False] (value=Margin object | dictionary-like):
#  |          A dictionary-like object for describing the figure's margins.
#  |
#  |          For more, run `help(plotly.graph_objs.Margin)`
#  |
#  |      paper_bgcolor [required=False] (value=str describing color):
#  |          str describing color
#  |
#  |      plot_bgcolor [required=False] (value=str describing color):
#  |          str describing color
#  |
#  |      dragmode [required=False] (value='zoom' | 'pan'):
#  |          Set what happens when a user preforms a mouse 'drag' in the plot
#  |          area. When set to 'zoom', a portion of the plot will be highlighted,
#  |          when the viewer exits the drag, this highlighted section will be
#  |          zoomed in on. When set to 'pan', data in the plot will move along
#  |          with the viewers dragging motions. A user can always depress the
#  |          'shift' key to access the whatever functionality has not been set as
#  |          the default.
#  |
#  |      hovermode [required=False] (value='closest' | 'x' | 'y'):
#  |          Set what happens when a user hovers over the figure. When set to
#  |          'x', all data sharing the same 'x' coordinate will be shown on
#  |          screen with corresponding trace labels. When set to 'y' all data
#  |          sharing the same 'y' coordainte will be shown on the screen with
#  |          corresponding trace labels. When set to 'closest', information about
#  |          the data point closest to where the viewer is hovering will appear.
#  |
#  |      barmode [required=False] (value='stack' | 'group' | 'overlay'):
#  |          This sets how multiple bar objects are plotted together. In other
#  |          words, this defines how bars at the same location appear on the
#  |          plot. If set to 'stack' the bars are stacked ontop of one another.
#  |          If set to 'group', the bars are plotted next to one another,
#  |          centered around the shared location. If set to 'overlay', the bars
#  |          are simply plotted over one another, you may need to set the opacity
#  |          to see this.
#  |
#  |      bargap [required=False] (value=number: x >= 0):
#  |          This sets the gap between bars (or sets of bars) at different
#  |          locations.
#  |
#  |      bargroupgap [required=False] (value=number: x >= 0):
#  |          This sets the gap between bars in the same group. That is, when
#  |          multiple bar objects are plotted and share the same locations, this
#  |          sets the distance between bars at each location.
#  |
#  |      boxmode [required=False] (value='overlay' | 'group'):
#  |          Sets how groups of box plots appear. If set to 'overlay', a group of
#  |          boxes will be plotted directly on top of one another at their
#  |          specified location. If set to 'group', the boxes will be centered
#  |          around their shared location, but they will not overlap.
#  |
#  |      boxgap [required=False] (value=number: x >= 0):
#  |          Set the spacing between neighboring box locations. This does not
#  |          effect the spacing within groups of boxes.
#  |
#  |      boxgroupgap [required=False] (value=number: x >= 0):
#  |          Set the spacing between neighboring boxes within a group. This does
#  |          not effect the spacing between boxes at neighboring box locations.
#  |
#  |      font [required=False] (value=Font object | dictionary-like):
#  |          Set the global font for the figure, e.g., all axis labels.
#  |
#  |          For more, run `help(plotly.graph_objs.Font)`
#  |
#  |      titlefont [required=False] (value=Font object | dictionary-like):
#  |          Set the title font for the figure.
#  |
#  |          For more, run `help(plotly.graph_objs.Font)`
#  |
#  |      separators [required=False] (value=Aw, snap! Undocumented!):
#  |          Aw, snap! Undocumented!
#  |
#  |      labeloffset [required=False] (value=Aw, snap! Undocumented!):
#  |          Aw, snap! Undocumented!
#  |
#  |      bardir [required=False] (value=Aw, snap! Undocumented!):
#  |          Aw, snap! Undocumented!
#  |
#  |      direction [required=Aw, snap! Undocumented!] (value=Aw, snap!
#  |      Undocumented!):
#  |          Aw, snap! Undocumented!
#  |
#  |      tickcolor [required=False] (value=Aw, snap! Undocumented!):
#  |          Aw, snap! Undocumented!
#  |
#  |      minortickcolor [required=False] (value=Aw, snap! Undocumented!):
#  |          Aw, snap! Undocumented!
#  |
#  |      defaultcolorrange [required=False] (value=Aw, snap! Undocumented!):
#  |          Aw, snap! Undocumented!
#  |
#  |      opacity [required=False] (value=number: x in [0, 1]):
#  |          Used with polar plots ONLY. Sets the opacity of the entire plot.
#  |
#  |      hidesources [required=False] (value=Aw, snap! Undocumented!):
#  |          Aw, snap! Undocumented!
#  |
#  |      showlegend [required=False] (value=bool: True | False):
#  |          Toggle whether or not the legend will be shown in this figure.
#  |
#  |      annotations [required=False] (value=Annotations object | dictionary-
#  |      like):
#  |          A list-like object that holds annotation dictionaries.
#  |
#  |          For more, run `help(plotly.graph_objs.Annotations)`
#  |
#  |      orientation [required=False] (value=Aw, snap! Undocumented!):
#  |          Aw, snap! Undocumented!
#  |
#  |      radialaxis [required=False] (value=RadialAxis object | dictionary-like):
#  |          A dictionary-like object describing the radial axis in a polar plot.
#  |
#  |          For more, run `help(plotly.graph_objs.RadialAxis)`
#  |
#  |      angularaxis [required=False] (value=AngularAxis object | dictionary-
#  |      like):
#  |          A dictionary-like object describing the angular axis in a polar
#  |          plot.
#  |
#  |          For more, run `help(plotly.graph_objs.AngularAxis)`
#  |
#  |      needsEndSpacing [required=Aw, snap! Undocumented!] (value=Aw, snap!
#  |      Undocumented!):
#  |          Aw, snap! Undocumented!
#  |
#  |  Method resolution order:
#  |      Layout
#  |      PlotlyDict
#  |      __builtin__.dict
#  |      __builtin__.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, *args, **kwargs)
#  |
#  |  force_clean(self, caller=True)
#  |      Attempts to convert to graph_objs and call force_clean() on values.
#  |
#  |      Calling force_clean() on a Layout will ensure that the object is
#  |      valid and may be sent to plotly. This process will also remove any
#  |      entries that end up with a length == 0.
#  |
#  |      Careful! This will delete any invalid entries *silently*.
#  |
#  |      This method differs from the parent (PlotlyDict) method in that it
#  |      must check for an infinite number of possible axis keys, i.e. 'xaxis',
#  |      'xaxis1', 'xaxis2', 'xaxis3', etc. Therefore, it cannot make a call
#  |      to super...
#  |
#  |  to_graph_objs(self, caller=True)
#  |      Walk obj, convert dicts and lists to plotly graph objs.
#  |
#  |      For each key in the object, if it corresponds to a special key that
#  |      should be associated with a graph object, the ordinary dict or list
#  |      will be reinitialized as a special PlotlyDict or PlotlyList of the
#  |      appropriate `kind`.
#  |
#  |  to_string(self, level=0, indent=4, eol='\n', pretty=True, max_chars=80)
#  |      Returns a formatted string showing graph_obj constructors.
#  |
#  |              Example:
#  |
#  |                  print obj.to_string()
#  |
#  |              Keyword arguments:
#  |              level (default = 0) -- set number of indentations to start with
#  |              indent (default = 4) -- set indentation amount
#  |              eol (default = '
#  |      ') -- set end of line character(s)
#  |              pretty (default = True) -- curtail long list output with a '...'
#  |              max_chars (default = 80) -- set max characters per line
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from PlotlyDict:
#  |
#  |  get_data(self)
#  |      Returns the JSON for the plot with non-data elements stripped.
#  |
#  |  get_ordered(self, caller=True)
#  |
#  |  strip_style(self)
#  |      Strip style from the current representation.
#  |
#  |      All PlotlyDicts and PlotlyLists are guaranteed to survive the
#  |      stripping process, though they made be left empty. This is allowable.
#  |
#  |      Keys that will be stripped in this process are tagged with
#  |      `'type': 'style'` in the INFO dictionary listed in graph_objs_meta.py.
#  |
#  |      This process first attempts to convert nested collections from dicts
#  |      or lists to subclasses of PlotlyList/PlotlyDict. This process forces
#  |      a validation, which may throw exceptions.
#  |
#  |      Then, each of these objects call `strip_style` on themselves and so
#  |      on, recursively until the entire structure has been validated and
#  |      stripped.
#  |
#  |  update(self, dict1=None, **dict2)
#  |      Update current dict with dict1 and then dict2.
#  |
#  |      This recursively updates the structure of the original dictionary-like
#  |      object with the new entries in the second and third objects. This
#  |      allows users to update with large, nested structures.
#  |
#  |      Note, because the dict2 packs up all the keyword arguments, you can
#  |      specify the changes as a list of keyword agruments.
#  |
#  |      Examples:
#  |      # update with dict
#  |      obj = Layout(title='my title', xaxis=XAxis(range=[0,1], domain=[0,1]))
#  |      update_dict = dict(title='new title', xaxis=dict(domain=[0,.8]))
#  |      obj.update(update_dict)
#  |      obj
#  |      {'title': 'new title', 'xaxis': {'range': [0,1], 'domain': [0,.8]}}
#  |
#  |      # update with list of keyword arguments
#  |      obj = Layout(title='my title', xaxis=XAxis(range=[0,1], domain=[0,1]))
#  |      obj.update(title='new title', xaxis=dict(domain=[0,.8]))
#  |      obj
#  |      {'title': 'new title', 'xaxis': {'range': [0,1], 'domain': [0,.8]}}
#  |
#  |      This 'fully' supports duck-typing in that the call signature is
#  |      identical, however this differs slightly from the normal update
#  |      method provided by Python's dictionaries.
#  |
#  |  validate(self, caller=True)
#  |      Recursively check the validity of the keys in a PlotlyDict.
#  |
#  |      The valid keys constitute the entries in each object
#  |      dictionary in INFO stored in graph_objs_meta.py.
#  |
#  |      The validation process first requires that all nested collections be
#  |      converted to the appropriate subclass of PlotlyDict/PlotlyList. Then,
#  |      each of these objects call `validate` and so on, recursively,
#  |      until the entire object has been validated.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from PlotlyDict:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes inherited from PlotlyDict:
#  |
#  |  __metaclass__ = <class 'plotly.graph_objs.graph_objs.DictMeta'>
#  |      A meta class for PlotlyDict class creation.
#  |
#  |      The sole purpose of this meta class is to properly create the __doc__
#  |      attribute so that running help(Obj), where Obj is a subclass of PlotlyDict,
#  |      will return information about key-value pairs for that object.
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from __builtin__.dict:
#  |
#  |  __cmp__(...)
#  |      x.__cmp__(y) <==> cmp(x,y)
#  |
#  |  __contains__(...)
#  |      D.__contains__(k) -> True if D has a key k, else False
#  |
#  |  __delitem__(...)
#  |      x.__delitem__(y) <==> del x[y]
#  |
#  |  __eq__(...)
#  |      x.__eq__(y) <==> x==y
#  |
#  |  __ge__(...)
#  |      x.__ge__(y) <==> x>=y
#  |
#  |  __getattribute__(...)
#  |      x.__getattribute__('name') <==> x.name
#  |
#  |  __getitem__(...)
#  |      x.__getitem__(y) <==> x[y]
#  |
#  |  __gt__(...)
#  |      x.__gt__(y) <==> x>y
#  |
#  |  __iter__(...)
#  |      x.__iter__() <==> iter(x)
#  |
#  |  __le__(...)
#  |      x.__le__(y) <==> x<=y
#  |
#  |  __len__(...)
#  |      x.__len__() <==> len(x)
#  |
#  |  __lt__(...)
#  |      x.__lt__(y) <==> x<y
#  |
#  |  __ne__(...)
#  |      x.__ne__(y) <==> x!=y
#  |
#  |  __repr__(...)
#  |      x.__repr__() <==> repr(x)
#  |
#  |  __setitem__(...)
#  |      x.__setitem__(i, y) <==> x[i]=y
#  |
#  |  __sizeof__(...)
#  |      D.__sizeof__() -> size of D in memory, in bytes
#  |
#  |  clear(...)
#  |      D.clear() -> None.  Remove all items from D.
#  |
#  |  copy(...)
#  |      D.copy() -> a shallow copy of D
#  |
#  |  fromkeys(...)
#  |      dict.fromkeys(S[,v]) -> New dict with keys from S and values equal to v.
#  |      v defaults to None.
#  |
#  |  get(...)
#  |      D.get(k[,d]) -> D[k] if k in D, else d.  d defaults to None.
#  |
#  |  has_key(...)
#  |      D.has_key(k) -> True if D has a key k, else False
#  |
#  |  items(...)
#  |      D.items() -> list of D's (key, value) pairs, as 2-tuples
#  |
#  |  iteritems(...)
#  |      D.iteritems() -> an iterator over the (key, value) items of D
#  |
#  |  iterkeys(...)
#  |      D.iterkeys() -> an iterator over the keys of D
#  |
#  |  itervalues(...)
#  |      D.itervalues() -> an iterator over the values of D
#  |
#  |  keys(...)
#  |      D.keys() -> list of D's keys
#  |
#  |  pop(...)
#  |      D.pop(k[,d]) -> v, remove specified key and return the corresponding value.
#  |      If key is not found, d is returned if given, otherwise KeyError is raised
#  |
#  |  popitem(...)
#  |      D.popitem() -> (k, v), remove and return some (key, value) pair as a
#  |      2-tuple; but raise KeyError if D is empty.
#  |
#  |  setdefault(...)
#  |      D.setdefault(k[,d]) -> D.get(k,d), also set D[k]=d if k not in D
#  |
#  |  values(...)
#  |      D.values() -> list of D's values
#  |
#  |  viewitems(...)
#  |      D.viewitems() -> a set-like object providing a view on D's items
#  |
#  |  viewkeys(...)
#  |      D.viewkeys() -> a set-like object providing a view on D's keys
#  |
#  |  viewvalues(...)
#  |      D.viewvalues() -> an object providing a view on D's values
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes inherited from __builtin__.dict:
#  |
#  |  __hash__ = None
#  |
#  |  __new__ = <built-in method __new__ of type object>
#  |      T.__new__(S, ...) -> a new object with type S, a subtype of T

# %% [markdown]
# Notice that `Data` is a list-like object whereas `Figure` and `Layout` are dictionary-like objects. Ordering is important in `Data` as individual traces are plotted in order starting from the first trace graph object in `Data`. For example, a scatter trace plotted over a bar trace does not yield, in general, the same plot as a bar trace plotted over a scatter trace.
#
# Speaking of traces, every Plotly plot type has its own graph object (or more specifically its own *trace graph object*) e.g. `Scatter`, `Bar`, `Histogram`. As a first example, let's try to improve on our first plot by incorporating the graph object `Scatter`:

# %%
# (*) Import the Scatter graph object
from plotly.graph_objs import Scatter

# Again, run help() for fun
help(Scatter)
# Out:
# Help on class Scatter in module plotly.graph_objs.graph_objs:
#
# class Scatter(PlotlyTrace)
#  |  A dictionary-like object for representing a scatter plot in plotly.
#  |
#  |      Example:
#  |
#  |          py.plot([Scatter(name='tacters', x=[1,4,2,3], y=[1,6,2,1])])
#  |
#  |
#  |  Quick method reference:
#  |
#  |      Scatter.update(changes)
#  |      Scatter.strip_style()
#  |      Scatter.get_data()
#  |      Scatter.to_graph_objs()
#  |      Scatter.validate()
#  |      Scatter.to_string()
#  |      Scatter.force_clean()
#  |
#  |  Valid keys:
#  |
#  |      x [required=True] (value=array-like of numbers, strings, datetimes):
#  |          The x coordinates from the (x,y) pair on the scatter plot.
#  |
#  |      y [required=True] (value=array-like of numbers, strings, datetimes):
#  |          The y coordinates from the (x,y) pair on the scatter plot.
#  |
#  |      text [required=False] (value=array-like of strings):
#  |          The text elements associated with every (x,y) pair on the scatter
#  |          plot. If the scatter 'mode' doesn't include 'text' then text will
#  |          appear on hover. If 'text' is included in 'mode', the entries in
#  |          'text' will be rendered on the plot at the locations specified by
#  |          their corresponding (x, y) pair.
#  |
#  |      textposition [required=False] (value='top' | 'bottom'):
#  |          Set's position of the text elements in the 'text' key.
#  |
#  |      name [required=False] (value=string):
#  |          The label associated with this trace. This name will appear in the
#  |          legend, in the column header in the spreadsheet, and on hover.
#  |
#  |      mode [required=False] (value='lines' | 'markers' | 'text' |
#  |      'lines+markers' | 'lines+text' | 'markers+text' | 'lines+markers+text'):
#  |          Plotting mode (style) for the scatter plot. If the mode includes
#  |          'text' then the 'text' will appear at the (x,y) points, otherwise it
#  |          will appear on hover.
#  |
#  |      marker [required=False] (value=Marker object | dictionary-like):
#  |          A dictionary-like object containing information about the marker
#  |          style of the scatter plot.
#  |
#  |          For more, run `help(plotly.graph_objs.Marker)`
#  |
#  |      line [required=False] (value=Line object | dictionary-like):
#  |          A dictionary-like object containing information about the line
#  |          connecting points on the scatter plot.
#  |
#  |          For more, run `help(plotly.graph_objs.Line)`
#  |
#  |      fill [required=False] (value='none' | 'tozeroy' | 'tonexty' | 'tozerox'
#  |      | 'tonextx):
#  |          Used to make area-style charts. Determines which area to fill with a
#  |          solid color.
#  |
#  |      fillcolor [required=False] (value=str describing color):
#  |          If the 'fill' for a line is not 'none', the fill color will appear
#  |          in the specified fill area.
#  |
#  |          Examples:
#  |              ["'green'", "'rgb(0, 255, 0)'", "'rgba(0, 255, 0, 0.3)'",
#  |              "'hsl(120,100%,50%)'", "'hsla(120,100%,50%,0.3)'"]
#  |
#  |      opacity [required=False] (value=number: x in [0, 1]):
#  |          Sets the opacity, or transparency, of this object. Also known as the
#  |          alpha channel of colors, if the object's color is given in terms of
#  |          'rgba', this does not need to be defined.
#  |
#  |      showlegend [required=False] (value=bool: True | False):
#  |          Toggle whether or not this trace will show up in the legend.
#  |
#  |      stream [required=False] (value=dictionary-like):
#  |          The stream dict that initializes traces as writable-streams, for use
#  |          with the real-time streaming API. See examples here:
#  |          http://nbviewer.ipython.org/github/plotly/Streaming-Demos
#  |
#  |      xaxis [required=False] (value=string: 'x1' | 'x2' | 'x3' | etc.):
#  |          This key determines which xaxis the x coordinates in this trace will
#  |          reference in the figure. 'x' references layout['xaxis'] and 'x2'
#  |          references layout['xaxis2']. 'x1' will always refer to
#  |          layout['xaxis'] or layout['xaxis1'], they are the same.
#  |
#  |      yaxis [required=False] (value=string: 'y1' | 'y2' | 'y3' | etc.):
#  |          This key determines which yaxis the y coordinates in this trace will
#  |          reference in the figure. 'y' references layout['yaxis'] and 'y2'
#  |          references layout['yaxis2']. 'y1' will always refer to
#  |          layout['yaxis'] or layout['yaxis1'], they are the same.
#  |
#  |      error_y [required=False] (value=ErrorY object | dictionary-like):
#  |          A dictionary-like object describing vertical error bars that can be
#  |          drawn with this trace's (x, y) points.
#  |
#  |          For more, run `help(plotly.graph_objs.ErrorY)`
#  |
#  |      error_x [required=False] (value=ErrorX object | dictionary-like):
#  |          A dictionary-like object describing horizontal error bars that can
#  |          be drawn with this trace's (x, y) points.
#  |
#  |          For more, run `help(plotly.graph_objs.ErrorX)`
#  |
#  |      visible [required=False] (value=bool: True | False):
#  |          Toggles whether this will actually be visible in the rendered
#  |          figure.
#  |
#  |      textfont [required=False] (value=Aw, snap! Undocumented!):
#  |          A dictionary-like object describing the font style of this scatter's
#  |          text elements. This only has an effect if 'text' is an array of
#  |          strings and 'mode' is set to include 'text'.
#  |
#  |          For more, run `help(plotly.graph_objs.Font)`
#  |
#  |      r [required=Aw, snap! Undocumented!] (value=Aw, snap! Undocumented!):
#  |          Aw, snap! Undocumented!
#  |
#  |      t [required=Aw, snap! Undocumented!] (value=Aw, snap! Undocumented!):
#  |          Aw, snap! Undocumented!
#  |
#  |      type [required=False] (value='scatter'):
#  |          Plotly identifier for this data's trace type. This defines how this
#  |          data dictionary will be handled. For example, 'scatter' type expects
#  |          x and y data-arrays corresponding to (x, y) coordinates wheras a
#  |          'histogram' only requires a single x or y array and a 'heatmap' type
#  |          requires a z matrix.
#  |
#  |  Method resolution order:
#  |      Scatter
#  |      PlotlyTrace
#  |      PlotlyDict
#  |      __builtin__.dict
#  |      __builtin__.object
#  |
#  |  Methods inherited from PlotlyTrace:
#  |
#  |  __init__(self, *args, **kwargs)
#  |
#  |  to_string(self, level=0, indent=4, eol='\n', pretty=True, max_chars=80)
#  |      Returns a formatted string showing graph_obj constructors.
#  |
#  |              Example:
#  |
#  |                  print obj.to_string()
#  |
#  |              Keyword arguments:
#  |              level (default = 0) -- set number of indentations to start with
#  |              indent (default = 4) -- set indentation amount
#  |              eol (default = '
#  |      ') -- set end of line character(s)
#  |              pretty (default = True) -- curtail long list output with a '...'
#  |              max_chars (default = 80) -- set max characters per line
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from PlotlyDict:
#  |
#  |  force_clean(self, caller=True)
#  |      Attempts to convert to graph_objs and call force_clean() on values.
#  |
#  |      Calling force_clean() on a PlotlyDict will ensure that the object is
#  |      valid and may be sent to plotly. This process will also remove any
#  |      entries that end up with a length == 0.
#  |
#  |      Careful! This will delete any invalid entries *silently*.
#  |
#  |  get_data(self)
#  |      Returns the JSON for the plot with non-data elements stripped.
#  |
#  |  get_ordered(self, caller=True)
#  |
#  |  strip_style(self)
#  |      Strip style from the current representation.
#  |
#  |      All PlotlyDicts and PlotlyLists are guaranteed to survive the
#  |      stripping process, though they made be left empty. This is allowable.
#  |
#  |      Keys that will be stripped in this process are tagged with
#  |      `'type': 'style'` in the INFO dictionary listed in graph_objs_meta.py.
#  |
#  |      This process first attempts to convert nested collections from dicts
#  |      or lists to subclasses of PlotlyList/PlotlyDict. This process forces
#  |      a validation, which may throw exceptions.
#  |
#  |      Then, each of these objects call `strip_style` on themselves and so
#  |      on, recursively until the entire structure has been validated and
#  |      stripped.
#  |
#  |  to_graph_objs(self, caller=True)
#  |      Walk obj, convert dicts and lists to plotly graph objs.
#  |
#  |      For each key in the object, if it corresponds to a special key that
#  |      should be associated with a graph object, the ordinary dict or list
#  |      will be reinitialized as a special PlotlyDict or PlotlyList of the
#  |      appropriate `kind`.
#  |
#  |  update(self, dict1=None, **dict2)
#  |      Update current dict with dict1 and then dict2.
#  |
#  |      This recursively updates the structure of the original dictionary-like
#  |      object with the new entries in the second and third objects. This
#  |      allows users to update with large, nested structures.
#  |
#  |      Note, because the dict2 packs up all the keyword arguments, you can
#  |      specify the changes as a list of keyword agruments.
#  |
#  |      Examples:
#  |      # update with dict
#  |      obj = Layout(title='my title', xaxis=XAxis(range=[0,1], domain=[0,1]))
#  |      update_dict = dict(title='new title', xaxis=dict(domain=[0,.8]))
#  |      obj.update(update_dict)
#  |      obj
#  |      {'title': 'new title', 'xaxis': {'range': [0,1], 'domain': [0,.8]}}
#  |
#  |      # update with list of keyword arguments
#  |      obj = Layout(title='my title', xaxis=XAxis(range=[0,1], domain=[0,1]))
#  |      obj.update(title='new title', xaxis=dict(domain=[0,.8]))
#  |      obj
#  |      {'title': 'new title', 'xaxis': {'range': [0,1], 'domain': [0,.8]}}
#  |
#  |      This 'fully' supports duck-typing in that the call signature is
#  |      identical, however this differs slightly from the normal update
#  |      method provided by Python's dictionaries.
#  |
#  |  validate(self, caller=True)
#  |      Recursively check the validity of the keys in a PlotlyDict.
#  |
#  |      The valid keys constitute the entries in each object
#  |      dictionary in INFO stored in graph_objs_meta.py.
#  |
#  |      The validation process first requires that all nested collections be
#  |      converted to the appropriate subclass of PlotlyDict/PlotlyList. Then,
#  |      each of these objects call `validate` and so on, recursively,
#  |      until the entire object has been validated.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from PlotlyDict:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes inherited from PlotlyDict:
#  |
#  |  __metaclass__ = <class 'plotly.graph_objs.graph_objs.DictMeta'>
#  |      A meta class for PlotlyDict class creation.
#  |
#  |      The sole purpose of this meta class is to properly create the __doc__
#  |      attribute so that running help(Obj), where Obj is a subclass of PlotlyDict,
#  |      will return information about key-value pairs for that object.
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from __builtin__.dict:
#  |
#  |  __cmp__(...)
#  |      x.__cmp__(y) <==> cmp(x,y)
#  |
#  |  __contains__(...)
#  |      D.__contains__(k) -> True if D has a key k, else False
#  |
#  |  __delitem__(...)
#  |      x.__delitem__(y) <==> del x[y]
#  |
#  |  __eq__(...)
#  |      x.__eq__(y) <==> x==y
#  |
#  |  __ge__(...)
#  |      x.__ge__(y) <==> x>=y
#  |
#  |  __getattribute__(...)
#  |      x.__getattribute__('name') <==> x.name
#  |
#  |  __getitem__(...)
#  |      x.__getitem__(y) <==> x[y]
#  |
#  |  __gt__(...)
#  |      x.__gt__(y) <==> x>y
#  |
#  |  __iter__(...)
#  |      x.__iter__() <==> iter(x)
#  |
#  |  __le__(...)
#  |      x.__le__(y) <==> x<=y
#  |
#  |  __len__(...)
#  |      x.__len__() <==> len(x)
#  |
#  |  __lt__(...)
#  |      x.__lt__(y) <==> x<y
#  |
#  |  __ne__(...)
#  |      x.__ne__(y) <==> x!=y
#  |
#  |  __repr__(...)
#  |      x.__repr__() <==> repr(x)
#  |
#  |  __setitem__(...)
#  |      x.__setitem__(i, y) <==> x[i]=y
#  |
#  |  __sizeof__(...)
#  |      D.__sizeof__() -> size of D in memory, in bytes
#  |
#  |  clear(...)
#  |      D.clear() -> None.  Remove all items from D.
#  |
#  |  copy(...)
#  |      D.copy() -> a shallow copy of D
#  |
#  |  fromkeys(...)
#  |      dict.fromkeys(S[,v]) -> New dict with keys from S and values equal to v.
#  |      v defaults to None.
#  |
#  |  get(...)
#  |      D.get(k[,d]) -> D[k] if k in D, else d.  d defaults to None.
#  |
#  |  has_key(...)
#  |      D.has_key(k) -> True if D has a key k, else False
#  |
#  |  items(...)
#  |      D.items() -> list of D's (key, value) pairs, as 2-tuples
#  |
#  |  iteritems(...)
#  |      D.iteritems() -> an iterator over the (key, value) items of D
#  |
#  |  iterkeys(...)
#  |      D.iterkeys() -> an iterator over the keys of D
#  |
#  |  itervalues(...)
#  |      D.itervalues() -> an iterator over the values of D
#  |
#  |  keys(...)
#  |      D.keys() -> list of D's keys
#  |
#  |  pop(...)
#  |      D.pop(k[,d]) -> v, remove specified key and return the corresponding value.
#  |      If key is not found, d is returned if given, otherwise KeyError is raised
#  |
#  |  popitem(...)
#  |      D.popitem() -> (k, v), remove and return some (key, value) pair as a
#  |      2-tuple; but raise KeyError if D is empty.
#  |
#  |  setdefault(...)
#  |      D.setdefault(k[,d]) -> D.get(k,d), also set D[k]=d if k not in D
#  |
#  |  values(...)
#  |      D.values() -> list of D's values
#  |
#  |  viewitems(...)
#  |      D.viewitems() -> a set-like object providing a view on D's items
#  |
#  |  viewkeys(...)
#  |      D.viewkeys() -> a set-like object providing a view on D's keys
#  |
#  |  viewvalues(...)
#  |      D.viewvalues() -> an object providing a view on D's values
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes inherited from __builtin__.dict:
#  |
#  |  __hash__ = None
#  |
#  |  __new__ = <built-in method __new__ of type object>
#  |      T.__new__(S, ...) -> a new object with type S, a subtype of T

# %% [markdown]
# Consider the following code:

# %%
# Make three lists of numbers
my_x0 = [1,2,3,5,6]
my_y0 = [1,4.5,7,24,38]
my_y1 = [1,4,9,25,36]

# (1.1) Define a 1st Scatter object
my_scatter1 = Scatter(x=my_x0,         # x-coordinates of trace
                      y=my_y0,         # y-coordinates of trace
                      mode='markers'   # scatter mode
                     )

# (1.2) Define a 2nd Scatter object
my_scatter2 = Scatter(x=my_x0,         # same x-coordinates
                      y=my_y1,         # different y-coordinates
                      mode='lines'     # different scatter mode
                     ) 

# (2) Make Data object (N.B. Data is list-like, must use [])
my_data = Data([my_scatter1,my_scatter2])

# (3) Make Layout object (Layout is dict-like)
my_layout = Layout(title='Fig 0.3: Some Experiment')

# (4) Make Figure object (Figure is dict-like)
my_fig = Figure(data=my_data, layout=my_layout) 

# Print the figure object in notebook
my_fig
# Out:
# {'data': [{'mode': 'markers',
#    'type': 'scatter',
#    'x': [1, 2, 3, 5, 6],
#    'y': [1, 4.5, 7, 24, 38]},
#   {'mode': 'lines',
#    'type': 'scatter',
#    'x': [1, 2, 3, 5, 6],
#    'y': [1, 4, 9, 25, 36]}],
#  'layout': {'title': 'Fig 0.3: Some Experiment'}}

# %% [markdown]
# Figure objects store data just like a Python dictionary. For instance, the `'layout'` has for value a dictionary and the `'data'` key has for value a list of dictionaries. These dictionaries store data and style options of each trace to be plotted.
#
# All Plotly graph objects are equipped with the `.to_string()` *graph object method* which yields a human-friendly string representation of any graph object. For example,

# %%
# Print figure object in human-friendly form
print my_fig.to_string()
# Out:
# Figure(
#     data=Data([
#         Scatter(
#             x=[1, 2, 3, 5, 6],
#             y=[1, 4.5, 7, 24, 38],
#             mode='markers'
#         ),
#         Scatter(
#             x=[1, 2, 3, 5, 6],
#             y=[1, 4, 9, 25, 36],
#             mode='lines'
#         )
#     ]),
#     layout=Layout(
#         title='Fig 0.3: Some Experiment'
#     )
# )

# %% [markdown]
# Using `.to_string()`, we can conveniently identify individual graph objects that make up the figure object. Nice.

# %% [markdown]
# Now, we send the figure object to Plotly, give our Plotly plot a file name and get it in return directly in this IPython notebook:

# %%
# (5) Send Figure object to Plotly and show plot in notebook
py.iplot(my_fig, filename='s0_second-plot')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~etpinard/163" height="525" width="100%"></iframe>

# %% [markdown]
# Not bad.
#
# But your high school science teacher would not entirely be proud of you, the axes are not labelled.
#
# To do so, we again turn to Plotly graph objects. For the task at hand, the relevant graph objects are `XAxis` and `YAxis`:

# %%
# (*) Import graph objects XAxis and YAxis
from plotly.graph_objs import XAxis, YAxis

# Again run help(), for fun!
help(XAxis)
# Out:
# Help on class XAxis in module plotly.graph_objs.graph_objs:
#
# class XAxis(PlotlyDict)
#  |  A dictionary-like object representing an xaxis in plotly.
#  |
#  |
#  |  Quick method reference:
#  |
#  |      XAxis.update(changes)
#  |      XAxis.strip_style()
#  |      XAxis.get_data()
#  |      XAxis.to_graph_objs()
#  |      XAxis.validate()
#  |      XAxis.to_string()
#  |      XAxis.force_clean()
#  |
#  |  Valid keys:
#  |
#  |      title [required=False] (value=string):
#  |          The xaxis title.
#  |
#  |      domain [required=False] (value=number array of length 2):
#  |          Sets the domain of this axis. The available space for this axis to
#  |          live in is from 0 to 1.
#  |
#  |          Examples:
#  |              [[0, 1], [0, 0.5]]
#  |
#  |      range [required=False] (value=number array of length 2):
#  |          Defines the start and end point for the axis.
#  |
#  |          Examples:
#  |              [[-13, 20], [0, 1]]
#  |
#  |      type [required=False] (value=string: linear | log | category):
#  |          Defines format of the axis.
#  |
#  |      showline [required=False] (value=bool: True | False):
#  |          Defines whether or not to show this axis line.
#  |
#  |      linecolor [required=False] (value=str describing color):
#  |          Defines the axis line color.
#  |
#  |          Examples:
#  |              ["'green'", "'rgb(0, 255, 0)'", "'rgba(0, 255, 0, 0.3)'",
#  |              "'hsl(120,100%,50%)'", "'hsla(120,100%,50%,0.3)'"]
#  |
#  |      linewidth [required=False] (value=number):
#  |          Sets the width of the axis line.
#  |
#  |      tick0 [required=False] (value=number):
#  |          Sets the starting point of the axis.
#  |
#  |      dtick [required=False] (value=Aw, snap! Undocumented!):
#  |          Sets the difference between ticks on this axis.
#  |
#  |      ticks [required=Aw, snap! Undocumented!] (value=string: 'inside' |
#  |      'outside' | '' (Empty str for NONE)):
#  |          Sets format of tick visibility.
#  |
#  |      ticklen [required=False] (value=number):
#  |          Sets the length of the tick lines.
#  |
#  |      tickcolor [required=False] (value=str describing color):
#  |          Sets the color of the tick lines.
#  |
#  |      tickwidth [required=False] (value=number: x > 0):
#  |          Sets the width of the tick lines.
#  |
#  |      nticks [required=False] (value=number: x >= 0):
#  |          Sets the number of ticks to appear on the axis.
#  |
#  |      showticklabels [required=False] (value=bool: True | False):
#  |          Show/Hide the axis tick labels.
#  |
#  |      tickangle [required=False] (value=number: x in [-90, 90]):
#  |          Sets the angle of the ticks in degrees.
#  |
#  |      exponentformat [required=False] (value='none' | 'e' | 'E' | 'power' |
#  |      'SI' | 'B'):
#  |          Sets how exponents show up. Here's how the number 1000000000 (1
#  |          billion) shows up in each. If set to 'none': 1,000,000,000. If set
#  |          to 'e': 1e+9. If set to 'E': 1E+9. If set to 'power': 1x10^9 (where
#  |          the 9 will appear super-scripted. If set to 'SI': 1G. If set to 'B':
#  |          1B (useful when referring to currency.
#  |
#  |      showexponent [required=False] (value='all' | 'first' | 'last' | 'none'):
#  |          If set to 'all', ALL exponents will be shown appended to their
#  |          significands. If set to 'first', the first tick's exponent will be
#  |          appended to its significand, however no other exponents will appear
#  |          --only the significands. If set to 'last', the last tick's exponent
#  |          will be appended to its significand, however no other exponents will
#  |          appear--only the significands. If set to 'none', NO exponents will
#  |          appear, only the significands.
#  |
#  |      showgrid [required=False] (value=bool: True | False):
#  |          Show/Hide grid for the axis.
#  |
#  |      gridcolor [required=False] (value=str describing color):
#  |          Sets the axis grid color. Any HTML specified color is accepted.
#  |
#  |          Examples:
#  |              ["'green'", "'rgb(0, 255, 0)'", "'rgba(0, 255, 0, 0.3)'",
#  |              "'hsl(120,100%,50%)'", "'hsla(120,100%,50%,0.3)'"]
#  |
#  |      gridwidth [required=Aw, snap! Undocumented!] (value=number: x > 0):
#  |          Sets the grid width.
#  |
#  |      autorange [required=False] (value=bool: True | False):
#  |          Toggle whether to let plotly autorange the axis.
#  |
#  |      rangemode [required=False] (value=string: 'normal' | 'tozero' |
#  |      'nonnegative'):
#  |          Aw, snap! Undocumented!
#  |
#  |      autotick [required=False] (value=bool: True | False):
#  |          Toggle axis autoticks.
#  |
#  |      zeroline [required=False] (value=bool: True | False):
#  |          Show/Hide an additional zeroline for this axis.
#  |
#  |      zerolinecolor [required=False] (value=str describing color):
#  |          Set the color of this axis' zeroline.
#  |
#  |          Examples:
#  |              ["'green'", "'rgb(0, 255, 0)'", "'rgba(0, 255, 0, 0.3)'",
#  |              "'hsl(120,100%,50%)'", "'hsla(120,100%,50%,0.3)'"]
#  |
#  |      zerolinewidth [required=False] (value=number: x > 0):
#  |          Sets the width of this axis' zeroline.
#  |
#  |      titlefont [required=False] (value=Font object | dictionary-like):
#  |          A dictionary for configuring the axis title font.
#  |
#  |          For more, run `help(plotly.graph_objs.Font)`
#  |
#  |      tickfont [required=False] (value=Font object | dictionary-like):
#  |          A dictionary for configuring the tick font.
#  |
#  |          For more, run `help(plotly.graph_objs.Font)`
#  |
#  |      overlaying [required=Aw, snap! Undocumented!] (value=Aw, snap!
#  |      Undocumented!):
#  |          Aw, snap! Undocumented!
#  |
#  |      position [required=False] (value=number: x in [0, 1]):
#  |          Sets where the axis is positioned in the plotting space. For example
#  |          'position'=0.5 will place this axis in the exact center of the
#  |          plotting space. This only has functionality if 'anchor'='free'.
#  |
#  |      anchor [required=False] (value='y' | 'free'):
#  |          Sets whether the xaxis will be anchored to its corresponding yaxis
#  |          OR 'free' to appear anywhere in the vertical space of the plot.
#  |
#  |      side [required=False] (value='bottom' | 'top'):
#  |          Set whether this axis sits at the 'bottom' of the plot or at the
#  |          'top' of the plot.
#  |
#  |      mirror [required=False] (value=bool: True | False):
#  |          Toggle whether to mirror the axis line to the opposite side of the
#  |          plot.
#  |
#  |  Method resolution order:
#  |      XAxis
#  |      PlotlyDict
#  |      __builtin__.dict
#  |      __builtin__.object
#  |
#  |  Methods inherited from PlotlyDict:
#  |
#  |  __init__(self, *args, **kwargs)
#  |
#  |  force_clean(self, caller=True)
#  |      Attempts to convert to graph_objs and call force_clean() on values.
#  |
#  |      Calling force_clean() on a PlotlyDict will ensure that the object is
#  |      valid and may be sent to plotly. This process will also remove any
#  |      entries that end up with a length == 0.
#  |
#  |      Careful! This will delete any invalid entries *silently*.
#  |
#  |  get_data(self)
#  |      Returns the JSON for the plot with non-data elements stripped.
#  |
#  |  get_ordered(self, caller=True)
#  |
#  |  strip_style(self)
#  |      Strip style from the current representation.
#  |
#  |      All PlotlyDicts and PlotlyLists are guaranteed to survive the
#  |      stripping process, though they made be left empty. This is allowable.
#  |
#  |      Keys that will be stripped in this process are tagged with
#  |      `'type': 'style'` in the INFO dictionary listed in graph_objs_meta.py.
#  |
#  |      This process first attempts to convert nested collections from dicts
#  |      or lists to subclasses of PlotlyList/PlotlyDict. This process forces
#  |      a validation, which may throw exceptions.
#  |
#  |      Then, each of these objects call `strip_style` on themselves and so
#  |      on, recursively until the entire structure has been validated and
#  |      stripped.
#  |
#  |  to_graph_objs(self, caller=True)
#  |      Walk obj, convert dicts and lists to plotly graph objs.
#  |
#  |      For each key in the object, if it corresponds to a special key that
#  |      should be associated with a graph object, the ordinary dict or list
#  |      will be reinitialized as a special PlotlyDict or PlotlyList of the
#  |      appropriate `kind`.
#  |
#  |  to_string(self, level=0, indent=4, eol='\n', pretty=True, max_chars=80)
#  |      Returns a formatted string showing graph_obj constructors.
#  |
#  |              Example:
#  |
#  |                  print obj.to_string()
#  |
#  |              Keyword arguments:
#  |              level (default = 0) -- set number of indentations to start with
#  |              indent (default = 4) -- set indentation amount
#  |              eol (default = '
#  |      ') -- set end of line character(s)
#  |              pretty (default = True) -- curtail long list output with a '...'
#  |              max_chars (default = 80) -- set max characters per line
#  |
#  |  update(self, dict1=None, **dict2)
#  |      Update current dict with dict1 and then dict2.
#  |
#  |      This recursively updates the structure of the original dictionary-like
#  |      object with the new entries in the second and third objects. This
#  |      allows users to update with large, nested structures.
#  |
#  |      Note, because the dict2 packs up all the keyword arguments, you can
#  |      specify the changes as a list of keyword agruments.
#  |
#  |      Examples:
#  |      # update with dict
#  |      obj = Layout(title='my title', xaxis=XAxis(range=[0,1], domain=[0,1]))
#  |      update_dict = dict(title='new title', xaxis=dict(domain=[0,.8]))
#  |      obj.update(update_dict)
#  |      obj
#  |      {'title': 'new title', 'xaxis': {'range': [0,1], 'domain': [0,.8]}}
#  |
#  |      # update with list of keyword arguments
#  |      obj = Layout(title='my title', xaxis=XAxis(range=[0,1], domain=[0,1]))
#  |      obj.update(title='new title', xaxis=dict(domain=[0,.8]))
#  |      obj
#  |      {'title': 'new title', 'xaxis': {'range': [0,1], 'domain': [0,.8]}}
#  |
#  |      This 'fully' supports duck-typing in that the call signature is
#  |      identical, however this differs slightly from the normal update
#  |      method provided by Python's dictionaries.
#  |
#  |  validate(self, caller=True)
#  |      Recursively check the validity of the keys in a PlotlyDict.
#  |
#  |      The valid keys constitute the entries in each object
#  |      dictionary in INFO stored in graph_objs_meta.py.
#  |
#  |      The validation process first requires that all nested collections be
#  |      converted to the appropriate subclass of PlotlyDict/PlotlyList. Then,
#  |      each of these objects call `validate` and so on, recursively,
#  |      until the entire object has been validated.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from PlotlyDict:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes inherited from PlotlyDict:
#  |
#  |  __metaclass__ = <class 'plotly.graph_objs.graph_objs.DictMeta'>
#  |      A meta class for PlotlyDict class creation.
#  |
#  |      The sole purpose of this meta class is to properly create the __doc__
#  |      attribute so that running help(Obj), where Obj is a subclass of PlotlyDict,
#  |      will return information about key-value pairs for that object.
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from __builtin__.dict:
#  |
#  |  __cmp__(...)
#  |      x.__cmp__(y) <==> cmp(x,y)
#  |
#  |  __contains__(...)
#  |      D.__contains__(k) -> True if D has a key k, else False
#  |
#  |  __delitem__(...)
#  |      x.__delitem__(y) <==> del x[y]
#  |
#  |  __eq__(...)
#  |      x.__eq__(y) <==> x==y
#  |
#  |  __ge__(...)
#  |      x.__ge__(y) <==> x>=y
#  |
#  |  __getattribute__(...)
#  |      x.__getattribute__('name') <==> x.name
#  |
#  |  __getitem__(...)
#  |      x.__getitem__(y) <==> x[y]
#  |
#  |  __gt__(...)
#  |      x.__gt__(y) <==> x>y
#  |
#  |  __iter__(...)
#  |      x.__iter__() <==> iter(x)
#  |
#  |  __le__(...)
#  |      x.__le__(y) <==> x<=y
#  |
#  |  __len__(...)
#  |      x.__len__() <==> len(x)
#  |
#  |  __lt__(...)
#  |      x.__lt__(y) <==> x<y
#  |
#  |  __ne__(...)
#  |      x.__ne__(y) <==> x!=y
#  |
#  |  __repr__(...)
#  |      x.__repr__() <==> repr(x)
#  |
#  |  __setitem__(...)
#  |      x.__setitem__(i, y) <==> x[i]=y
#  |
#  |  __sizeof__(...)
#  |      D.__sizeof__() -> size of D in memory, in bytes
#  |
#  |  clear(...)
#  |      D.clear() -> None.  Remove all items from D.
#  |
#  |  copy(...)
#  |      D.copy() -> a shallow copy of D
#  |
#  |  fromkeys(...)
#  |      dict.fromkeys(S[,v]) -> New dict with keys from S and values equal to v.
#  |      v defaults to None.
#  |
#  |  get(...)
#  |      D.get(k[,d]) -> D[k] if k in D, else d.  d defaults to None.
#  |
#  |  has_key(...)
#  |      D.has_key(k) -> True if D has a key k, else False
#  |
#  |  items(...)
#  |      D.items() -> list of D's (key, value) pairs, as 2-tuples
#  |
#  |  iteritems(...)
#  |      D.iteritems() -> an iterator over the (key, value) items of D
#  |
#  |  iterkeys(...)
#  |      D.iterkeys() -> an iterator over the keys of D
#  |
#  |  itervalues(...)
#  |      D.itervalues() -> an iterator over the values of D
#  |
#  |  keys(...)
#  |      D.keys() -> list of D's keys
#  |
#  |  pop(...)
#  |      D.pop(k[,d]) -> v, remove specified key and return the corresponding value.
#  |      If key is not found, d is returned if given, otherwise KeyError is raised
#  |
#  |  popitem(...)
#  |      D.popitem() -> (k, v), remove and return some (key, value) pair as a
#  |      2-tuple; but raise KeyError if D is empty.
#  |
#  |  setdefault(...)
#  |      D.setdefault(k[,d]) -> D.get(k,d), also set D[k]=d if k not in D
#  |
#  |  values(...)
#  |      D.values() -> list of D's values
#  |
#  |  viewitems(...)
#  |      D.viewitems() -> a set-like object providing a view on D's items
#  |
#  |  viewkeys(...)
#  |      D.viewkeys() -> a set-like object providing a view on D's keys
#  |
#  |  viewvalues(...)
#  |      D.viewvalues() -> an object providing a view on D's values
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes inherited from __builtin__.dict:
#  |
#  |  __hash__ = None
#  |
#  |  __new__ = <built-in method __new__ of type object>
#  |      T.__new__(S, ...) -> a new object with type S, a subtype of T

# %%
# (6.1) Make XAxis object, add title key
my_xaxis = XAxis(title='Some independent variable')

# (6.2) Make YAxis object, add title key
my_yaxis = YAxis(title='Some dependent variable')

# (7) Update 'layout' key in the Figure object, print result to stdout
my_fig['layout'].update(dict(xaxis1=my_xaxis,
                             yaxis1=my_yaxis
                           ))

# Convert figure object to string, print to stdout
print my_fig.to_string()
# Out:
# Figure(
#     data=Data([
#         Scatter(
#             x=[1, 2, 3, 5, 6],
#             y=[1, 4.5, 7, 24, 38],
#             mode='markers'
#         ),
#         Scatter(
#             x=[1, 2, 3, 5, 6],
#             y=[1, 4, 9, 25, 36],
#             mode='lines'
#         )
#     ]),
#     layout=Layout(
#         title='Fig 0.3: Some Experiment',
#         xaxis1=XAxis(
#             title='Some independent variable'
#         ),
#         yaxis1=YAxis(
#             title='Some dependent variable'
#         )
#     )
# )

# %% [markdown]
# Graph objects can be *updated* using the `update()` method (similar to the `update()` method for Python dictionaries), meaning that adding or updating features to a Plotly plot does not require whole redefinitions (more in [subsection 0.5](#0.5-Graph-object-methods)).
#
# A call to Plotly gets us:

# %%
# (*) Send Figure object to Plotly and show plot in notebook
py.iplot(my_fig, filename='s0_second-plot-axis-titles')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~etpinard/164" height="525" width="100%"></iframe>

# %% [markdown]
# Great!
#
# Adding or customizing other features such as the legend or annotations is just as easy.
# All Plotly objects are associated with an intuitively-named class (using the CamelCase conventions). Moreover, extensive documentation makes running `help()`, helpful.
#
# We encourge graph objects imports using the
#
# `>>> from plotly.graph_objs import GraphObj1, GraphObj2, ...`
#
# form for cleaner looking scripts. Although, something like
#
# `>>> import plotly.graph_objs as go`
#
# works too. Alternatively, if you don't care about namespaces and just want to make cool graphs, one can import all graph objects at once with the
#
# `>>>  from plotly.graph_objs import * `
#
# form which *should not* come in conflict with other Python libraries.
#
# If you would like a complete list of the graph objects available in the current version of the Plolty package, run:

# %%
from plotly.graph_objs import __all__

__all__  # print list of available graph objects
# Out:
# ['Data',
#  'Annotations',
#  'Bar',
#  'Box',
#  'Contour',
#  'Heatmap',
#  'Histogram',
#  'Histogram2d',
#  'Histogram2dContour',
#  'Scatter',
#  'Annotation',
#  'AngularAxis',
#  'ColorBar',
#  'Contours',
#  'ErrorX',
#  'ErrorY',
#  'Figure',
#  'Font',
#  'Layout',
#  'Legend',
#  'Line',
#  'Margin',
#  'Marker',
#  'RadialAxis',
#  'Stream',
#  'Trace',
#  'XAxis',
#  'XBins',
#  'YAxis',
#  'YBins']

# %% [markdown]
# ### 0.5 Graph object methods

# %% [markdown]
# OK. Now that you know what graph objects are, you might be saying:
#
# > Wait! I've been using Python dictionaries and lists to setup Plotly plots in version 0.5.* of the API without these new graph objects, Why should I change my ways?
#
# Well, along with the graph objects' extensive documentation and their `.to_string()` method that we saw in the previous subsection, graph objects support:
#
# * Key validation
# * Nested dictionary updates
#
# on top of Python dictionary and list features.

# %% [markdown]
# <h5>Key validation</h5>

# %% [markdown]
# Consider the following example, where we import a particular graph object and add a key-value pair to an instance:

# %%
from plotly.graph_objs import Heatmap  # import Heatmap graph object

my_heatmap = Heatmap()              # init. a Heatmap object instance
my_heatmap['text'] = ['a','b','c']  # add 'text' key to it
my_heatmap.validate()               # check if valid!
# Out:
# ---------------------------------------------------------------------------
# PlotlyDictKeyError                        Traceback (most recent call last)
# <ipython-input-20-d210cdaa771b> in <module>()
#       3 my_heatmap = Heatmap()              # init. a Heatmap object instance
#       4 my_heatmap['text'] = ['a','b','c']  # add 'text' key to it
# ----> 5 my_heatmap.validate()               # check if valid!
#
# /usr/local/lib/python2.7/dist-packages/plotly/graph_objs/graph_objs.pyc in validate(self, caller)
#     719                     raise exceptions.PlotlyDictKeyError(obj=self,
#     720                                                         key=key,
# --> 721                                                         notes=notes)
#     722
#     723     def to_string(self, level=0, indent=4, eol='\n', pretty=True, max_chars=80):
#
# PlotlyDictKeyError: Invalid key, 'text', for class, 'Heatmap'.
#
# Run 'help(plotly.graph_objs.Heatmap)' for more information.
#
# Path To Error:
# ['text']
#
# Additional Notes:
# That key is valid only in these objects:
#
# 	Trace('text'="..")
# 	Scatter('text'="array-like of strings")
# 	Area('text'="..")
# 	Bar('text'="array-like of strings")
# 	Annotation('text'="string")

# %% [markdown]
# Hmm, we got an error. Plotly does not let us use the `'text'` key in `Heatmap`.
#
# But, using the `validate()` graph object method, Plotly lets you know about it and Plotly is nice enough to give you suggestions about invalid keys! In this case, the `'text'` key is valid in the `Trace`, `Scatter`, `Area`, `Bar` and `Annotation` objects.
#
# > The `validate()` method allows users to validate graph object keys within an Python/IPython session without having to resort to documentation.
#
# And now as of version 1.0.8 of Plotly's Python API, `plot()` and `iplot()` run `validate()` locally before sending your figure object to Plotly for plotting. Try running
#
#     >>> py.plot([my_heatmap], filename='s0_wont-work')
#
# You will get the same error message as the above. If you would like to disable this feautre set `validate=False` in the `plot()` or `iplot()` call.

# %% [markdown]
# <h5>Nested dictionary update</h5>

# %% [markdown]
# Python dictionary objects carry an update method that does not nest, but rather swaps out value-for-value. In contrast, Plotly graph objects fully support nested updating.
#
# Moreover, Python standard list objects do NOT define an update method. Plotly list-like graph objects (e.g. `Data`) include one.
#
# Here are some quick examples of how these feature can improve your workflow:

# %%
# Define 2 (standard) dictionaries with one key in common that links to 
#  different nested dictionaries
my_dict1 = dict(type='scatter', x='x', y='y', 
                marker=dict(color='blue', symbol='plus'))
my_dict2 = dict(marker=dict(color='red'))

# Update and print in notebook
my_dict1.update(my_dict2)
my_dict1
# Out:
# {'marker': {'color': 'red'}, 'type': 'scatter', 'x': 'x', 'y': 'y'}

# %% [markdown]
# Snap! The `'symbol'` is gone.
#
# Say we want to update `my_dict1`'s marker color but leave its marker symbol alone. What is the most efficient way to proceed? Well, simply use a Plotly graph object instead:

# %%
# Define a Scatter object and a (standard) dictionary
my_go1 = Scatter(type='scatter', x='x', y='y', 
                 marker=dict(color='blue', symbol='plus'))
my_dict2 = dict(marker=dict(color='red'))  # same as previous code cell

# Update Scatter object and print in notebook
my_go1.update(my_dict2)
my_go1
# Out:
# {'marker': {'color': 'red', 'symbol': 'plus'},
#  'type': 'scatter',
#  'x': 'x',
#  'y': 'y'}

# %% [markdown]
# Nice!
#
# Note that the argument for the `update()` graph object method doesn't need to be a graph object, `update()` accepts Python dictionaries as well.
#
# Plotly graph object also helps users manipulate list-like graph objects, such as `Data`.
#
# To show this, let's start with a plot of random numbers:

# %%
import numpy as np   # import numpy  

# Make Data object, 
#   made up 20 Scatter objects plotting 50 norm. dist. random pts
my_data = Data([Scatter(x=range(50), 
                        y=np.random.randn(50)) for i in range(20)])

my_fig = Figure()         # init. Figure object 
my_fig['data'] = my_data  # add data
my_fig['layout'] = Layout(showlegend=False)  # remove legend from plot

# Send Figure object to Plotly and show plot in notebook
py.iplot(my_fig, filename='s0_line-scatter')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~etpinard/205" height="525" width="100%"></iframe>

# %% [markdown]
# Numpy users should note: Plotly accepts 1-dimensional Numpy arrays as list arguments as well. No need to convert them!
#
# Now, say we would like to change the line style for all of the 20 traces represented by `Scatter` objects. Scatter line style are set via the `'line'` key in the `Scatter` graph object and keys  (e.g. `'color'`, `'width'`, `opacity'`) in the `Line` graph object.
#
# So, first import the `Line` graph object:

# %%
# (*) Import the Line object
from plotly.graph_objs import Line

# %% [markdown]
# Now, we need to update each trace (or element)  of the `'data'` key our figure object. If we used Python standard lists and dictionaries, this task would be quite of a hassle. Luckily, the  `update()` graph object method applies style changes to all traces by default. Consider:

# %%
# Make a dictionary linking the 'line' key to a Line object
my_style = dict(line=Line(color='blue', width=0.3, opacity=0.7))

# Update the figure object with update()
my_fig['data'].update(my_style)
            
# Print values linked to the 'line' key of each trace in notebook
[my_fig['data'][i]['line'] for i in range(20)]
# Out:
# [{'color': 'blue', 'opacity': 0.7, 'width': 0.3},
#  {'color': 'blue', 'opacity': 0.7, 'width': 0.3},
#  {'color': 'blue', 'opacity': 0.7, 'width': 0.3},
#  {'color': 'blue', 'opacity': 0.7, 'width': 0.3},
#  {'color': 'blue', 'opacity': 0.7, 'width': 0.3},
#  {'color': 'blue', 'opacity': 0.7, 'width': 0.3},
#  {'color': 'blue', 'opacity': 0.7, 'width': 0.3},
#  {'color': 'blue', 'opacity': 0.7, 'width': 0.3},
#  {'color': 'blue', 'opacity': 0.7, 'width': 0.3},
#  {'color': 'blue', 'opacity': 0.7, 'width': 0.3},
#  {'color': 'blue', 'opacity': 0.7, 'width': 0.3},
#  {'color': 'blue', 'opacity': 0.7, 'width': 0.3},
#  {'color': 'blue', 'opacity': 0.7, 'width': 0.3},
#  {'color': 'blue', 'opacity': 0.7, 'width': 0.3},
#  {'color': 'blue', 'opacity': 0.7, 'width': 0.3},
#  {'color': 'blue', 'opacity': 0.7, 'width': 0.3},
#  {'color': 'blue', 'opacity': 0.7, 'width': 0.3},
#  {'color': 'blue', 'opacity': 0.7, 'width': 0.3},
#  {'color': 'blue', 'opacity': 0.7, 'width': 0.3},
#  {'color': 'blue', 'opacity': 0.7, 'width': 0.3}]

# %%
# Send Figure object to Plotly and show plot in notebook
py.iplot(my_fig, filename='s0_blue-line-scatter')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~etpinard/206" height="525" width="100%"></iframe>

# %% [markdown]
# Each trace now has a new line style!
#
# The `update()` method for Plotly's list-like objects repeatedly iterates over the given list (e.g. of traces in the above example) until each entry in the original list has received an update.
#
# To update a single one of the original list entries, specify the trace number when calling `update()`. For example:

# %%
# Make a dictionary linking the 'line' key to a Line object
my_style1 = dict(line=Line(color='red', width=1, opacity=1))

# Update trace 0 of the 'data' key in figure object
my_fig['data'][0].update(my_style1)

# Print values linked to the 'line' key of each trace in notebook
[my_fig['data'][i]['line'] for i in range(20)]
# Out:
# [{'color': 'red', 'opacity': 1, 'width': 1},
#  {'color': 'red', 'opacity': 1, 'width': 1},
#  {'color': 'red', 'opacity': 1, 'width': 1},
#  {'color': 'red', 'opacity': 1, 'width': 1},
#  {'color': 'red', 'opacity': 1, 'width': 1},
#  {'color': 'red', 'opacity': 1, 'width': 1},
#  {'color': 'red', 'opacity': 1, 'width': 1},
#  {'color': 'red', 'opacity': 1, 'width': 1},
#  {'color': 'red', 'opacity': 1, 'width': 1},
#  {'color': 'red', 'opacity': 1, 'width': 1},
#  {'color': 'red', 'opacity': 1, 'width': 1},
#  {'color': 'red', 'opacity': 1, 'width': 1},
#  {'color': 'red', 'opacity': 1, 'width': 1},
#  {'color': 'red', 'opacity': 1, 'width': 1},
#  {'color': 'red', 'opacity': 1, 'width': 1},
#  {'color': 'red', 'opacity': 1, 'width': 1},
#  {'color': 'red', 'opacity': 1, 'width': 1},
#  {'color': 'red', 'opacity': 1, 'width': 1},
#  {'color': 'red', 'opacity': 1, 'width': 1},
#  {'color': 'red', 'opacity': 1, 'width': 1}]

# %% [markdown]
# One can also send a list to `update()` graph object method where it iterates over over both receiving and send lists. If needed to fill in the receiving list, iteration over the sent list is repeated. For example:

# %%
# Make color map (using colorbrewer 'Reds')
colors = ['rgb(254,229,217)','rgb(252,174,145)','rgb(251, 106, 74)',
          'rgb(222,45,38)','rgb(165,15,21)']

# Make list of 5 dictionaries, sent update to 'data' key in figure object,
#  iteration is repeated 4 times over the trace object list
styles = [dict(line=Line(color=colors[i], width=0.5, opacity=0.7)) 
          for i in range(5)]
my_fig['data'].update(styles)

# Print values linked to the 'line' key of each trace in notebook
[my_fig['data'][i]['line'] for i in range(20)]
# Out:
# [{'color': 'rgb(165,15,21)', 'opacity': 0.7, 'width': 0.5},
#  {'color': 'rgb(165,15,21)', 'opacity': 0.7, 'width': 0.5},
#  {'color': 'rgb(165,15,21)', 'opacity': 0.7, 'width': 0.5},
#  {'color': 'rgb(165,15,21)', 'opacity': 0.7, 'width': 0.5},
#  {'color': 'rgb(165,15,21)', 'opacity': 0.7, 'width': 0.5},
#  {'color': 'rgb(165,15,21)', 'opacity': 0.7, 'width': 0.5},
#  {'color': 'rgb(165,15,21)', 'opacity': 0.7, 'width': 0.5},
#  {'color': 'rgb(165,15,21)', 'opacity': 0.7, 'width': 0.5},
#  {'color': 'rgb(165,15,21)', 'opacity': 0.7, 'width': 0.5},
#  {'color': 'rgb(165,15,21)', 'opacity': 0.7, 'width': 0.5},
#  {'color': 'rgb(165,15,21)', 'opacity': 0.7, 'width': 0.5},
#  {'color': 'rgb(165,15,21)', 'opacity': 0.7, 'width': 0.5},
#  {'color': 'rgb(165,15,21)', 'opacity': 0.7, 'width': 0.5},
#  {'color': 'rgb(165,15,21)', 'opacity': 0.7, 'width': 0.5},
#  {'color': 'rgb(165,15,21)', 'opacity': 0.7, 'width': 0.5},
#  {'color': 'rgb(165,15,21)', 'opacity': 0.7, 'width': 0.5},
#  {'color': 'rgb(165,15,21)', 'opacity': 0.7, 'width': 0.5},
#  {'color': 'rgb(165,15,21)', 'opacity': 0.7, 'width': 0.5},
#  {'color': 'rgb(165,15,21)', 'opacity': 0.7, 'width': 0.5},
#  {'color': 'rgb(165,15,21)', 'opacity': 0.7, 'width': 0.5}]

# %%
# Send Figure object to Plotly and show plot in notebook
py.iplot(my_fig, filename='s0_red-line-scatter')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~etpinard/207" height="525" width="100%"></iframe>

# %% [markdown]
# Using Plotly graph objects let you use the powerful `update()` method and makes style customization a breeze and, hopefully, this will convince you that graph objects are advantageous new tools in Plotly's Python API.

# %% [markdown]
# ### 0.6 Get figure and new possible workflows

# %% [markdown]
# Possibly the most life-changing new feature of Plotly's new Python API version is the `get_figure()` function.
#
# Plotly now allows you to pull figures down from its servers as figure objects with a single Python command. That's right you can pull down *entire* figure objects, containing every data point and every style options used to make the figure inside a Python/IPython session.
#
# > With Plotly's `get_figure()` function, reproducibility is at your finger tips.
#
# This feature puts forward exciting new workflows possibilities such as:
#
# * Grab data and style of a plot made by another Plotly user and use them to make your own plot,
# * Send data to Plotly, style your plot in the Plotly web GUI and get figure object back in the Python/IPython session.
#
# Moreover, you can now convert Plotly figure objects to (static) `.png` figures and save them on your machine with a single Python command.
#
# > With Plotly's `image.save_as()` function, your Plotly figures can now easily live both online and on your machine.

# %% [markdown]
# ##### Grab data and style

# %% [markdown]
# Say a really nice Plotly ploy on shows up on your twitter feed. For example:

# %%
# (NEW! in plotly.tools module) Embed a Plotly plot in an IPython notebook 
#  'alexhp' is the username of the plot's maker
#  '68' is the unique file id corresponding to the plot (same as in URL)
tls.embed('alexhp', '68')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~alexhp/68" height="525" width="100%"></iframe>

# %% [markdown]
# And you would like to use the data to make a different plot with the same data, a histogram of asteroid flyby distances. Well first, get the figure object from the Plotly servers using the `get_figure()` function of the `plotly.plotly` module:

# %%
# Get figure object from Plotly servers
#  'alexhp' is the username of the plot's maker
#  '68' is the unique file id corresponding to the plot (same as in URL)
asteroids = py.get_figure('alexhp', '68')

# Print figure object to stdout in human-readable form
print asteroids.to_string()
# Out:
# Figure(
#     data=Data([
#         Scatter(
#             x=[2004.7449496677464],
#             y=[242.84457898323254],
#             text=['4179 Toutatis<br>Radius: 2188 meters <br> Velocity: 11.0...],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=220.77616239495518,
#                 color='rgb(186,0,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2079.2679907394736],
#             y=[279.6571383427504],
#             text=['52768 1998 OR2<br>Radius: 1738 meters <br> Velocity: 8.1...],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=175.78008287493748,
#                 color='rgb(136,0,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2073.30556125785],
#             y=[269.23559863262216],
#             text=['164121 2003 YT1<br>Radius: 1445 meters <br> Velocity: 23...],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=146.5439770745928,
#                 color='rgb(255,151,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2076.571951553305],
#             y=[253.48302415127242],
#             text=['385343 2002 LV<br>Radius: 1202 meters <br> Velocity: 20....],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=122.22644346174121,
#                 color='rgb(255,86,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2028.8114973465322],
#             y=[145.21541820872923],
#             text=['35396 1997 XF11<br>Radius: 1047 meters <br> Velocity: 13...],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=106.71285480509003,
#                 color='rgb(236,0,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2130.0353827380136],
#             y=[251.49676396955005],
#             text=['85182 1991 AQ<br>Radius: 955 meters <br> Velocity: 24.73...],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=97.49925860214353,
#                 color='rgb(255,167,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2186.4866490275685],
#             y=[200.27765102510574],
#             text=['314082 Dryope<br>Radius: 794 meters <br> Velocity: 13.98...],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=81.43282347242815,
#                 color='rgb(236,0,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2071.8080455575323],
#             y=[208.89464192916287],
#             text=['154276 2002 SY50<br>Radius: 759 meters <br> Velocity: 21...],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=77.85775750291832,
#                 color='rgb(255,110,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2198.285350425011],
#             y=[116.63233555827603],
#             text=['290772 2005 VC<br>Radius: 724 meters <br> Velocity: 14.8...],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=74.44359600749902,
#                 color='rgb(252,0,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2027.5908014384988],
#             y=[60.77752159620918],
#             text=['137108 1999 AN10<br>Radius: 661 meters <br> Velocity: 26...],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=68.06934480075964,
#                 color='rgb(255,196,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2099.9343608868207],
#             y=[296.6604112621319],
#             text=['33342 1998 WT24<br>Radius: 661 meters <br> Velocity: 9.0...],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=68.06934480075964,
#                 color='rgb(149,0,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2001.9576737679242],
#             y=[296.99310409689184],
#             text=['33342 1998 WT24<br>Radius: 661 meters <br> Velocity: 8.8...],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=68.06934480075964,
#                 color='rgb(149,0,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2192.584793120752],
#             y=[307.4356831473995],
#             text=['137126 1999 CF9<br>Radius: 631 meters <br> Velocity: 17....],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=65.09573444801933,
#                 color='rgb(255,41,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2060.104798670985],
#             y=[190.98414183698262],
#             text=['4660 Nereus<br>Radius: 575 meters <br> Velocity: 6.33 km/s'],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=59.5439937337157,
#                 color='rgb(105,0,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2028.4774170126059],
#             y=[39.6952454802193],
#             text=['153814 2001 WN5<br>Radius: 550 meters <br> Velocity: 10....],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=56.95408738576243,
#                 color='rgb(173,0,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2169.5936601888598],
#             y=[266.7230028825372],
#             text=['3362 Khufu<br>Radius: 550 meters <br> Velocity: 15.12 km/s'],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=56.95408738576243,
#                 color='rgb(255,2,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2080.6432758542037],
#             y=[104.20485559349598],
#             text=['163132 2002 CU11<br>Radius: 550 meters <br> Velocity: 26...],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=56.95408738576243,
#                 color='rgb(255,196,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2051.8023223545156],
#             y=[196.98788235590635],
#             text=['2004 FU4<br>Radius: 550 meters <br> Velocity: 13.64 km/s'],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=56.95408738576243,
#                 color='rgb(231,0,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2163.90454358834],
#             y=[264.9034673110986],
#             text=['162474 2000 LB16<br>Radius: 525 meters <br> Velocity: 28...],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=54.480746024977286,
#                 color='rgb(255,228,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2096.1371515898],
#             y=[148.19074322852606],
#             text=['269690 1996 RG3<br>Radius: 501 meters <br> Velocity: 14....],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=52.11872336272722,
#                 color='rgb(238,0,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2086.7834173471406],
#             y=[181.27485535031002],
#             text=['171576 1999 VP11<br>Radius: 501 meters <br> Velocity: 20...],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=52.11872336272722,
#                 color='rgb(255,96,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2001.1570240864924],
#             y=[230.49257708676592],
#             text=['2001 EC<br>Radius: 479 meters <br> Velocity: 22.49 km/s'],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=49.863009232263806,
#                 color='rgb(255,131,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2172.0556715022126],
#             y=[110.9297622010966],
#             text=['276033 2002 AJ129<br>Radius: 457 meters <br> Velocity: 3...],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=47.708818961487516,
#                 color='rgb(255,255,136)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2168.786641044356],
#             y=[195.4961727815103],
#             text=['374158 2004 UL<br>Radius: 437 meters <br> Velocity: 35.7...],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=45.65158322401658,
#                 color='rgb(255,255,156)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2049.9685784559706],
#             y=[275.0524620375738],
#             text=['2004 LV3<br>Radius: 437 meters <br> Velocity: 20.06 km/s'],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=45.65158322401658,
#                 color='rgb(255,89,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2015.0668708088135],
#             y=[192.65313008684595],
#             text=['357439 2004 BL86<br>Radius: 417 meters <br> Velocity: 15...],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=43.68693834703356,
#                 color='rgb(255,10,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2002.6285069111811],
#             y=[87.10472693520656],
#             text=['2002 NY40<br>Radius: 398 meters <br> Velocity: 20.9 km/s'],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=41.81071705534972,
#                 color='rgb(255,102,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2038.1034339218102],
#             y=[172.20341407587594],
#             text=['2002 NY40<br>Radius: 398 meters <br> Velocity: 20.55 km/s'],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=41.81071705534972,
#                 color='rgb(255,96,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2153.677801347262],
#             y=[121.03345051128942],
#             text=['1997 GL3<br>Radius: 380 meters <br> Velocity: 24.99 km/s'],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=40.01893963205609,
#                 color='rgb(255,172,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2083.312048568344],
#             y=[219.9945916545704],
#             text=['2006 JF42<br>Radius: 380 meters <br> Velocity: 12.45 km/s'],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=40.01893963205609,
#                 color='rgb(210,0,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2159.2928413393547],
#             y=[180.81018325712714],
#             text=['2006 JF42<br>Radius: 380 meters <br> Velocity: 12.36 km/s'],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=40.01893963205609,
#                 color='rgb(210,0,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2101.568298283229],
#             y=[144.84514448898375],
#             text=['2002 PD43<br>Radius: 380 meters <br> Velocity: 39.55 km/s'],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=40.01893963205609,
#                 color='rgb(255,255,255)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2076.9104625701384],
#             y=[251.7713190895516],
#             text=['162173 1999 JU3<br>Radius: 363 meters <br> Velocity: 4.4...],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=38.30780547701014,
#                 color='rgb(70,0,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2095.2431686510654],
#             y=[202.96089724255052],
#             text=['297300 1998 SC15<br>Radius: 363 meters <br> Velocity: 14...],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=38.30780547701014,
#                 color='rgb(238,0,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2140.878134361267],
#             y=[39.098877744260484],
#             text=['153201 2000 WO107<br>Radius: 347 meters <br> Velocity: 2...],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=36.67368504525315,
#                 color='rgb(255,191,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2093.8906623025105],
#             y=[198.55273474877245],
#             text=['153201 2000 WO107<br>Radius: 347 meters <br> Velocity: 2...],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=36.67368504525315,
#                 color='rgb(255,193,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2116.8714303635784],
#             y=[70.66080340352838],
#             text=['152685 1998 MZ<br>Radius: 347 meters <br> Velocity: 17.5...],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=36.67368504525315,
#                 color='rgb(255,44,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2004.979986846707],
#             y=[299.75387644540876],
#             text=['184266 2004 VW14<br>Radius: 331 meters <br> Velocity: 12...],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=35.11311214825913,
#                 color='rgb(217,0,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2052.1997209677174],
#             y=[181.2015586556112],
#             text=['221455 2006 BC10<br>Radius: 331 meters <br> Velocity: 18...],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=35.11311214825913,
#                 color='rgb(255,60,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2108.469614372824],
#             y=[263.1350483627057],
#             text=['2011 UW158<br>Radius: 331 meters <br> Velocity: 6.4 km/s'],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=35.11311214825913,
#                 color='rgb(105,0,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2006.501121451272],
#             y=[70.13564709938875],
#             text=['2004 XP14<br>Radius: 331 meters <br> Velocity: 17.41 km/s'],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=35.11311214825913,
#                 color='rgb(255,41,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2029.0685168711889],
#             y=[197.43688161911285],
#             text=['292220 2006 SU49<br>Radius: 316 meters <br> Velocity: 4....],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=33.622776601683796,
#                 color='rgb(78,0,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2122.8787711174978],
#             y=[131.99607710521659],
#             text=['2005 GC120<br>Radius: 302 meters <br> Velocity: 17.78 km/s'],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=32.19951720402014,
#                 color='rgb(255,47,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2072.775787676961],
#             y=[111.79484630627688],
#             text=['2011 SM68<br>Radius: 302 meters <br> Velocity: 22.93 km/s'],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=32.19951720402014,
#                 color='rgb(255,138,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2012.4751665070023],
#             y=[273.967005350134],
#             text=['1999 XL136<br>Radius: 302 meters <br> Velocity: 19.55 km/s'],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=32.19951720402014,
#                 color='rgb(255,78,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2029.2757819746666],
#             y=[9.51642303441163],
#             text=['99942 Apophis<br>Radius: 288 meters <br> Velocity: 7.41 ...],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=30.840315031266062,
#                 color='rgb(123,0,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2182.9787152350104],
#             y=[219.6939957795712],
#             text=['332446 2008 AF4<br>Radius: 288 meters <br> Velocity: 11....],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=30.840315031266062,
#                 color='rgb(202,0,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2073.302333759105],
#             y=[194.41140512142036],
#             text=['2010 HQ80<br>Radius: 288 meters <br> Velocity: 19.94 km/s'],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=30.840315031266062,
#                 color='rgb(255,86,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2150.218272432827],
#             y=[289.66118621472856],
#             text=['267221 2001 AD2<br>Radius: 275 meters <br> Velocity: 21....],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=29.54228703338165,
#                 color='rgb(255,110,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2149.889576965771],
#             y=[212.32292938332822],
#             text=['279744 1998 KM3<br>Radius: 275 meters <br> Velocity: 18....],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=29.54228703338165,
#                 color='rgb(255,54,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2133.221937107492],
#             y=[208.3390756799714],
#             text=['267221 2001 AD2<br>Radius: 275 meters <br> Velocity: 21....],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=29.54228703338165,
#                 color='rgb(255,112,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2004.5968344661892],
#             y=[259.7314120400353],
#             text=['2004 QB<br>Radius: 275 meters <br> Velocity: 18.09 km/s'],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=29.54228703338165,
#                 color='rgb(255,54,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2185.537663655855],
#             y=[190.17105473015798],
#             text=['2011 EL11<br>Radius: 275 meters <br> Velocity: 19.78 km/s'],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=29.54228703338165,
#                 color='rgb(255,83,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2046.242856925627],
#             y=[270.2738468506286],
#             text=['267221 2001 AD2<br>Radius: 275 meters <br> Velocity: 21....],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=29.54228703338165,
#                 color='rgb(255,120,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2041.7485383118167],
#             y=[220.19675417646192],
#             text=['2008 QS11<br>Radius: 263 meters <br> Velocity: 10.7 km/s'],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=28.302679918953835,
#                 color='rgb(181,0,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2086.7816344296943],
#             y=[139.55610573458395],
#             text=['2340 Hathor<br>Radius: 251 meters <br> Velocity: 13.23 km/s'],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=27.118864315095795,
#                 color='rgb(223,0,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2194.820505071241],
#             y=[138.85260596869048],
#             text=['374855 2006 VQ13<br>Radius: 251 meters <br> Velocity: 16...],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=27.118864315095795,
#                 color='rgb(255,26,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2130.3949770387603],
#             y=[166.5443698583311],
#             text=['163348 2002 NN4<br>Radius: 251 meters <br> Velocity: 12....],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=27.118864315095795,
#                 color='rgb(207,0,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2130.7701195961254],
#             y=[144.71445907748515],
#             text=['2340 Hathor<br>Radius: 251 meters <br> Velocity: 13.4 km/s'],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=27.118864315095795,
#                 color='rgb(225,0,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2048.145758253121],
#             y=[155.1245180337067],
#             text=['162162 1999 DB7<br>Radius: 251 meters <br> Velocity: 7.0...],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=27.118864315095795,
#                 color='rgb(115,0,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2069.786099326369],
#             y=[158.3877130486779],
#             text=['2340 Hathor<br>Radius: 251 meters <br> Velocity: 13.2 km/s'],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=27.118864315095795,
#                 color='rgb(223,0,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2070.4108788376443],
#             y=[242.226385898058],
#             text=['163348 2002 NN4<br>Radius: 251 meters <br> Velocity: 12....],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=27.118864315095795,
#                 color='rgb(207,0,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2160.1790178367773],
#             y=[246.00906377720838],
#             text=['2006 FX<br>Radius: 251 meters <br> Velocity: 17.08 km/s'],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=27.118864315095795,
#                 color='rgb(255,36,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2078.5865095114273],
#             y=[301.7493287067417],
#             text=['277475 2005 WK4<br>Radius: 240 meters <br> Velocity: 9.1...],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=25.988329190194886,
#                 color='rgb(154,0,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2100.2920715295836],
#             y=[82.65911823568861],
#             text=['363116 2001 GQ2<br>Radius: 240 meters <br> Velocity: 19....],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=25.988329190194886,
#                 color='rgb(255,78,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2141.635121572921],
#             y=[194.30960220485184],
#             text=['196625 2003 RM10<br>Radius: 229 meters <br> Velocity: 17...],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=24.908676527677734,
#                 color='rgb(255,47,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2054.516772349193],
#             y=[194.62032860184158],
#             text=['2013 LM31<br>Radius: 229 meters <br> Velocity: 15.66 km/s'],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=24.908676527677734,
#                 color='rgb(255,10,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2170.0992503383363],
#             y=[280.37069344514504],
#             text=['2007 RV9<br>Radius: 229 meters <br> Velocity: 13.04 km/s'],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=24.908676527677734,
#                 color='rgb(220,0,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2181.056570563995],
#             y=[255.1451638623617],
#             text=['2005 CJ<br>Radius: 229 meters <br> Velocity: 12.09 km/s'],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=24.908676527677734,
#                 color='rgb(204,0,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2192.0682963824643],
#             y=[144.36303702928228],
#             text=['2007 PV27<br>Radius: 229 meters <br> Velocity: 16.37 km/s'],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=24.908676527677734,
#                 color='rgb(255,23,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2179.937936225537],
#             y=[245.4640466665211],
#             text=['1995 YR1<br>Radius: 229 meters <br> Velocity: 29.06 km/s'],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=24.908676527677734,
#                 color='rgb(255,243,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2008.0754280522483],
#             y=[89.15305640400283],
#             text=['2007 TU24<br>Radius: 219 meters <br> Velocity: 9.25 km/s'],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=23.877616239495516,
#                 color='rgb(154,0,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2081.1994320514577],
#             y=[239.2422048539637],
#             text=['2006 GB<br>Radius: 219 meters <br> Velocity: 7.1 km/s'],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=23.877616239495516,
#                 color='rgb(118,0,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2037.2118364429846],
#             y=[249.62771604834242],
#             text=['2006 GB<br>Radius: 219 meters <br> Velocity: 6.93 km/s'],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=23.877616239495516,
#                 color='rgb(115,0,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2168.0338602253546],
#             y=[272.439149979968],
#             text=['2007 TU24<br>Radius: 219 meters <br> Velocity: 9.05 km/s'],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=23.877616239495516,
#                 color='rgb(152,0,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2136.027152426136],
#             y=[296.4701602446613],
#             text=['2000 YF29<br>Radius: 219 meters <br> Velocity: 7.5 km/s'],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=23.877616239495516,
#                 color='rgb(123,0,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2193.006413180664],
#             y=[158.55316523001198],
#             text=['2000 YF29<br>Radius: 219 meters <br> Velocity: 7.76 km/s'],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=23.877616239495516,
#                 color='rgb(128,0,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2006.7634935297963],
#             y=[303.4977767290281],
#             text=['2006 RZ<br>Radius: 219 meters <br> Velocity: 13.5 km/s'],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=23.877616239495516,
#                 color='rgb(228,0,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2009.1327361130118],
#             y=[266.64168140285415],
#             text=['208023 1999 AQ10<br>Radius: 209 meters <br> Velocity: 8....],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=22.892961308540407,
#                 color='rgb(139,0,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2067.674596657695],
#             y=[231.80186187154268],
#             text=['2002 SZ<br>Radius: 209 meters <br> Velocity: 17.82 km/s'],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=22.892961308540407,
#                 color='rgb(255,49,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2150.6499646457733],
#             y=[262.16756154430385],
#             text=['2002 SZ<br>Radius: 209 meters <br> Velocity: 17.42 km/s'],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=22.892961308540407,
#                 color='rgb(255,41,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2059.878221796451],
#             y=[110.73945925229582],
#             text=['2009 WM1<br>Radius: 209 meters <br> Velocity: 14.24 km/s'],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=22.892961308540407,
#                 color='rgb(241,0,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2088.3458973891093],
#             y=[290.6568464816115],
#             text=['2012 HZ33<br>Radius: 209 meters <br> Velocity: 13.84 km/s'],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=22.892961308540407,
#                 color='rgb(233,0,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2042.4447200553502],
#             y=[234.2223387424332],
#             text=['2004 MD6<br>Radius: 200 meters <br> Velocity: 21.57 km/s'],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=21.95262314968879,
#                 color='rgb(255,115,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2057.765683210924],
#             y=[274.49363949696],
#             text=['162120 1998 SH36<br>Radius: 200 meters <br> Velocity: 17...],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=21.95262314968879,
#                 color='rgb(255,44,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2051.5945687544668],
#             y=[294.1521360980591],
#             text=['162422 2000 EV70<br>Radius: 200 meters <br> Velocity: 16...],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=21.95262314968879,
#                 color='rgb(255,18,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2189.702843924395],
#             y=[286.12526104604416],
#             text=['360191 1988 TA<br>Radius: 191 meters <br> Velocity: 13.2...],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=21.05460717963246,
#                 color='rgb(225,0,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2120.2803229019355],
#             y=[226.78840274849495],
#             text=['2011 DV<br>Radius: 191 meters <br> Velocity: 5.51 km/s'],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=21.05460717963246,
#                 color='rgb(89,0,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2053.7343776135517],
#             y=[137.2696893785205],
#             text=['360191 1988 TA<br>Radius: 191 meters <br> Velocity: 12.9...],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=21.05460717963246,
#                 color='rgb(220,0,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2067.1579136444507],
#             y=[287.40565611204664],
#             text=['2008 RG1<br>Radius: 182 meters <br> Velocity: 14.93 km/s'],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=20.197008586099837,
#                 color='rgb(254,0,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2065.3867524291777],
#             y=[59.977242621714375],
#             text=['2005 WY55<br>Radius: 182 meters <br> Velocity: 18.6 km/s'],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=20.197008586099837,
#                 color='rgb(255,62,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2047.0222617581314],
#             y=[252.12763430774342],
#             text=['2010 WZ8<br>Radius: 182 meters <br> Velocity: 7.21 km/s'],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=20.197008586099837,
#                 color='rgb(120,0,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2051.21211585542],
#             y=[294.3444667931309],
#             text=['4581 Asclepius<br>Radius: 182 meters <br> Velocity: 11.0...],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=20.197008586099837,
#                 color='rgb(186,0,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2066.710123853839],
#             y=[73.43584577081073],
#             text=['2011 SR5<br>Radius: 182 meters <br> Velocity: 26.36 km/s'],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=20.197008586099837,
#                 color='rgb(255,196,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2082.927734820492],
#             y=[165.42792744222396],
#             text=['2010 MU112<br>Radius: 182 meters <br> Velocity: 29.25 km/s'],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=20.197008586099837,
#                 color='rgb(255,246,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2010.8674178489425],
#             y=[261.4144048615441],
#             text=['2010 RF181<br>Radius: 182 meters <br> Velocity: 7.87 km/s'],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=20.197008586099837,
#                 color='rgb(131,0,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2194.1245495187263],
#             y=[199.76152774512818],
#             text=['1999 FA<br>Radius: 182 meters <br> Velocity: 7.18 km/s'],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=20.197008586099837,
#                 color='rgb(118,0,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
# ...
#                 color='rgb(255,41,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2008.3537855633106],
#             y=[24.243988095081463],
#             text=['2008 JL24<br>Radius: 3 meters <br> Velocity: 3.52 km/s'],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=2.3019951720402014,
#                 color='rgb(55,0,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2006.0775683134893],
#             y=[31.449616986616924],
#             text=['2006 BF56<br>Radius: 3 meters <br> Velocity: 25.45 km/s'],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=2.3019951720402014,
#                 color='rgb(255,180,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2010.9121542508706],
#             y=[8.440618641462011],
#             text=['2010 XB<br>Radius: 3 meters <br> Velocity: 20.09 km/s'],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=2.3019951720402014,
#                 color='rgb(255,89,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2011.0263883186594],
#             y=[18.135816978955962],
#             text=['2011 AM37<br>Radius: 3 meters <br> Velocity: 4.41 km/s'],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=2.2884031503126607,
#                 color='rgb(70,0,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2011.9860521874002],
#             y=[19.017941748486102],
#             text=['2011 YC40<br>Radius: 3 meters <br> Velocity: 11.36 km/s'],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=2.2884031503126607,
#                 color='rgb(191,0,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2008.0411116433252],
#             y=[54.35168718342646],
#             text=['2008 BW2<br>Radius: 3 meters <br> Velocity: 6.97 km/s'],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=2.2884031503126607,
#                 color='rgb(115,0,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2011.3390375287015],
#             y=[54.71908532175363],
#             text=['2011 JV10<br>Radius: 3 meters <br> Velocity: 5.33 km/s'],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=2.2884031503126607,
#                 color='rgb(86,0,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2012.0006215501119],
#             y=[40.26996252472007],
#             text=['2011 YB63<br>Radius: 3 meters <br> Velocity: 8.53 km/s'],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=2.2754228703338164,
#                 color='rgb(141,0,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2003.3370550309444],
#             y=[185.14164974746777],
#             text=['2008 WO2<br>Radius: 3 meters <br> Velocity: 6.21 km/s'],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=2.2754228703338164,
#                 color='rgb(102,0,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2008.8743043200584],
#             y=[60.817392347297314],
#             text=['2008 WO2<br>Radius: 3 meters <br> Velocity: 6.29 km/s'],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=2.2754228703338164,
#                 color='rgb(102,0,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2012.950948861822],
#             y=[48.746372715831484],
#             text=['2012 XB112<br>Radius: 3 meters <br> Velocity: 4.43 km/s'],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=2.263026799189538,
#                 color='rgb(70,0,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2039.4313652813892],
#             y=[248.2223624956097],
#             text=['2012 XB112<br>Radius: 3 meters <br> Velocity: 4.5 km/s'],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=2.263026799189538,
#                 color='rgb(73,0,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2005.901251463589],
#             y=[17.20832858284722],
#             text=['2005 WN3<br>Radius: 3 meters <br> Velocity: 19.3 km/s'],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=2.263026799189538,
#                 color='rgb(255,75,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2014.0203343825556],
#             y=[20.449705736057478],
#             text=['2014 AG51<br>Radius: 3 meters <br> Velocity: 15.04 km/s'],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=2.263026799189538,
#                 color='rgb(254,0,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2010.8749315724647],
#             y=[8.598607980432734],
#             text=['2010 WA<br>Radius: 3 meters <br> Velocity: 13.07 km/s'],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=2.251188643150958,
#                 color='rgb(220,0,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2003.7387588765719],
#             y=[12.953205016060988],
#             text=['2003 SQ222<br>Radius: 2 meters <br> Velocity: 15.44 km/s'],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=2.2398832919019487,
#                 color='rgb(255,7,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2012.231324985174],
#             y=[12.996867957889723],
#             text=['2012 FS35<br>Radius: 2 meters <br> Velocity: 4.83 km/s'],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=2.229086765276777,
#                 color='rgb(78,0,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2072.211878259812],
#             y=[182.52398953175413],
#             text=['2012 FS35<br>Radius: 2 meters <br> Velocity: 3.62 km/s'],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=2.229086765276777,
#                 color='rgb(57,0,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2008.8406664841932],
#             y=[8.55595412930999],
#             text=['2008 VM<br>Radius: 2 meters <br> Velocity: 11.11 km/s'],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=2.229086765276777,
#                 color='rgb(186,0,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2011.1066405121421],
#             y=[21.98227358592627],
#             text=['2011 CA7<br>Radius: 2 meters <br> Velocity: 9.33 km/s'],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=2.2187761623949553,
#                 color='rgb(157,0,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2011.989477365692],
#             y=[43.919450404210124],
#             text=['2012 AQ<br>Radius: 2 meters <br> Velocity: 3.28 km/s'],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=2.181970085860998,
#                 color='rgb(52,0,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2007.6749825129632],
#             y=[16.345024057864734],
#             text=['2007 RS1<br>Radius: 2 meters <br> Velocity: 12.14 km/s'],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=2.1659586907437562,
#                 color='rgb(204,0,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2011.0975396499553],
#             y=[7.983107957870593],
#             text=['2011 CF22<br>Radius: 2 meters <br> Velocity: 19.6 km/s'],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=2.1659586907437562,
#                 color='rgb(255,78,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2012.0495453370436],
#             y=[50.774606675462856],
#             text=['2012 BV1<br>Radius: 2 meters <br> Velocity: 8.65 km/s'],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=2.158489319246111,
#                 color='rgb(144,0,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2013.7127469093564],
#             y=[37.10698951773434],
#             text=['2013 RZ53<br>Radius: 2 meters <br> Velocity: 2.18 km/s'],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=2.1513561248436206,
#                 color='rgb(31,0,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2014.6850660705868],
#             y=[118.10103553141718],
#             text=['2013 RZ53<br>Radius: 2 meters <br> Velocity: 1.56 km/s'],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=2.1513561248436206,
#                 color='rgb(21,0,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2013.9743681857578],
#             y=[5.480113084472864],
#             text=['2013 YB<br>Radius: 1 meters <br> Velocity: 10.52 km/s'],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=2.1258925411794167,
#                 color='rgb(175,0,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2011.0929759135076],
#             y=[7.564823996884261],
#             text=['2011 CQ1<br>Radius: 1 meters <br> Velocity: 9.69 km/s'],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=2.0954992586021435,
#                 color='rgb(162,0,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2008.8057057159801],
#             y=[14.795051714133013],
#             text=['2008 UM1<br>Radius: 1 meters <br> Velocity: 15.62 km/s'],
#             name='',
#             marker=Marker(
#                 symbol='circle',
#                 line=Line(
#                     color=['white'],
#                     width=0.5
#                 ),
#                 size=2.0954992586021435,
#                 color='rgb(255,10,0)',
#                 opacity=1.0
#             )
#         ),
#         Scatter(
#             x=[2014.1840518607246, 2014.1840518607246, 2014.1840518607246, ...],
#             y=[1.0, 4.04040404040404, 7.08080808080808, 10.121212121212121,...],
#             name='Today',
#             mode='lines'
#         ),
#         Scatter(
#             x=[2000.0, 2001.010101010101, 2002.020202020202, 2003.030303030...],
#             y=[6.3, 6.3, 6.3, 6.3, 6.3, 6.3, 6.3, 6.3, 6.3, 6.3, 6.3, 6.3, ...],
#             name='Geosynchronous Satellites',
#             mode='lines',
#             line=Line(
#                 dash='dot'
#             )
#         ),
#         Scatter(
#             x=[2000.0, 2001.010101010101, 2002.020202020202, 2003.030303030...],
#             y=[60.33589693721351, 60.33589693721351, 60.33589693721351, 60....],
#             name='Moon',
#             mode='lines',
#             line=Line(
#                 dash='dot'
#             )
#         )
#     ]),
#     layout=Layout(
#         title='A Century of Asteroid Flybys',
#         xaxis=XAxis(
#             title="Date<br>Data extracted from <a href='http://neo.jpl.nasa...",
#             range=[2000, 2100],
#             linecolor='black',
#             linewidth=2,
#             tickcolor='black'
#         ),
#         yaxis=YAxis(
#             title='Nominal Flyby Distance (Earth Radii)',
#             range=[1, 302.0],
#             type='linear',
#             linecolor='black',
#             linewidth=2,
#             tickcolor='black'
#         ),
#         autosize=True,
#         paper_bgcolor='#fbfbfb',
#         plot_bgcolor='#fbfbfb',
#         hovermode='closest',
#         font=Font(
#             family='Century Gothic',
#             size=16,
#             color='black'
#         ),
#         showlegend=False
#     )
# )

# %% [markdown]
# And there you have it! The full figure object in your Python/IPython session.
#
# Now, let's save a static (i.e. non-interactive) `.png` version of the original Plotly figure to our working directory using the just retrieved figure object and the `image.save_as()` function of the `plotly.plotly` module:

# %%
# (NEW!) convert Plotly figure object to a (static) .png figure
#        and save it as 'asteroids.png' in the working directory
py.image.save_as(asteroids, 'asteroids')

# %% [markdown]
# See the results by importing the `.png` figure inside this notebook:

# %%
# Import .png figure and show it in this cell
from IPython.display import Image
Image('asteroids.png')

# %% [markdown]
# Not bad. The Plotly figure now resides on your computer!
#
# Alternatively, one could have used another `plotly.plotly` function,
#
#     >>> py.image.ishow(asteroids, 'asteroids')
#
# to display the static `.png` version of the `asteroids` figure object inside this notebook.

# %% [markdown]
# Next, extract the data object tucked inside `asteroids` using the `get_data()` method and make a list of flyby distances by looping through each trace objects (`Scatter` in this case):

# %%
# Extract data object inside figure object
asteroids_data = asteroids.get_data()

# Make a list of distances,
#  distances are linked to the 'y' key in each trace (Scatter) object,
#  specify item [0] to extract value from list
distances = [trace['y'][0] for trace in asteroids_data]

# %% [markdown]
# Histograms in Plotly are generated using the `Histogram` graph object. Experienced Plotly users, please note:
#
# > The `'histogramx'` and `'histogramy'` plot types are merged into the `Histogram` graph object in version 1.0 of Plotly's Python API. For more info on Plotly histograms see [section 4](http://nbviewer.ipython.org/github/plotly/python-user-guide/blob/master/s4_histograms/s4_histograms.ipynb).

# %%
# (*) Import Histogram (NEW!)
from plotly.graph_objs import Histogram

# %%
help(Histogram)  # for fun
# Out:
# Help on class Histogram in module plotly.graph_objs.graph_objs:
#
# class Histogram(PlotlyTrace)
#  |  A dictionary-like object for representing a histogram plot in plotly.
#  |
#  |      Example:
#  |          # make a histogram along xaxis...
#  |          py.plot([Histogram(x=[1,1,2,3,2,3,3])])
#  |
#  |          # make a histogram along yaxis...
#  |          py.plot([Histogram(y=[1,1,2,3,2,3,3], orientation='h')])
#  |
#  |
#  |  Quick method reference:
#  |
#  |      Histogram.update(changes)
#  |      Histogram.strip_style()
#  |      Histogram.get_data()
#  |      Histogram.to_graph_objs()
#  |      Histogram.validate()
#  |      Histogram.to_string()
#  |      Histogram.force_clean()
#  |
#  |  Valid keys:
#  |
#  |      x [required=True] (value=array-like of numbers, strings, datetimes):
#  |          The x data that is binned and plotted as bars along the x-axis.
#  |
#  |      y [required=True] (value=array-like of numbers, strings, datetimes):
#  |          The y data that is binned and plotted as bars along the y-axis.
#  |
#  |      name [required=False] (value=string):
#  |          The label associated with this trace. This name will appear in the
#  |          legend, in the column header in the spreadsheet, and on hover.
#  |
#  |      orientation [required=False] (value='v' | 'h'):
#  |          'v' | 'h'
#  |
#  |      marker [required=False] (value=Marker object | dictionary-like):
#  |          Aw, snap! Undocumented!
#  |
#  |          For more, run `help(plotly.graph_objs.Marker)`
#  |
#  |      opacity [required=False] (value=number: x in [0, 1]):
#  |          Sets the opacity, or transparency, of this object. Also known as the
#  |          alpha channel of colors, if the object's color is given in terms of
#  |          'rgba', this does not need to be defined.
#  |
#  |      line [required=False] (value=Line object | dictionary-like):
#  |          Aw, snap! Undocumented!
#  |
#  |          For more, run `help(plotly.graph_objs.Line)`
#  |
#  |      autobinx [required=False] (value=bool: True | False):
#  |          Toggle whether or not to allow plotly to automatically pick the bin
#  |          sizing in the x direction for this histogram.
#  |
#  |      xbins [required=False] (value=XBins object | dictionary-like):
#  |          A dictionary-like object explaining how the bins should be created
#  |          in the x direction for this histogram.
#  |
#  |          For more, run `help(plotly.graph_objs.XBins)`
#  |
#  |      nbinsx [required=False] (value=number: x > 0):
#  |          Specifies the number of bins in the x-direction.
#  |
#  |      autobiny [required=False] (value=bool: True | False):
#  |          Toggle whether or not to allow plotly to automatically pick the bin
#  |          sizing in the y direction for this histogram.
#  |
#  |      ybins [required=False] (value=YBins object | dictionary-like):
#  |          A dictionary-like object explaining how the bins should be created
#  |          in the y direction for this histogram.
#  |
#  |          For more, run `help(plotly.graph_objs.YBins)`
#  |
#  |      nbinsy [required=False] (value=number: x > 0):
#  |          Specifies the number of bins in the y-direction.
#  |
#  |      histnorm [required=Aw, snap! Undocumented!] (value='' | 'percent' |
#  |      'probability' | 'density' | 'probability density'):
#  |          If histnorm is not specified, or histnorm='' (empty string), the
#  |          height of each bar displays the frequency of occurrence, i.e., the
#  |          number of times this value was found in the corresponding bin. If
#  |          histnorm='percent', the height of each bar displays the percentage
#  |          of total occurrences found within the corresponding bin. If
#  |          histnorm='probability', the height of each bar displays the
#  |          probability that an event will fall into the corresponding bin. If
#  |          histnorm='density', the height of each bar is equal to the number of
#  |          occurrences in a bin divided by the size of the bin interval such
#  |          that summing the area of all bins will yield the total number of
#  |          occurrences. If histnorm='probability density', the height of each
#  |          bar is equal to the number of probability that an event will fall
#  |          into the corresponding bin divided by the size of the bin interval
#  |          such that summing the area of all bins will yield 1, i.e. an event
#  |          must fall into one of the bins.
#  |
#  |      showlegend [required=False] (value=bool: True | False):
#  |          Toggle whether or not this trace will show up in the legend.
#  |
#  |      xaxis [required=False] (value=string: 'x1' | 'x2' | 'x3' | etc.):
#  |          This key determines which xaxis the x coordinates in this trace will
#  |          reference in the figure. 'x' references layout['xaxis'] and 'x2'
#  |          references layout['xaxis2']. 'x1' will always refer to
#  |          layout['xaxis'] or layout['xaxis1'], they are the same.
#  |
#  |      yaxis [required=False] (value=string: 'y1' | 'y2' | 'y3' | etc.):
#  |          This key determines which yaxis the y coordinates in this trace will
#  |          reference in the figure. 'y' references layout['yaxis'] and 'y2'
#  |          references layout['yaxis2']. 'y1' will always refer to
#  |          layout['yaxis'] or layout['yaxis1'], they are the same.
#  |
#  |      visible [required=False] (value=bool: True | False):
#  |          Toggles whether this will actually be visible in the rendered
#  |          figure.
#  |
#  |      stream [required=False] (value=dictionary-like):
#  |          The stream dict that initializes traces as writable-streams, for use
#  |          with the real-time streaming API. See examples here:
#  |          http://nbviewer.ipython.org/github/plotly/Streaming-Demos
#  |
#  |      error_y [required=False] (value=ErrorY object | dictionary-like):
#  |          A dictionary-like object describing vertical error bars that can be
#  |          drawn with this trace's (x, y) points.
#  |
#  |          For more, run `help(plotly.graph_objs.ErrorY)`
#  |
#  |      error_x [required=False] (value=ErrorX object | dictionary-like):
#  |          A dictionary-like object describing horizontal error bars that can
#  |          be drawn with this trace's (x, y) points.
#  |
#  |          For more, run `help(plotly.graph_objs.ErrorX)`
#  |
#  |      type [required=True] (value=histogram):
#  |          Plotly identifier for this data's trace type. This defines how this
#  |          data dictionary will be handled. For example, 'scatter' type expects
#  |          x and y data-arrays corresponding to (x, y) coordinates wheras a
#  |          'histogram' only requires a single x or y array and a 'heatmap' type
#  |          requires a z matrix.
#  |
#  |  Method resolution order:
#  |      Histogram
#  |      PlotlyTrace
#  |      PlotlyDict
#  |      __builtin__.dict
#  |      __builtin__.object
#  |
#  |  Methods inherited from PlotlyTrace:
#  |
#  |  __init__(self, *args, **kwargs)
#  |
#  |  to_string(self, level=0, indent=4, eol='\n', pretty=True, max_chars=80)
#  |      Returns a formatted string showing graph_obj constructors.
#  |
#  |              Example:
#  |
#  |                  print obj.to_string()
#  |
#  |              Keyword arguments:
#  |              level (default = 0) -- set number of indentations to start with
#  |              indent (default = 4) -- set indentation amount
#  |              eol (default = '
#  |      ') -- set end of line character(s)
#  |              pretty (default = True) -- curtail long list output with a '...'
#  |              max_chars (default = 80) -- set max characters per line
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from PlotlyDict:
#  |
#  |  force_clean(self, caller=True)
#  |      Attempts to convert to graph_objs and call force_clean() on values.
#  |
#  |      Calling force_clean() on a PlotlyDict will ensure that the object is
#  |      valid and may be sent to plotly. This process will also remove any
#  |      entries that end up with a length == 0.
#  |
#  |      Careful! This will delete any invalid entries *silently*.
#  |
#  |  get_data(self)
#  |      Returns the JSON for the plot with non-data elements stripped.
#  |
#  |  get_ordered(self, caller=True)
#  |
#  |  strip_style(self)
#  |      Strip style from the current representation.
#  |
#  |      All PlotlyDicts and PlotlyLists are guaranteed to survive the
#  |      stripping process, though they made be left empty. This is allowable.
#  |
#  |      Keys that will be stripped in this process are tagged with
#  |      `'type': 'style'` in the INFO dictionary listed in graph_objs_meta.py.
#  |
#  |      This process first attempts to convert nested collections from dicts
#  |      or lists to subclasses of PlotlyList/PlotlyDict. This process forces
#  |      a validation, which may throw exceptions.
#  |
#  |      Then, each of these objects call `strip_style` on themselves and so
#  |      on, recursively until the entire structure has been validated and
#  |      stripped.
#  |
#  |  to_graph_objs(self, caller=True)
#  |      Walk obj, convert dicts and lists to plotly graph objs.
#  |
#  |      For each key in the object, if it corresponds to a special key that
#  |      should be associated with a graph object, the ordinary dict or list
#  |      will be reinitialized as a special PlotlyDict or PlotlyList of the
#  |      appropriate `kind`.
#  |
#  |  update(self, dict1=None, **dict2)
#  |      Update current dict with dict1 and then dict2.
#  |
#  |      This recursively updates the structure of the original dictionary-like
#  |      object with the new entries in the second and third objects. This
#  |      allows users to update with large, nested structures.
#  |
#  |      Note, because the dict2 packs up all the keyword arguments, you can
#  |      specify the changes as a list of keyword agruments.
#  |
#  |      Examples:
#  |      # update with dict
#  |      obj = Layout(title='my title', xaxis=XAxis(range=[0,1], domain=[0,1]))
#  |      update_dict = dict(title='new title', xaxis=dict(domain=[0,.8]))
#  |      obj.update(update_dict)
#  |      obj
#  |      {'title': 'new title', 'xaxis': {'range': [0,1], 'domain': [0,.8]}}
#  |
#  |      # update with list of keyword arguments
#  |      obj = Layout(title='my title', xaxis=XAxis(range=[0,1], domain=[0,1]))
#  |      obj.update(title='new title', xaxis=dict(domain=[0,.8]))
#  |      obj
#  |      {'title': 'new title', 'xaxis': {'range': [0,1], 'domain': [0,.8]}}
#  |
#  |      This 'fully' supports duck-typing in that the call signature is
#  |      identical, however this differs slightly from the normal update
#  |      method provided by Python's dictionaries.
#  |
#  |  validate(self, caller=True)
#  |      Recursively check the validity of the keys in a PlotlyDict.
#  |
#  |      The valid keys constitute the entries in each object
#  |      dictionary in INFO stored in graph_objs_meta.py.
#  |
#  |      The validation process first requires that all nested collections be
#  |      converted to the appropriate subclass of PlotlyDict/PlotlyList. Then,
#  |      each of these objects call `validate` and so on, recursively,
#  |      until the entire object has been validated.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from PlotlyDict:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes inherited from PlotlyDict:
#  |
#  |  __metaclass__ = <class 'plotly.graph_objs.graph_objs.DictMeta'>
#  |      A meta class for PlotlyDict class creation.
#  |
#  |      The sole purpose of this meta class is to properly create the __doc__
#  |      attribute so that running help(Obj), where Obj is a subclass of PlotlyDict,
#  |      will return information about key-value pairs for that object.
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from __builtin__.dict:
#  |
#  |  __cmp__(...)
#  |      x.__cmp__(y) <==> cmp(x,y)
#  |
#  |  __contains__(...)
#  |      D.__contains__(k) -> True if D has a key k, else False
#  |
#  |  __delitem__(...)
#  |      x.__delitem__(y) <==> del x[y]
#  |
#  |  __eq__(...)
#  |      x.__eq__(y) <==> x==y
#  |
#  |  __ge__(...)
#  |      x.__ge__(y) <==> x>=y
#  |
#  |  __getattribute__(...)
#  |      x.__getattribute__('name') <==> x.name
#  |
#  |  __getitem__(...)
#  |      x.__getitem__(y) <==> x[y]
#  |
#  |  __gt__(...)
#  |      x.__gt__(y) <==> x>y
#  |
#  |  __iter__(...)
#  |      x.__iter__() <==> iter(x)
#  |
#  |  __le__(...)
#  |      x.__le__(y) <==> x<=y
#  |
#  |  __len__(...)
#  |      x.__len__() <==> len(x)
#  |
#  |  __lt__(...)
#  |      x.__lt__(y) <==> x<y
#  |
#  |  __ne__(...)
#  |      x.__ne__(y) <==> x!=y
#  |
#  |  __repr__(...)
#  |      x.__repr__() <==> repr(x)
#  |
#  |  __setitem__(...)
#  |      x.__setitem__(i, y) <==> x[i]=y
#  |
#  |  __sizeof__(...)
#  |      D.__sizeof__() -> size of D in memory, in bytes
#  |
#  |  clear(...)
#  |      D.clear() -> None.  Remove all items from D.
#  |
#  |  copy(...)
#  |      D.copy() -> a shallow copy of D
#  |
#  |  fromkeys(...)
#  |      dict.fromkeys(S[,v]) -> New dict with keys from S and values equal to v.
#  |      v defaults to None.
#  |
#  |  get(...)
#  |      D.get(k[,d]) -> D[k] if k in D, else d.  d defaults to None.
#  |
#  |  has_key(...)
#  |      D.has_key(k) -> True if D has a key k, else False
#  |
#  |  items(...)
#  |      D.items() -> list of D's (key, value) pairs, as 2-tuples
#  |
#  |  iteritems(...)
#  |      D.iteritems() -> an iterator over the (key, value) items of D
#  |
#  |  iterkeys(...)
#  |      D.iterkeys() -> an iterator over the keys of D
#  |
#  |  itervalues(...)
#  |      D.itervalues() -> an iterator over the values of D
#  |
#  |  keys(...)
#  |      D.keys() -> list of D's keys
#  |
#  |  pop(...)
#  |      D.pop(k[,d]) -> v, remove specified key and return the corresponding value.
#  |      If key is not found, d is returned if given, otherwise KeyError is raised
#  |
#  |  popitem(...)
#  |      D.popitem() -> (k, v), remove and return some (key, value) pair as a
#  |      2-tuple; but raise KeyError if D is empty.
#  |
#  |  setdefault(...)
#  |      D.setdefault(k[,d]) -> D.get(k,d), also set D[k]=d if k not in D
#  |
#  |  values(...)
#  |      D.values() -> list of D's values
#  |
#  |  viewitems(...)
#  |      D.viewitems() -> a set-like object providing a view on D's items
#  |
#  |  viewkeys(...)
#  |      D.viewkeys() -> a set-like object providing a view on D's keys
#  |
#  |  viewvalues(...)
#  |      D.viewvalues() -> an object providing a view on D's values
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes inherited from __builtin__.dict:
#  |
#  |  __hash__ = None
#  |
#  |  __new__ = <built-in method __new__ of type object>
#  |      T.__new__(S, ...) -> a new object with type S, a subtype of T

# %%
# Make Data object
my_data = Data([Histogram(x=distances)])

# Make layout object (plot title, x-axis title and y-axis title)
my_layout = Layout(title='Histogram of distance data for asteroid flybys', 
                   xaxis=XAxis(title='Number of flybys for the given distance'), 
                   yaxis=YAxis(title='Normalized flyby distance (Earth radii)'),
                   showlegend=False)  # remove legend

# Make figure object, send to Plotly and show plot in notebook
my_fig = Figure(data=my_data, layout=my_layout)
py.iplot(my_fig, filename='s0_distance-histogramx')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~etpinard/208" height="525" width="100%"></iframe>

# %% [markdown]
# Nice.
#
# Let's say that you really like the font used in the original asteroid plot. Well now, you can get its name, color, size, etc. from the figure object inside you Python/IPython session:

# %%
# Extract global font in 'layout' and 'font' key and print stdout
asteroids_font = asteroids['layout']['font']
asteroids_font
# Out:
# {'color': 'black', 'family': 'Century Gothic', 'size': 16}

# %%
# Add 'font' key to figure object
my_fig['layout'].update({'font': asteroids_font})

# Send to Plotly and show plot in notebook
py.iplot(my_fig, filename='s0_distance-histogramx-nice-font')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~etpinard/209" height="525" width="100%"></iframe>

# %% [markdown]
# Wow! All that took was three lines of code. Just think of the possibilities that the `get_figure()` function opens up.

# %% [markdown]
# ##### Python-GUI-Python

# %% [markdown]
# Plotly allows user to style their graphs with a GUI. This method is fast and flexible and now, combined with the API `get_figure()` function, styling inside the GUI is reproducible!
#
# For example, starting with a simple Box chart:

# %%
# (*) Import the Box figure object
from plotly.graph_objs import Box

# %%
# Make Data object made up of 15 Box object 
my_data = Data([Box(name='box{}'.format(i), 
                    y=np.random.randn(40)) for i in range(15)])

# Make figure object, send to Plotly and show plot in notebook
my_fig = Figure(data=my_data)
py.iplot(my_fig, filename='s0_quick-boxes')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~etpinard/210" height="525" width="100%"></iframe>

# %% [markdown]
# Click on the *data and graph* link at the bottom right-hand corner of the plot. This will open up in a unique URL that identifies this figure.
#
# Since it's public, you can view it and choose to *save and edit*.
#
# <img src="http://i.imgur.com/NSsI8mT.png">
#
# Change a few style options in a new copy of the figure on the web GUI. Then, find the figure's unique URL which is a combination of your username and the file ID of the plot, which is just a number. Watch the video below for an example:

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('zEKfPI3GtOw', width='100%', height='350')
# Out:
#         <iframe
#             width="100%"
#             height=350"
#             src="https://www.youtube.com/embed/zEKfPI3GtOw"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# Using the `get_figure()` function, I can pull in the entire figure object just edited!
# From that video, the unique user-file_id pair was `'PythonAPI'`, `'61'`, so:

# %%
# Get figure object from Plotly's servers 
my_fig_styled = py.get_figure('PythonAPI', '61')

# %% [markdown]
# Then, you can use this new figure object to restyle or replot it within an Python/IPython session ad infinitum:

# %%
# Send to Plotly and show plot in notebook
py.iplot(my_fig_styled, filename='s0_quickbars-edited',
         width=700)  # adjust display width (in pixels)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~etpinard/211/675/500" height="525" width="700"></iframe>

# %% [markdown]
# That's right. Styling inside the GUI is reproducible!

# %% [markdown]
# ### 0.7 Subplots and other version 1.0 additions

# %% [markdown]
# ##### Subplots in Plotly

# %% [markdown]
# When working with Plotly, it's best not to think of subplots, but rather of axes and subaxes. All axes share the same axes area, `[0, 1]` from left-to-right in the x direction and `[0, 1]` from bottom-to-top in the y direction. Since all axes share the same space, they can be *anchored* (or bind together) arbitrarily and shared with other axes.
#
# Here's a common situation where this flexibility comes in handy. Below, we create an x and y axis for the main `Histogram2d` object. Then, a second x-axis is created for a horizontal `Histogram` data object. Finally, a second y-axis is created for a vertical `Histogram` data object. First, import the `Histogram2d` graph object:

# %%
# (*) Import the Histogram2d graph objects
from plotly.graph_objs import Histogram2d

# %%
help(Histogram2d)  # for fun
# Out:
# Help on class Histogram2d in module plotly.graph_objs.graph_objs:
#
# class Histogram2d(PlotlyTrace)
#  |  A dictionary-like object for representing a histogram2d plot in plotly.
#  |
#  |      Example:
#  |
#  |          import numpy as np
#  |          x = np.random.randn(500)
#  |          y = np.random.randn(500)+1
#  |          py.iplot([Histogram2d(x=x, y=y)])
#  |
#  |
#  |  Quick method reference:
#  |
#  |      Histogram2d.update(changes)
#  |      Histogram2d.strip_style()
#  |      Histogram2d.get_data()
#  |      Histogram2d.to_graph_objs()
#  |      Histogram2d.validate()
#  |      Histogram2d.to_string()
#  |      Histogram2d.force_clean()
#  |
#  |  Valid keys:
#  |
#  |      x [required=True] (value=array-like of numbers, strings, datetimes):
#  |          The x data that is binned and plotted as bars along the x-axis.
#  |
#  |      y [required=True] (value=array-like of numbers, strings, datetimes):
#  |          The y data that is binned and plotted as bars along the y-axis.
#  |
#  |      scl [required=False] (value=array_like of value-color pairs | 'Greys' |
#  |      'Greens' | 'Bluered' | 'Hot' | 'Picnic' | 'Portland' | 'Jet' | 'RdBu' |
#  |      'Blackbody' | 'Earth' | 'Electric' | 'YIOrRd' | 'YIGnBu'):
#  |          The color scale. The strings are pre-defined color scales. For
#  |          custom color scales, define a list of color-value pairs, where the
#  |          first element of the pair corresponds to a normalized value of z
#  |          from 0-1  (i.e. (z-zmin)/(zmax-zmin)), and the second element of
#  |          pair corresponds to a color.
#  |
#  |          Examples:
#  |              ['Greys', [[0, 'rgb(0,0,0)'], [1, 'rgb(255,255,255)']], [[0,
#  |              'rgb(8, 29, 88)'], [0.125, 'rgb(37, 52, 148)'], [0.25, 'rgb(34,
#  |              94, 168)'], [0.375, 'rgb(29, 145, 192)'], [0.5, 'rgb(65, 182,
#  |              196)'], [0.625, 'rgb(127, 205, 187)'], [0.75, 'rgb(199, 233,
#  |              180)'], [0.875, 'rgb(237, 248, 217)'], [1, 'rgb(255, 255,
#  |              217)']]]
#  |
#  |      reversescl [required=False] (value=Aw, snap! Undocumented!):
#  |          Aw, snap! Undocumented!
#  |
#  |      colorbar [required=False] (value=ColorBar object | dictionary-like):
#  |          This object represents a color bar that will be shown on the figure
#  |          where the color is related to the data being shown.
#  |
#  |          For more, run `help(plotly.graph_objs.ColorBar)`
#  |
#  |      name [required=False] (value=string):
#  |          The label associated with this trace. This name will appear in the
#  |          legend, in the column header in the spreadsheet, and on hover.
#  |
#  |      marker [required=False] (value=Marker object | dictionary-like):
#  |          Aw, snap! Undocumented!
#  |
#  |          For more, run `help(plotly.graph_objs.Marker)`
#  |
#  |      line [required=False] (value=Line object | dictionary-like):
#  |          Aw, snap! Undocumented!
#  |
#  |          For more, run `help(plotly.graph_objs.Line)`
#  |
#  |      autobinx [required=False] (value=bool: True | False):
#  |          Toggle whether or not to allow plotly to automatically pick the bin
#  |          sizing in the x direction for this histogram.
#  |
#  |      autobiny [required=False] (value=bool: True | False):
#  |          Toggle whether or not to allow plotly to automatically pick the bin
#  |          sizing in the y direction for this histogram.
#  |
#  |      xbins [required=False] (value=XBins object | dictionary-like):
#  |          A dictionary-like object explaining how the bins should be created
#  |          in the x direction for this histogram.
#  |
#  |          For more, run `help(plotly.graph_objs.XBins)`
#  |
#  |      ybins [required=False] (value=YBins object | dictionary-like):
#  |          A dictionary-like object explaining how the bins should be created
#  |          in the y direction for this histogram.
#  |
#  |          For more, run `help(plotly.graph_objs.YBins)`
#  |
#  |      nbinsx [required=False] (value=number: x > 0):
#  |          Specifies the number of bins in the x-direction.
#  |
#  |      nbinsy [required=False] (value=number: x > 0):
#  |          Specifies the number of bins in the y-direction.
#  |
#  |      histnorm [required=Aw, snap! Undocumented!] (value='' | 'percent' |
#  |      'probability' | 'density' | 'probability density'):
#  |          If histnorm is not specified, or histnorm='' (empty string), the
#  |          height of each bar displays the frequency of occurrence, i.e., the
#  |          number of times this value was found in the corresponding bin. If
#  |          histnorm='percent', the height of each bar displays the percentage
#  |          of total occurrences found within the corresponding bin. If
#  |          histnorm='probability', the height of each bar displays the
#  |          probability that an event will fall into the corresponding bin. If
#  |          histnorm='density', the height of each bar is equal to the number of
#  |          occurrences in a bin divided by the size of the bin interval such
#  |          that summing the area of all bins will yield the total number of
#  |          occurrences. If histnorm='probability density', the height of each
#  |          bar is equal to the number of probability that an event will fall
#  |          into the corresponding bin divided by the size of the bin interval
#  |          such that summing the area of all bins will yield 1, i.e. an event
#  |          must fall into one of the bins.
#  |
#  |      showlegend [required=False] (value=bool: True | False):
#  |          Toggle whether or not this trace will show up in the legend.
#  |
#  |      xaxis [required=False] (value=string: 'x1' | 'x2' | 'x3' | etc.):
#  |          This key determines which xaxis the x coordinates in this trace will
#  |          reference in the figure. 'x' references layout['xaxis'] and 'x2'
#  |          references layout['xaxis2']. 'x1' will always refer to
#  |          layout['xaxis'] or layout['xaxis1'], they are the same.
#  |
#  |      yaxis [required=False] (value=string: 'y1' | 'y2' | 'y3' | etc.):
#  |          This key determines which yaxis the y coordinates in this trace will
#  |          reference in the figure. 'y' references layout['yaxis'] and 'y2'
#  |          references layout['yaxis2']. 'y1' will always refer to
#  |          layout['yaxis'] or layout['yaxis1'], they are the same.
#  |
#  |      visible [required=False] (value=bool: True | False):
#  |          Toggles whether this will actually be visible in the rendered
#  |          figure.
#  |
#  |      showscale [required=False] (value=bool: True | False):
#  |          Toggle whether or not the color scale associated with this mapping
#  |          will be shown alongside the rendered figure.
#  |
#  |      stream [required=False] (value=dictionary-like):
#  |          The stream dict that initializes traces as writable-streams, for use
#  |          with the real-time streaming API. See examples here:
#  |          http://nbviewer.ipython.org/github/plotly/Streaming-Demos
#  |
#  |      type [required=True] (value=histogram2d):
#  |          Plotly identifier for this data's trace type. This defines how this
#  |          data dictionary will be handled. For example, 'scatter' type expects
#  |          x and y data-arrays corresponding to (x, y) coordinates wheras a
#  |          'histogram' only requires a single x or y array and a 'heatmap' type
#  |          requires a z matrix.
#  |
#  |  Method resolution order:
#  |      Histogram2d
#  |      PlotlyTrace
#  |      PlotlyDict
#  |      __builtin__.dict
#  |      __builtin__.object
#  |
#  |  Methods inherited from PlotlyTrace:
#  |
#  |  __init__(self, *args, **kwargs)
#  |
#  |  to_string(self, level=0, indent=4, eol='\n', pretty=True, max_chars=80)
#  |      Returns a formatted string showing graph_obj constructors.
#  |
#  |              Example:
#  |
#  |                  print obj.to_string()
#  |
#  |              Keyword arguments:
#  |              level (default = 0) -- set number of indentations to start with
#  |              indent (default = 4) -- set indentation amount
#  |              eol (default = '
#  |      ') -- set end of line character(s)
#  |              pretty (default = True) -- curtail long list output with a '...'
#  |              max_chars (default = 80) -- set max characters per line
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from PlotlyDict:
#  |
#  |  force_clean(self, caller=True)
#  |      Attempts to convert to graph_objs and call force_clean() on values.
#  |
#  |      Calling force_clean() on a PlotlyDict will ensure that the object is
#  |      valid and may be sent to plotly. This process will also remove any
#  |      entries that end up with a length == 0.
#  |
#  |      Careful! This will delete any invalid entries *silently*.
#  |
#  |  get_data(self)
#  |      Returns the JSON for the plot with non-data elements stripped.
#  |
#  |  get_ordered(self, caller=True)
#  |
#  |  strip_style(self)
#  |      Strip style from the current representation.
#  |
#  |      All PlotlyDicts and PlotlyLists are guaranteed to survive the
#  |      stripping process, though they made be left empty. This is allowable.
#  |
#  |      Keys that will be stripped in this process are tagged with
#  |      `'type': 'style'` in the INFO dictionary listed in graph_objs_meta.py.
#  |
#  |      This process first attempts to convert nested collections from dicts
#  |      or lists to subclasses of PlotlyList/PlotlyDict. This process forces
#  |      a validation, which may throw exceptions.
#  |
#  |      Then, each of these objects call `strip_style` on themselves and so
#  |      on, recursively until the entire structure has been validated and
#  |      stripped.
#  |
#  |  to_graph_objs(self, caller=True)
#  |      Walk obj, convert dicts and lists to plotly graph objs.
#  |
#  |      For each key in the object, if it corresponds to a special key that
#  |      should be associated with a graph object, the ordinary dict or list
#  |      will be reinitialized as a special PlotlyDict or PlotlyList of the
#  |      appropriate `kind`.
#  |
#  |  update(self, dict1=None, **dict2)
#  |      Update current dict with dict1 and then dict2.
#  |
#  |      This recursively updates the structure of the original dictionary-like
#  |      object with the new entries in the second and third objects. This
#  |      allows users to update with large, nested structures.
#  |
#  |      Note, because the dict2 packs up all the keyword arguments, you can
#  |      specify the changes as a list of keyword agruments.
#  |
#  |      Examples:
#  |      # update with dict
#  |      obj = Layout(title='my title', xaxis=XAxis(range=[0,1], domain=[0,1]))
#  |      update_dict = dict(title='new title', xaxis=dict(domain=[0,.8]))
#  |      obj.update(update_dict)
#  |      obj
#  |      {'title': 'new title', 'xaxis': {'range': [0,1], 'domain': [0,.8]}}
#  |
#  |      # update with list of keyword arguments
#  |      obj = Layout(title='my title', xaxis=XAxis(range=[0,1], domain=[0,1]))
#  |      obj.update(title='new title', xaxis=dict(domain=[0,.8]))
#  |      obj
#  |      {'title': 'new title', 'xaxis': {'range': [0,1], 'domain': [0,.8]}}
#  |
#  |      This 'fully' supports duck-typing in that the call signature is
#  |      identical, however this differs slightly from the normal update
#  |      method provided by Python's dictionaries.
#  |
#  |  validate(self, caller=True)
#  |      Recursively check the validity of the keys in a PlotlyDict.
#  |
#  |      The valid keys constitute the entries in each object
#  |      dictionary in INFO stored in graph_objs_meta.py.
#  |
#  |      The validation process first requires that all nested collections be
#  |      converted to the appropriate subclass of PlotlyDict/PlotlyList. Then,
#  |      each of these objects call `validate` and so on, recursively,
#  |      until the entire object has been validated.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from PlotlyDict:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes inherited from PlotlyDict:
#  |
#  |  __metaclass__ = <class 'plotly.graph_objs.graph_objs.DictMeta'>
#  |      A meta class for PlotlyDict class creation.
#  |
#  |      The sole purpose of this meta class is to properly create the __doc__
#  |      attribute so that running help(Obj), where Obj is a subclass of PlotlyDict,
#  |      will return information about key-value pairs for that object.
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from __builtin__.dict:
#  |
#  |  __cmp__(...)
#  |      x.__cmp__(y) <==> cmp(x,y)
#  |
#  |  __contains__(...)
#  |      D.__contains__(k) -> True if D has a key k, else False
#  |
#  |  __delitem__(...)
#  |      x.__delitem__(y) <==> del x[y]
#  |
#  |  __eq__(...)
#  |      x.__eq__(y) <==> x==y
#  |
#  |  __ge__(...)
#  |      x.__ge__(y) <==> x>=y
#  |
#  |  __getattribute__(...)
#  |      x.__getattribute__('name') <==> x.name
#  |
#  |  __getitem__(...)
#  |      x.__getitem__(y) <==> x[y]
#  |
#  |  __gt__(...)
#  |      x.__gt__(y) <==> x>y
#  |
#  |  __iter__(...)
#  |      x.__iter__() <==> iter(x)
#  |
#  |  __le__(...)
#  |      x.__le__(y) <==> x<=y
#  |
#  |  __len__(...)
#  |      x.__len__() <==> len(x)
#  |
#  |  __lt__(...)
#  |      x.__lt__(y) <==> x<y
#  |
#  |  __ne__(...)
#  |      x.__ne__(y) <==> x!=y
#  |
#  |  __repr__(...)
#  |      x.__repr__() <==> repr(x)
#  |
#  |  __setitem__(...)
#  |      x.__setitem__(i, y) <==> x[i]=y
#  |
#  |  __sizeof__(...)
#  |      D.__sizeof__() -> size of D in memory, in bytes
#  |
#  |  clear(...)
#  |      D.clear() -> None.  Remove all items from D.
#  |
#  |  copy(...)
#  |      D.copy() -> a shallow copy of D
#  |
#  |  fromkeys(...)
#  |      dict.fromkeys(S[,v]) -> New dict with keys from S and values equal to v.
#  |      v defaults to None.
#  |
#  |  get(...)
#  |      D.get(k[,d]) -> D[k] if k in D, else d.  d defaults to None.
#  |
#  |  has_key(...)
#  |      D.has_key(k) -> True if D has a key k, else False
#  |
#  |  items(...)
#  |      D.items() -> list of D's (key, value) pairs, as 2-tuples
#  |
#  |  iteritems(...)
#  |      D.iteritems() -> an iterator over the (key, value) items of D
#  |
#  |  iterkeys(...)
#  |      D.iterkeys() -> an iterator over the keys of D
#  |
#  |  itervalues(...)
#  |      D.itervalues() -> an iterator over the values of D
#  |
#  |  keys(...)
#  |      D.keys() -> list of D's keys
#  |
#  |  pop(...)
#  |      D.pop(k[,d]) -> v, remove specified key and return the corresponding value.
#  |      If key is not found, d is returned if given, otherwise KeyError is raised
#  |
#  |  popitem(...)
#  |      D.popitem() -> (k, v), remove and return some (key, value) pair as a
#  |      2-tuple; but raise KeyError if D is empty.
#  |
#  |  setdefault(...)
#  |      D.setdefault(k[,d]) -> D.get(k,d), also set D[k]=d if k not in D
#  |
#  |  values(...)
#  |      D.values() -> list of D's values
#  |
#  |  viewitems(...)
#  |      D.viewitems() -> a set-like object providing a view on D's items
#  |
#  |  viewkeys(...)
#  |      D.viewkeys() -> a set-like object providing a view on D's keys
#  |
#  |  viewvalues(...)
#  |      D.viewvalues() -> an object providing a view on D's values
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes inherited from __builtin__.dict:
#  |
#  |  __hash__ = None
#  |
#  |  __new__ = <built-in method __new__ of type object>
#  |      T.__new__(S, ...) -> a new object with type S, a subtype of T

# %% [markdown]
# We link a given trace object to a particular axis by setting the `'xaxis'` and `'yaxis'` keys. Note that the default xaxis value is `'x1'` and the default yaxis value is `'y1'`; they're only explicitly shown below for clarity.

# %%
# Generate show random data 
x = np.random.logistic(loc=-2, scale=.8, size=10000)
y = np.random.randn(10000)

# Make histogram objects
hist2d = Histogram2d(x=x,  # data
                     y=y,  # data
                     xaxis='x1',   # x-axis for data (default)
                     yaxis='y1')   # y-axis (default)
histx = Histogram(x=x,         # (NEW!) bind data to x-axis
                  xaxis='x1',  # x-axis 
                  yaxis='y2',  # y-axis
                  orientation='v')  # (NEW!) vert. bars (default when x is set)
histy = Histogram(y=y,            # (NEW!) bind data to y-axis
                  xaxis='x2',     # x-axis
                  yaxis='y1',     # y-axis
                  orientation='h')  # (NEW!) horiz. bars (default when only y is set)

# Make Data object, using the three histogram objects
my_data = Data([hist2d, histx, histy])

# Make axes objects
my_xaxis1 = XAxis(domain=[0, .7])   # set domain of each axis
my_yaxis1 = YAxis(domain=[0, .7])
my_xaxis2 = XAxis(domain=[.75, 1])
my_yaxis2 = YAxis(domain=[.75, 1])

# Make Layout object, usingthe four axis objects
my_layout = Layout(showlegend=False,  # remove legend
                xaxis1=my_xaxis1,     # set axes
                xaxis2=my_xaxis2, 
                yaxis1=my_yaxis1, 
                yaxis2=my_yaxis2)

# Make figure object, send to Plotly and show plot in notebook
my_fig = Figure(data=my_data, layout=my_layout)
py.iplot(my_fig, filename='s0_hist-subs')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~etpinard/212" height="525" width="100%"></iframe>

# %% [markdown]
# Now, because the x-axis is shared between the `Histogram2d` object and the orange `Histogram` object, zooming and panning in the x-direction will effect both of these objects simultaneously. This is because they indeed share this x-axis. Again, it's best not to think of these as separate subplots, but data plotted on different axes.
#
# To be even clearer, press the shift button and click and drag on the green `Histogram` object in the x-direction. Notice that nothing else moves when you perform this action. This is because the only data referencing this second xaxis is the data in the `Histogram` object.
#
# Not bad.

# %% [markdown]
# ##### Get subplot axes

# %% [markdown]
# Although the way Plotly handles multiple axes/subplots is powerful, if you're just looking to setup a simple grid of subplots, the API now offers a simpler way to do so.
#
# The new `get_subplots()` function allows you to intuitively setup grids of subplots. To do this, use the get_subplots function from the `plotly.tools` module. This returns an instantiated Figure object with the axes domains mapped out for you.
#
# In addition, including the keyword argument, `print_grid=True`, will print out a tab-delimited reference to the subplot grid that was returned to you. This is quite useful for setting each traces' axes afterwords.
#
# For example, let's make a 3 row by 2 column grid:

# %%
# Generate Figure object with 3x2 subplot grid
my_fig = tls.get_subplots(rows=3, columns=2, print_grid=True)
# Out:
# This is the format of your plot grid!
# [5]	[6]
# [3]	[4]
# [1]	[2]

# %% [markdown]
# Let's print out that Figure object:

# %%
# Print figure object to stdout
print my_fig.to_string()
# Out:
# Figure(
#     data=Data(),
#     layout=Layout(
#         xaxis1=XAxis(
#             domain=[0.0, 0.45],
#             anchor='y1'
#         ),
#         xaxis2=XAxis(
#             domain=[0.55, 1.0],
#             anchor='y2'
#         ),
#         xaxis3=XAxis(
#             domain=[0.0, 0.45],
#             anchor='y3'
#         ),
#         xaxis4=XAxis(
#             domain=[0.55, 1.0],
#             anchor='y4'
#         ),
#         xaxis5=XAxis(
#             domain=[0.0, 0.45],
#             anchor='y5'
#         ),
#         xaxis6=XAxis(
#             domain=[0.55, 1.0],
#             anchor='y6'
#         ),
#         yaxis1=YAxis(
#             domain=[0.0, 0.2333333333333333],
#             anchor='x1'
#         ),
#         yaxis2=YAxis(
#             domain=[0.0, 0.2333333333333333],
#             anchor='x2'
#         ),
#         yaxis3=YAxis(
#             domain=[0.3833333333333333, 0.6166666666666666],
#             anchor='x3'
#         ),
#         yaxis4=YAxis(
#             domain=[0.3833333333333333, 0.6166666666666666],
#             anchor='x4'
#         ),
#         yaxis5=YAxis(
#             domain=[0.7666666666666666, 0.9999999999999999],
#             anchor='x5'
#         ),
#         yaxis6=YAxis(
#             domain=[0.7666666666666666, 0.9999999999999999],
#             anchor='x6'
#         )
#     )
# )

# %% [markdown]
# The 3x2 grid creates 6 individual subplots which are referenced by `'xaxis1'`, `'yaxis1'`, etc. keys and the `'x2'`, `'y2'`, etc. values with no tricky list comprehension required!
#
# Please note
#
# > Axes indexting starts at 1 in Plotly, unlike in Python. Using keys `'xaxis0'` and `'yaxis0'` in the layout graph object will result in errors.
#
# Note also that `get_subplots()` allows users to set the vertical and horizontal spacing between the subplots with the `vertical_spacing` and `horizontal_spacing` keyword arguments.
#
# So, add data to the `'data'` key in this figure object and plot the result:

# %%
# (*) Import the Bar graph object
from plotly.graph_objs import Bar

# %%
splts = range(1,7)  # subplot indices --- subplot indexing starts at 1

# Update 'data' key object with list of Bar objects links to different axes
my_fig['data'] = Data([Bar(name='trace{}'.format(splt), # fills in '{}' w/ str(splt)
                        x=range(1,6),
                        y=np.random.rand(5)*10,
                        xaxis='x{}'.format(splt),
                        yaxis='y{}'.format(splt)) for splt in splts])

# Remove legend by updating 'layout' key
my_fig['layout'].update({'showlegend':False})

# Send figure object to plotly, show plot in notebook
py.iplot(my_fig, filename='s0_tiny-boxes-on-the-hillside')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~etpinard/213" height="525" width="100%"></iframe>

# %% [markdown]
# Nice.
#
# Plotly subplots are now very easy to generate.

# %% [markdown]
# ##### Other version 1.0 additions

# %% [markdown]
# A complete list of changes and compatibility issues from version 0.5 to version 1.0 of Plotly's Python API can be found <a href="https://github.com/plotly/python-api/blob/master/compatibility.md">here</a>.
#
# We note:
#
# * When defining a filename in the  `.plot()` or `.iplot()` call `fileopt` is automatically set to `'overwrite'`. So, any existing plot with that filename will be overwritten.
#
# * The `.ion()` and `.ioff()` methods have been depreciated. You should now use the `auto_open` keyword argument in `.plot()` or `.iplot()`.
#
# * Keys `'xaxis'` and `'xaxis1'` refer to same axis; figure objects containing subplots are consistant with figure objects containing a single plot. Similarly, references to first axis used to required `'x'`, but now allow `'x1'` to refer to the same axis.
#
# * The `Histogram` graph object merges functionality of the old `'histogramx'` and `'histogramy'` plot type.
#
# * Horizontal bar charts and histograms are achieved with the `'orientation'` key (not `'bardir'` any more) in `Bar` or `Histogram` objects.
#
# * Horizontal error bars (with the `ErrorX` graph object) and asymmetric error bars are now supported in version 1.0.19 and up.
#
# * The `plotly.display()` function is depreciated. Use `tls.embed()` to embed a Plotly plot inside an IPython notebook or use `tls.get_embed()` to print the `<iframe>` HTML code to embed a Plotly plot on a web page.

# %% [markdown]
# <hr>
#
# <h4 style="font-size:14pt;">Go to
#
# [Section 2 --- Bar Charts](http://nbviewer.ipython.org/github/plotly/python-user-guide/blob/master/s2_bar-charts/s2_bar-charts.ipynb) </h4>
#
# <h4 style="font-size:14pt;">Go to
#
# [top of page](#Plotly's-Python-API-User-Guide) </h4>
#
# <h4 style="font-size:14pt;">Go to User Guide's
#
# [homepage](http://nbviewer.ipython.org/github/plotly/python-user-guide/blob/master/s00_homepage/s00_homepage.ipynb) </h4>
#
# <hr>
#
# <!-- <h4 style="font-size:14pt;">Go to
#
# [Section 1 Line & Scatter Plots (http://nbviewer.ipython.org/github/plotly/python-user-guide/blob/master/s1_line-scatter/s1_line-scatter.ipynb) </h4> -->

# %% [markdown]
# <div style="float:right; \">
#     <img src="http://i.imgur.com/4vwuxdJ.png"
#  align=right style="float:right; margin-left: 5px; margin-top: -10px" />
# </div>
#
# <h4>Got Questions or Feedback? </h4>
#
# About <a href="https://plot.ly" target="_blank">Plotly</a>
#
# * email: feedback@plot.ly
# * tweet:
# <a href="https://twitter.com/plotlygraphs" target="_blank">@plotlygraphs</a>
#
# About the <a href="https://github.com/plotly/python-user-guide" target="_blank">User Guide</a>
#
# * email: etienne@plot.ly
# * tweet: <a href="https://twitter.com/etpinard" target="_blank">@etpinard</a>
#
# <h4 style="margin-top:30px;">Notebook styling ideas</h4>
#
# Big thanks to
#
# * <a href="http://nbviewer.ipython.org/github/CamDavidsonPilon/Probabilistic-Programming-and-Bayesian-Methods-for-Hackers/blob/master/Prologue/Prologue.ipynb" target="_blank">Cam Davidson-Pilon</a>
# * <a href="http://lorenabarba.com/blog/announcing-aeropython/#.U1ULXdX1LJ4.google_plusone_share" target="_blank">Lorena A. Barba</a>
#
# <br>

# %%
# CSS styling within IPython notebook
from IPython.core.display import HTML
def css_styling():
    styles = open("../custom.css", "r").read()
    return HTML(styles)
css_styling()
# Out:
# <style>
#     /*body {
#         background-color: #F5F5F5;
#     }*/
#     div.cell{
#         width: 850px;
#         margin-left: 10% !important;
#         margin-right: auto;
#     }
#     h1 {
#         font-family: "Open sans",verdana,arial,sans-serif;
#     }
#     .text_cell_render h1 {
#         font-weight: 200;
#         font-size: 40pt;
#         line-height: 100%;
#         color:#447adb;
#         margin-bottom: 0em;
#         margin-top: 0em;
#         display: block;
#         white-space: nowrap;
#     }
#     h2 {
#         font-family: "Open sans",verdana,arial,sans-serif;
#         text-indent:1em;
#     }
#     .text_cell_render h2 {
#         font-weight: 200;
#         font-size: 20pt;
#         font-style: italic;
#         line-height: 100%;
#         color:#447adb;
#         margin-bottom: 1.5em;
#         margin-top: 0.5em;
#         display: block;
#         white-space: nowrap;
#     }
#     h3 {
#         font-family: "Open sans",verdana,arial,sans-serif;
#     }
#     .text_cell_render h3 {
#         font-weight: 300;
#         font-size: 18pt;
#         line-height: 100%;
#         color:#447adb;
#         margin-bottom: 0.5em;
#         margin-top: 2em;
#         display: block;
#         white-space: nowrap;
#     }
#     h4 {
#         font-family: "Open sans",verdana,arial,sans-serif;
#     }
#     .text_cell_render h4 {
#         font-weight: 300;
#         font-size: 16pt;
#         color:#447adb;
#         margin-bottom: 0.5em;
#         margin-top: 0.5em;
#         display: block;
#         white-space: nowrap;
#     }
#     h5 {
#         font-family: "Open sans",verdana,arial,sans-serif;
#     }
#     .text_cell_render h5 {
#         font-weight: 300;
#         font-style: normal;
#         color: #1d3b84;
#         font-size: 16pt;
#         margin-bottom: 0em;
#         margin-top: 1.5em;
#         display: block;
#         white-space: nowrap;
#     }
#     div.text_cell_render{
#         font-family: "Open sans",verdana,arial,sans-serif;
#         line-height: 135%;
#         font-size: 125%;
#         width:750px;
#         margin-left:auto;
#         margin-right:auto;
#         text-align:justify;
#         text-justify:inter-word;
#     }
#     div.output_subarea.output_text.output_pyout {
#         overflow-x: auto;
#         overflow-y: scroll;
#         max-height: 300px;
#     }
#     div.output_subarea.output_stream.output_stdout.output_text {
#         overflow-x: auto;
#         overflow-y: scroll;
#         max-height: 300px;
#     }
#     div.output_subarea.output_html.rendered_html {
#         overflow-x: scroll;
#         max-width: 100%;
#     }
#     code{
#       font-size: 78%;
#     }
#     .rendered_html code{
#     background-color: transparent;
#     }
#     ul{
#         /* color:#447adb; */
#         margin: 2em;
#     }
#     ul li{
#         padding-left: 0.5em;
#         margin-bottom: 0.5em;
#         margin-top: 0.5em;
#     }
#     ul li li{
#         padding-left: 0.2em;
#         margin-bottom: 0.2em;
#         margin-top: 0.2em;
#     }
#     ol{
#         /* color:#447adb; */
#         margin: 2em;
#     }
#     ol li{
#         padding-left: 0.5em;
#         margin-bottom: 0.5em;
#         margin-top: 0.5em;
#     }
#     /*.prompt{
#         display: None;
#     } */
#     ul li{
#         padding-left: 0.5em;
#         margin-bottom: 0.5em;
#         margin-top: 0.2em;
#     }
#     a:link{
#        font-weight: bold;
#        color:#447adb;
#     }
#     a:visited{
#        font-weight: bold;
#        color: #1d3b84;
#     }
#     a:hover{
#        font-weight: bold;
#        color: #1d3b84;
#     }
#     a:focus{
#        font-weight: bold;
#        color:#447adb;
#     }
#     a:active{
#        font-weight: bold;
#        color:#447adb;
#     }
#     .rendered_html :link {
#        text-decoration: none;
#     }
#     .rendered_html :hover {
#        text-decoration: none;
#     }
#     .rendered_html :visited {
#       text-decoration: none;
#     }
#     .rendered_html :focus {
#       text-decoration: none;
#     }
#     .rendered_html :active {
#       text-decoration: none;
#     }
#     .warning{
#         color: rgb( 240, 20, 20 )
#     }
#     hr {
#       color: #f3f3f3;
#       background-color: #f3f3f3;
#       height: 1px;
#     }
#     blockquote{
#       display:block;
#       background: #f3f3f3;
#       font-family: "Open sans",verdana,arial,sans-serif;
#       width:610px;
#       padding: 15px 15px 15px 15px;
#       text-align:justify;
#       text-justify:inter-word;
#       }
#       blockquote p {
#         margin-bottom: 0;
#         line-height: 125%;
#         font-size: 100%;
#       }
#    /* element.style {
#     } */
# </style>
# <script>
#     MathJax.Hub.Config({
#                         TeX: {
#                            extensions: ["AMSmath.js"]
#                            },
#                 tex2jax: {
#                     inlineMath: [ ["$","$"], ["\\(","\\)"] ],
#                     displayMath: [ ["$$","$$"], ["\\[","\\]"] ]
#                 },
#                 displayAlign: "center", // Change this to "center" to center equations.
#                 "HTML-CSS": {
#                     styles: {".MathJax_Display": {"margin": 4}}
#                 }
#         });
# </script>
