# %% [markdown]
# # Section 3: Bubble Charts

# %% [markdown]
# Welcome to Plotly's *Python API User Guide*.
#
# > Links to the other sections can be found on the User Guide's [homepage](http://nbviewer.ipython.org/github/etpinard/plotly-python-doc/blob/master/s0_getting-started/s0_getting-started.ipynb) <br>
# and the full Github repository is available
# <a href="https://github.com/etpinard/plotly-python-doc/tree/1.0" target="_blank">here</a>.
#
# <hr>

# %% [markdown]
# This time we will use the Pandas python module for data manipulation

# %%
import plotly.plotly as py  # (New syntax!) tools to communicate with Plotly's server
import plotly.tools as tls  # (NEW!) useful Python/Plotly tools 

# (NEW!) objects to piece together plots
from plotly.graph_objs import Data, Layout, Figure

import numpy as np  # numpy (for math functions and arrays, here)
import pandas as pd # Pandas for data manipulation

my_creds = tls.get_credentials_file()                  # read credentials
py.sign_in(my_creds['username'], my_creds['api_key'])  # (New syntax!) Plotly sign in

# Check Plolty version (if not 1.0, please upgrade)
py.__version__
# Out:
# '1.0.0'

# %% [markdown]
# First get the data: It can be downloaded <a href="http://www.stat.ubc.ca/~jenny/notOcto/STAT545A/examples/gapminder/data/gapminderDataFiveYear.txt" target="_blank">here</a> or on the User Guide's Github <a href="https://github.com/etpinard/plotly-python-doc/tree/1.0/s3_bubble-charts" target="_blank">repository</a>.
#
# Note that the files were originally downloaded <a href="http://www.stat.ubc.ca/~jenny/notOcto/STAT545A/examples/gapminder/data/gapminderDataFiveYear.txt" target="_blank">here</a>.

# %%
# Read csv file and define pandas object (df for dataframe)
df = pd.read_csv('gapminderDataFiveYear.txt',sep='\t')

# 
df.head()

from plotly.graph_objs import Scatter
help(Scatter)
# Out:
# Help on class Scatter in module plotly.graph_objs:
#
# class Scatter(_PlotlyTrace)
#  |  A dictionary-like object for representing a scatter plot in plotly.
#  |
#  |      Example:
#  |
#  |          py.plot([Scatter(name='tacters', x=[1,4,2,3], y=[1,6,2,1])])
#  |
#  |
#  |  Quick method reference:
#  |
#  |      Scatter.update(dict1, **dict2)
#  |      Scatter.strip_style()
#  |      Scatter.get_data()
#  |      Scatter.to_graph_objs()
#  |      Scatter.validate()
#  |      Scatter.force_clean()
#  |
#  |  Valid keys:
#  |
#  |      x [required=True] (value=array_like of numbers, strings, datetimes):
#  |          The x coordinates from the (x,y) pair on the scatter plot.
#  |
#  |      y [required=True] (value=array_like of numbers, strings, datetimes):
#  |          The y coordinates from the (x,y) pair on the scatter plot.
#  |
#  |      text [required=False] (value=array_like of strings):
#  |          The text elements associated with every (x,y) pair on the scatter
# ...

# %% [markdown]
# #### 3.1 A first Bubble Chart

# %% [markdown]
# Bubble charts a great for ...
#
# Ok so let's try to ...
#
# * Life expentancy as a function of GDP per capita, for all countries in file
# * Marker size increses with population size
# * Marker colors correspond to different continents

# %%
# (*) Graph objects required for the following plot
from plotly.graph_objs import Scatter, Marker, Line, Font, XAxis, YAxis

# Choose a year, find other years with df['year'].unique()
the_year = 2007   

# Find indices corresponding to 'the_year'
i_good = (df['year']==the_year)

# Grab all rows correponding to 'the_year'
df_good = df[i_good] 

# Find the maximum population count (used to compute bubble sizes)
pop_max = df_good['pop'].max()

## Let's define a few functions to help us build the data object

# (a) Bubble size as a function of population (returns list of numbers)
def bubble_size(pop,pop_max):
    bubble_size_max = 100  # maximum bubble size (arbitrary)
    return [ np.sqrt(j/pop_max)*bubble_size_max for j in pop ]  # square root scaling 

# (b) Dictionary of colors, 1 for each continent, color scale taken from d3's 'category10'
cmap = {'Asia':'#1f77b4', 'Europe':'#ff7f0e', 'Africa':'#2ca02c',
        'Americas':'#d62728','Oceania':'#9467bd'}

# (c) Hover-text generating function (returns a list of strings)
def make_text(X):
    return  'Country: %s<br>Life Expectancy: %s years<br>GDP\
             per capita: %s $<br>Population: %s million' \
             % (X['country'], X['lifeExp'], X['gdpPercap'], X['pop']/1e6)

# (d) Trace-generating function (returns a Scatter object)
def make_trace(X,name_in,size_in,color_in,text_in):  
    return Scatter(x=X['gdpPercap']/1000.,  #
                   y=X['lifeExp'],          # 
                   mode='markers',          #
                   name=name_in,            #
                   text=text_in,            #
                   marker= Marker(color=color_in,         #
                                  size=size_in,           #
                                  opacity=0.7,            #
                                  line= Line(width=0.0))
                                  #             #
                  )

# Initialize data object
my_data = Data([])

# Group data by continent, build one trace per continent
for cont_name, X in df_good.groupby('continent'):
    my_size = bubble_size(X['pop'],pop_max)                  # get bubble sizes
    my_color = cmap[cont_name]                               # get marker color
    my_text = X.apply(make_text,axis=1).tolist()             # get hover text 
    trace = make_trace(X,cont_name,my_size,my_color,my_text) # make trace dictionary
    my_data.append(trace)                                    # append to my_data object
        
# Make layout object
my_layout = Layout(title='Fig.7: Life Expectancy versus GDP \
                          per Capita in '+str(the_year),  # set plot title
                   font= Font(family='Georgia, serif',    # set global font family
                              color='#635F5D'),           #   and color
                   showlegend=False,    # remove legend
                   hovermode='closest', # info about closest data point appears on hover    
                   plot_bgcolor='#EFECEA',  # set plot color to grey
                   xaxis= XAxis(title='Gross Domestic Product per Capita \
                                        [in 1000s of USD of 2000]',   # set x-axis title
                                zeroline=False,       # remove thick zero line
                                gridcolor='#FFFFFF',  # white grid lines
                                ticks='outside',    # draw ticks outside axes 
                                ticklen=8,          # tick length
                                tickwidth=1.5),     #   and width
                   yaxis= YAxis(title='Life Expentancy [in years]',  # set y-axis title
                                zeroline=False,       # remove thick zero line
                                gridcolor='#FFFFFF',  # white grid lines
                                ticks='outside',      # draw ticks outside axes 
                                ticklen=8,            # tick length
                                tickwidth=1.5)        #   and width  
                   )

# Make Figure object, send to Plotly and show in notebook
fig = Figure(data=my_data, layout=my_layout)
py.iplot(fig, filename='s3_life-gdp')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~etpinard/84" height="525" width="100%"></iframe>

# %% [markdown]
# * Comment on `'hovermode'` (hovermode to 'closest' to turn off showing all points near the same x on hover)
# * Comment on `'opacity'`

# %% [markdown]
# #### 3.2 Bubble chart with line fits

# %% [markdown]
# Another bar chart with the same data or with a different dataset and showing an other example of subplots (any suggestions?).
#
#
# GDP with time

# %% [markdown]
# #### 3.3 Bubble chart with multiple axes

# %% [markdown]
# <hr>
#
# **Go to** [next section](http://nbviewer.ipython.org/github/etpinard/plotly-python-doc/blob/master/s4_histograms/s4_histograms.ipynb)
#
# **Go to** [previous section](http://nbviewer.ipython.org/github/etpinard/plotly-python-doc/blob/master/s2_bar-charts/s2_bar-charts.ipynb)
#
# **Go back to User Guide's** [homepage](http://nbviewer.ipython.org/github/etpinard/plotly-python-doc/blob/master/s0_getting-started/s0_getting-started.ipynb)
#
# <hr>

# %% [markdown]
# <h4>Got Questions and Feedback? </h4>
#
# <div style="float:right; \">
#     <img src="http://i.imgur.com/i6YeveO.png"
#  align=right style="float:right; margin-left: 5px; margin-top: -20px" />
# </div>
#
# <br>
#
# About <a href="https://plot.ly" target="_blank">Plotly</a>
#
# * email: feedback@plot.ly
# * tweet:
# <a href="https://twitter.com/plotlygraphs" target="_blank">@plotlygraphs</a>
#
# About the <a href="https://github.com/etpinard/plotly-python-doc" target="_blank">User Guide</a>
#
# * email: etienne.t.pinard@gmail.com
# * tweet: <a href="https://twitter.com/etpinard" target="_blank">@etpinard</a>
#
# <h4>Big Thanks to</h4>
#
# * <a href="http://nbviewer.ipython.org/github/CamDavidsonPilon/Probabilistic-Programming-and-Bayesian-Methods-for-Hackers/blob/master/Prologue/Prologue.ipynb" target="_blank">Cam Davidson-Pilon</a> <br> for notebook styling ideas
#
# <hr>

# %%
# CSS styling within IPython notebook
from IPython.core.display import HTML
def css_styling():
    styles = open("../plotly-python-doc.css", "r").read()
    return HTML(styles)
css_styling()
# Out:
# <style>
#     @font-face {
#         font-family: "Computer Modern";
#         src: url('http://9dbb143991406a7c655e-aa5fcb0a5a4ec34cff238a2d56ca4144.r56.cf5.rackcdn.com/cmunss.otf');
#     }
#     @font-face {
#         font-family: "Computer Modern";
#         font-weight: bold;
#         src: url('http://9dbb143991406a7c655e-aa5fcb0a5a4ec34cff238a2d56ca4144.r56.cf5.rackcdn.com/cmunsx.otf');
#     }
#     @font-face {
#         font-family: "Computer Modern";
#         font-style: oblique;
#         src: url('http://9dbb143991406a7c655e-aa5fcb0a5a4ec34cff238a2d56ca4144.r56.cf5.rackcdn.com/cmunsi.otf');
#     }
#     @font-face {
#         font-family: "Computer Modern";
#         font-weight: bold;
#         font-style: oblique;
#         src: url('http://9dbb143991406a7c655e-aa5fcb0a5a4ec34cff238a2d56ca4144.r56.cf5.rackcdn.com/cmunso.otf');
#     }
#     div.cell{
#         width:800px;
#         margin-left:16% !important;
#         margin-right:auto;
#     }
#     h1 {
# ...
