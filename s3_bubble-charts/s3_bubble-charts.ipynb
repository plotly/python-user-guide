# %% [markdown]
# # Plotly's Python API User Guide

# %% [markdown]
# ## Section 3: Bubble Charts

# %% [markdown]
# Welcome to Plotly's Python API User Guide.
#
# > Links to the other sections can be found on the User Guide's [homepage](http://nbviewer.ipython.org/github/plotly/python-user-guide/blob/master/s00_homepage/s00_homepage.ipynb) <br>
# Users unfamiliar with Plotly's Python API version 1.0 see [section 0](http://nbviewer.ipython.org/github/plotly/python-user-guide/blob/master/s0_getting-started/s0_getting-started.ipynb) <br>
# The Github repository is available
# <a href="https://github.com/plotly/python-user-guide" target="_blank">here</a>

# %% [markdown]
# Section 3 is divided as follows:
#
# * [3.1 A first bubble chart](#3.1-A-first-bubble-chart)
#
# Quickstart (make a bubble charts of 3 bubbles):
#
#     >>> import plotly.plotly as py
#     >>> from plotly.graph_objs import Figure,Data,Scatter,Marker
#     >>> py.sign_in('my_username','my_api_key')
#     >>> my_markers = Marker(color=['blue','red','yellow'],
#                             size=[10,20,30])
#     >>> my_data = Data([Scatter(x=[1,2,3],y=[5,6,7],
#                                 mode='markers'
#                                 marker=my_markers)])
#     >>> my_fig = Figure(data=my_data)
#     >>> py.plot(my_fig)
#
# <hr>

# %% [markdown]
# The User Guide assumes version 1.0 of Plotly's Python API. Check which version is installed on your machine and please upgrade if needed (see the User Guide's <a href="http://nbviewer.ipython.org/github/plotly/python-user-guide/blob/master/s00_homepage/s00_homepage.ipynb#Installation-guidelines" target="_blank">homepage</a> for more info).

# %%
# Check Plolty version (if not 1.0, please upgrade)
import plotly
plotly.__version__
# Out:
# '1.0.2'

# %% [markdown]
# <hr>
#
# In this section, we analyze <a href="http://www.gapminder.org/" target="_blank">GapMinder Data</a> of life expectancy and Gross Domestic Product of all the world's countries using bubble charts. We also cover some of Plotly's marker object options, axis types and hover-mode options.
#
# We first import a few modules and sign in to Plotly using our credential file:

# %%
import plotly.plotly as py  # (New syntax!) tools to communicate with Plotly's server
import plotly.tools as tls  # (NEW!) useful Python/Plotly tools 

# (NEW!) objects to piece together plots
from plotly.graph_objs import Data, Layout, Figure

import numpy as np  # numpy (for math functions and arrays, here)

my_creds = tls.get_credentials_file()                  # read credentials
py.sign_in(my_creds['username'], my_creds['api_key'])  # (New syntax!) Plotly sign in

# %% [markdown]
# If you are not familiar with the credentials file, refer to the User Guide's <a href="http://nbviewer.ipython.org/github/plotly/python-user-guide/blob/master/s00_homepage/s00_homepage.ipynb#Installation-guidelines" target="_blank">homepage</a>.

# %% [markdown]
# The data is stored in a file called `gapminderDataFiveYear.txt`. For readers looking to run this notebook, the file is in this section's Github <a href="https://github.com/plotly/python-user-guide/blob/master/s3_bubble-charts" target="_blank">folder</a> It was originally downloaded <a href="http://www.stat.ubc.ca/~jenny/notOcto/STAT545A/examples/gapminder/data/gapminderDataFiveYear.txt" target="_blank">here</a>, thanks to <a href="http://www.stat.ubc.ca/~jenny/" target="_blank">Jennifer Bryan</a>.
#
# To help us manipulate the date, we use the `pandas` module in this section. <br>
# You can download the module using pip. Simply run:
#
#     $ pip install pandas
#
# For more info on this module, we recommand <a href="https://bitbucket.org/hrojas/learn-pandas" target="_blank">Hernán Rojas' Pandas tutorial</a>.
#
# So, first read the data and define a dataframe object:

# %%
# Pandas for data manipulation
import pandas as pd 

# Read csv file and define dataframe object (df for dataframe)
df = pd.read_csv('gapminderDataFiveYear.txt',sep='\t')

# Print dataframe header to stdout
df.head()
# Out:
#        country  year       pop continent  lifeExp   gdpPercap
# 0  Afghanistan  1952   8425333      Asia   28.801  779.445314
# 1  Afghanistan  1957   9240934      Asia   30.332  820.853030
# 2  Afghanistan  1962  10267083      Asia   31.997  853.100710
# 3  Afghanistan  1967  11537966      Asia   34.020  836.197138
# 4  Afghanistan  1972  13079460      Asia   36.088  739.981106

# %% [markdown]
# The data file gives us information about life expentancy, GDP per capita and population for several years, continents and conuntry. Would it be too much to ask to condense all this information into a single plot? Using Plotly bubble chart, the answer is no.

# %% [markdown]
# #### 3.1 A first bubble chart

# %% [markdown]
# Bubble charts a great for way to show information about several variables on a single plot. Bubble charts in Plotly are generated using the `Scatter` graph object where two variables are plotted against each other following a particular color scheme and marker size distribution (i.e. the bubbles) thus relating up to four different variables.
#
# Ok. So let's plot:
#
# * Life expentancy versus GDP per capita, for all countries in the data file, <br>
#    &nbsp; with the `'y'` and `'x'` keys in `Scatter`.
# * With marker sizes incresing with population size (making bubbles!), <br>
#     &nbsp; with the `'size'` key in the `Marker` object linked to `'marker'` in `Scatter`.
# * Marker colors correspond to different continents <br>
#     &nbsp; with the `'color'` key in the `Marker` object linked to `'marker'` in `Scatter`.
#
# Finally, to make sure that each bubble is visible, we modify the opacity of each marker. This is done by setting the `'opacity'` key in `Marker`.

# %%
# (*) Graph objects required for the following plot
from plotly.graph_objs import Scatter, Marker, Line, Font, XAxis, YAxis

# %%
help(Marker)  # run help() on Marker, notice 'color', 'size' and 'opacity'
# Out:
# Help on class Marker in module plotly.graph_objs.graph_objs:
#
# class Marker(PlotlyDict)
#  |  A dictionary-like object representing marker(s) style in plotly.
#  |
#  |
#  |  Quick method reference:
#  |
#  |      Marker.update(changes)
#  |      Marker.strip_style()
#  |      Marker.get_data()
#  |      Marker.to_graph_objs()
#  |      Marker.validate()
#  |      Marker.to_string()
#  |      Marker.force_clean()
#  |
#  |  Valid keys:
#  |
#  |      symbol [required=False] (value='dot' | 'cross' | 'diamond' | 'square' |
#  |      'triangle-down' | 'triangle-left' | 'triangle-right' | 'triangle-up' |
#  |      'x'):
#  |          The symbol that is drawn on the plot for each marker.
#  |
#  |      line [required=False] (value=Line object | Line object | dict):
#  |          A dict-like object describing the line belonging to the marker.
#  |
#  |          For more, run `help(plotly.graph_objs.Line)`
#  |
#  |      size [required=False] (value=number):
# ...

# %% [markdown]
# In the following code, we define (a) a function to compute the bubbles' sizes in relation to the population, (b) a dictionary of colors, one for each continent and (c) and a trace-generating function:

# %%
# Choose a year, find other years with df['year'].unique()
the_year = 2007   

# Find indices corresponding to 'the_year'
i_good = (df['year']==the_year)

# Grab all rows correponding to 'the_year'
df_good = df[i_good] 

# Find the maximum population count (used to compute bubble sizes)
pop_max = df_good['pop'].max()

## Define a few functions to help us build the data object

# (a) Bubble size as a function of population (returns list of numbers)
def bubble_size(pop,pop_max):
    bubble_size_max = 100  # maximum bubble size (arbitrary)
    return [np.sqrt(j/pop_max)*bubble_size_max for j in pop]  # square root scaling 

# (b) Dictionary of colors, 1 for each continent, color scale taken from d3's 'category10'
cmap = {'Asia':'#1f77b4', 'Europe':'#ff7f0e', 'Africa':'#2ca02c',
        'Americas':'#d62728','Oceania':'#9467bd'}

# (c) Trace-generating function (returns a Scatter object)
def make_trace(X,name_in,size_in,color_in):  
    return Scatter(x=X['gdpPercap'],        # GDP on the x-xaxis
                   y=X['lifeExp'],          # life Exp on th y-axis
                   mode='markers',          # N.B. point markers on this plot
                   name=name_in,            # label continent names on hover
                   marker= Marker(color=color_in, # marker color
                                  size=size_in,   # N.B. marker sizes (size_in is a list)
                                  opacity=0.7,    # N.B. partly transparent markers
                                  line= Line(width=0.0))  # remove marker borders
                  )

# Initialize Data object 
my_data = Data()

# Group data frame by continent, 
#   make one trace object per continent and append to data object
for cont_name, X in df_good.groupby('continent'):
    my_size = bubble_size(X['pop'],pop_max)                  # get bubble sizes
    my_color = cmap[cont_name]                               # get marker color
    trace = make_trace(X,cont_name,my_size,my_color)         # make 1 trace object
    my_data.append(trace)                                    # append to Data object
        
# Make layout object
my_layout = Layout(title='Fig 3.1a: Life Expectancy versus GDP \
                          per Capita in '+str(the_year),  # set plot title
                   font= Font(family='Georgia, serif',    # set global font family
                              color='#635F5D'),           #   and color 
                   plot_bgcolor='#EFECEA',   # set plot color to grey
                   xaxis= XAxis(title='Gross Domestic Product per Capita \
                                        [in USD of the year 2000]'),  # set x-axis title
                   yaxis= YAxis(title='Life Expentancy [in years]'),  # set y-axis title
                  )

# Define dictionary of axis style options
my_axes_style = dict(zeroline=False,       # remove thick zero line
                     gridcolor='#FFFFFF',  # white grid lines
                     ticks='outside',      # draw ticks outside axes 
                     ticklen=8,            # tick length
                     tickwidth=1.5)        #   and width

# Set these axis options to both axis obejcts                                 
my_layout['xaxis'].update(my_axes_style)
my_layout['yaxis'].update(my_axes_style) 
    
# Make Figure object, send to Plotly and show in notebook
my_fig = Figure(data=my_data, layout=my_layout)
py.iplot(my_fig, filename='s3_life-gdp')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~etpinard/84" height="525" width="100%"></iframe>

# %% [markdown]
# Not bad!
#
# Notice how Plotly automatically converted the x-axis units to k's (i.e. thousands) of USD. No need to change the ticks' labels here! This is quite a nice feature don't you think? Imagine having tick labels of 0, 10000, 20000, 30000, ... instead.
#
# The relationship between GDP per capita and life expentancy appears to be logarithmic. So, next, we replot our first bubble chart on log x-axis.

# %%
help(XAxis) # run help() on XAxis, notice the 'type' key!
# Out:
# Help on class XAxis in module plotly.graph_objs.graph_objs:
#
# class XAxis(PlotlyDict)
#  |  A dictionary-like object representing an xaxis in plotly.
#  |
#  |
#  |  Quick method reference:
#  |
#  |      XAxis.update(changes)
#  |      XAxis.strip_style()
#  |      XAxis.get_data()
#  |      XAxis.to_graph_objs()
#  |      XAxis.validate()
#  |      XAxis.to_string()
#  |      XAxis.force_clean()
#  |
#  |  Valid keys:
#  |
#  |      title [required=False] (value=string):
#  |          The xaxis title.
#  |
#  |      domain [required=False] (value=number array of length 2):
#  |          Sets the domain of this axis. The available space for this axis to
#  |          live in is from 0 to 1.
#  |
#  |          Examples:
#  |              [[0, 1], [0, 0.5]]
#  |
#  |      range [required=False] (value=number array of length 2):
#  |          Defines the start and end point for the axis.
#  |
#  |          Examples:
#  |              [[-13, 20], [0, 1]]
#  |
# ...

# %% [markdown]
# So, changing the axis type is as simple as adding a key-value pair in `XAxis` (or `YAxis`).
#
# Moreover, let's utilize Plotly's intractability by adding some hover text and tweaking the plot's *hover mode*.

# %%
help(Layout)  # run help() on Layout, notice 'hovermode'!
# Out:
# Help on class Layout in module plotly.graph_objs.graph_objs:
#
# class Layout(PlotlyDict)
#  |  A dictionary-like object holding plot settings for plotly figures.
#  |
#  |
#  |  Quick method reference:
#  |
#  |      Layout.update(changes)
#  |      Layout.strip_style()
#  |      Layout.get_data()
#  |      Layout.to_graph_objs()
#  |      Layout.validate()
#  |      Layout.to_string()
#  |      Layout.force_clean()
#  |
#  |  Valid keys:
#  |
#  |      title [required=False] (value=string):
#  |          The figure title.
#  |
#  |      xaxis [required=False] (value=XAxis object | dictionary-like):
#  |          The first 'xaxis' object can be entered into layout as 'xaxis' OR
#  |          'xaxis1', they're identical to plotly. After this, to create
#  |          references to new x-axes, you need to define them in the layout
#  |          dictionary.
#  |
#  |          For more, run `help(plotly.graph_objs.XAxis)`
#  |
# ...

# %% [markdown]
# By default, when hovering over a data point Plotly prints its y-value near the cursor and its x-value on the x-axis. The default behavior corresponds to `'hovermode':'x'` in `Layout`. `hovermode':'y'` gives the opposite behavior. Alternatively,
#
# > When `'hovermode'` is set to `'closest'`, information about the data point closest to where the viewer is hovering appears next to the cursor. Plotly print this info inside the same text box as the text linked to the `'text'` key (if defined) of the trace object in question.
#
# So, we make a few updates to the current figure object:

# %%
# Update 'xaxis' key, set it to log type
my_fig['layout']['xaxis'].update(dict(type='log'))

# (d) Define a hover-text generating function (returns a list of strings)
def make_text(X):
    return  'Country: %s\
             <br>Life Expectancy: %s years\
             <br>GDP per capita: %s $\
             <br>Population: %s million' \
             % (X['country'], X['lifeExp'], X['gdpPercap'], X['pop']/1e6)     
    
# Again, group data frame by continent, 
#   make one trace object per continent and append to data object
i_trace = 0  # init. trace counter
for cont_name, X in df_good.groupby('continent'):
    my_text = X.apply(make_text,axis=1).tolist()        # get list of hover texts
    my_fig['data'][i_trace].update(dict(text=my_text))  # update trace i of Figure obj.
    i_trace += 1

# Update the 'layout' key
my_fig['layout'].update(dict(showlegend=False,    # remove legend (info in hover)
                             hovermode='closest', # N.B hover -> closest data pt
                             autosize=False,  # turn off autosize
                             width=650,       # plot width
                             height=500,      # plot height
                             ))

# %% [markdown]
# The `apply()` dataframe method loops through every row (with `axis=1`) and calls a given function, in our case `make_text()`.
#
# Before sending the figure object to Plotly, add an annotation citing the data source.

# %%
# (*) Import annotation objects 
from plotly.graph_objs import Annotation, Annotations

# %%
# Add an annotation citing the data source
my_anno = Annotation(text='Data source: GapMinder 2007',  # annotation text
                     x=0.05,  # position's x-coord
                     y=0.95,  #   and y-coord
                     xref='paper',  # use paper coords
                     yref='paper',  #  for both coordinates
                     font= Font(size=14),  # increase font size (default is 12)
                     showarrow=False,      # remove arrow 
                     bgcolor='#FFFFFF',      # white background
                     borderpad=4)            # space between border and text (in pixels))

# Update 'annotations', notice that Annotations takes in a list 
my_fig['layout'].update(dict(annotations=Annotations([my_anno])))  

# Make Figure object, send to Plotly and show in notebook
py.iplot(my_fig, filename='s3_life-gdp-log')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~etpinard/191" height="525" width="100%"></iframe>

# %% [markdown]
# Not a bad-looking plot.
#
# Spend some time hovering over the bubbles and admire Plotly's interactibility!

# %% [markdown]
# #### 3.2

# %% [markdown]
# Any suggestions for other bubble charts?
#
# <br>

# %% [markdown]
# <hr>
#
# <h4 style="font-size:14pt;">Go to
#
# [Section 4 --- Histograms & Box Plots](http://nbviewer.ipython.org/github/plotly/python-user-guide/blob/master/s4_histograms/s4_histograms.ipynb) </h4>
#
# <h4 style="font-size:14pt;">Go to
#
# [Section 2 --- Bar Charts](http://nbviewer.ipython.org/github/plotly/python-user-guide/blob/master/s2_bar-charts/s2_bar-charts.ipynb) </h4>
#
# <h4 style="font-size:14pt;">Go to
#
# [top of page](#Plotly's-Python-API-User-Guide) </h4>
#
# <h4 style="font-size:14pt;">Go to User Guide's
#
# [homepage](http://nbviewer.ipython.org/github/plotly/python-user-guide/blob/master/s00_homepage/s00_homepage.ipynb) </h4>
#
# <hr>

# %% [markdown]
# <div style="float:right; \">
#     <img src="http://i.imgur.com/4vwuxdJ.png"
#  align=right style="float:right; margin-left: 5px; margin-top: -10px" />
# </div>
#
# <h4>Got Questions or Feedback? </h4>
#
# About <a href="https://plot.ly" target="_blank">Plotly</a>
#
# * email: feedback@plot.ly
# * tweet:
# <a href="https://twitter.com/plotlygraphs" target="_blank">@plotlygraphs</a>
#
# About the <a href="https://github.com/plotly/python-user-guide" target="_blank">User Guide</a>
#
# * email: etienne@plot.ly
# * tweet: <a href="https://twitter.com/etpinard" target="_blank">@etpinard</a>
#
# <h4 style="margin-top:30px;">Notebook styling ideas</h4>
#
# Big thanks to
#
# * <a href="http://nbviewer.ipython.org/github/CamDavidsonPilon/Probabilistic-Programming-and-Bayesian-Methods-for-Hackers/blob/master/Prologue/Prologue.ipynb" target="_blank">Cam Davidson-Pilon</a>
# * <a href="http://lorenabarba.com/blog/announcing-aeropython/#.U1ULXdX1LJ4.google_plusone_share" target="_blank">Lorena A. Barba</a>
#
# <br>

# %%
# CSS styling within IPython notebook
from IPython.core.display import HTML
def css_styling():
    styles = open("../custom.css", "r").read()
    return HTML(styles)
css_styling()
# Out:
# <style>
#     /*body {
#         background-color: #F5F5F5;
#     }*/
#     div.cell{
#         width: 850px;
#         margin-left: 10% !important;
#         margin-right: auto;
#     }
#     h1 {
#         font-family: 'Open sans',verdana,arial,sans-serif;
#     }
#     .text_cell_render h1 {
#         font-weight: 200;
#         font-size: 40pt;
#         line-height: 100%;
#         color:#447adb;
#         margin-bottom: 0em;
#         margin-top: 0em;
#         display: block;
#         white-space: nowrap;
#     }
#     h2 {
#         font-family: 'Open sans',verdana,arial,sans-serif;
#         text-indent:1em;
#     }
#     .text_cell_render h2 {
#         font-weight: 200;
#         font-size: 20pt;
#         font-style: italic;
#         line-height: 100%;
#         color:#447adb;
#         margin-bottom: 1.5em;
#         margin-top: 0.5em;
#         display: block;
#         white-space: nowrap;
#     }
#     h3 {
# ...
