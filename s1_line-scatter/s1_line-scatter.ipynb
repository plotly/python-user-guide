# %% [markdown]
# # Plotly's Python API User Guide

# %% [markdown]
# ## Section 1: Line & Scatter Plots

# %% [markdown]
# Welcome to Plotly's Python API User Guide.
#
# > Links to the other sections are on the User Guide's [homepage](http://nbviewer.ipython.org/github/plotly/python-user-guide/blob/master/s00_homepage/s00_homepage.ipynb#Table-of-Contents:) <br>
# If unfamiliar with Plotly's Python API version 1.0 see [section 0](http://nbviewer.ipython.org/github/plotly/python-user-guide/blob/master/s0_getting-started/s0_getting-started.ipynb) <br>
# The Github repository is available
# <a href="https://github.com/plotly/python-user-guide" target="_blank">here</a>

# %% [markdown]
# Section 1 is divided as follows:
#
# * [1.1 Basic line and scatter plots](#1.1-Basic-line-and-scatter-plots)
# * [1.2 Style and layout options](#1.2-Style-and-layout-options)
# * [1.3 Scatter plots with errors bars](#1.3-Scatter-plots-with-errors-bars)
# * [1.4 Other types of scatter plots](#1.4-Other-types-of-scatter-plots)
# * [1.5 Subplots, multiples axes and insets](#1.5-Subplots,-multiples-axes-and-insets)

# %% [markdown]
# Quickstart (make a scatter plot of 3 red squares):
#
#     >>> import plotly.plotly as py
#     >>> from plotly.graph_objs import Figure,Data,Scatter,Marker
#     >>> py.sign_in('my_username','my_api_key')
#     >>> my_marker= Marker(color='red',symbol='square')
#     >>> my_data = Data([Scatter(x=[1,2,3],y=[5,6,7],
#                                 mode='markers',
#                                 marker= my_marker)])
#     >>> my_fig = Figure(data=my_data)
#     >>> py.plot(my_fig)
#
# <hr>

# %% [markdown]
# The User Guide assumes version 1.0 of Plotly's Python API. Check which version is installed on your machine and please upgrade if needed (see the User Guide's <a href="http://nbviewer.ipython.org/github/plotly/python-user-guide/blob/master/s00_homepage/s00_homepage.ipynb#Installation-guidelines" target="_blank">homepage</a> for more info).

# %%
# Check Plolty version (if not 1.0, please upgrade)
import plotly
plotly.__version__
# Out:
# '1.0.26'

# %% [markdown]
# <hr>
#
# In this section, we cover line and scatter plots in Plotly. All datasets used in this section, are taken from the Plotly servers showcasing Plotly's Python API `get_figure()` function, introduced in <a href="http://nbviewer.ipython.org/github/plotly/python-user-guide/blob/master/s0_getting-started/s0_getting-started.ipynb#0.6-Get-figure-and-new-possible-workflows" target="_blank">section 0</a>, once more as well as presenting a sort of hall of fame of Plotly datasets.
# Additionally, we learn about:
#
# * Import ... Share your plots!!
# * Color models in Plotly (coming soon)
# * Fonts in Plotly (coming soon)

# %% [markdown]
# We first import a few modules and sign in to Plotly using our credentials file:

# %%
# (NEW!) To communicate with Plotly's server, sign in with credentials file
import plotly.plotly as py  

# (NEW!) Useful Python/Plotly tools
import plotly.tools as tls   

# (NEW!) Graph objects to piece together plots
from plotly.graph_objs import Data, Layout, Figure

import numpy as np  # numpy for math functions and arrays

# %% [markdown]
# If you are not familiar with credentials files, refer to the User Guide's  <a href="http://nbviewer.ipython.org/github/plotly/python-user-guide/blob/master/s00_homepage/s00_homepage.ipynb#Step-6" target="_blank">homepage</a>.
#
# Recall that, while being imported, the `plotly.plotly` module looks for your credentials file on your machine and automatically uses it to sign in to Plotly's servers. If more convenient, users can still manually sign in to Plotly by typing:
#
#     >>> py.sign_in('your_username','your_api_key')
#
# Once you are signed in, you do not need to communicate your username nor your API key to Plotly again in the current Python/IPython session.

# %% [markdown]
# ### 1.1 Basic line and scatter plots

# %% [markdown]
# For our first scatter plot, we use data from this <a href="http://qz.com/" target="_blank">Quartz</a> graph:

# %%
# Embed Plotly graph in notebook
#   Quartz is username of the graph's maker,
#   7 is the graph's unique id number
#   and adjust the frame's width and height in pixels
tls.embed('Quartz','7', width=700, height=500)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~Quartz/7/675/475" height="500" width="700"></iframe>

# %% [markdown]
# The above graph was featured in this Quartz <a href="http://qz.com/187350/six-charts-that-show-why-china-is-competing-with-the-multinationals-it-used-to-work-for/" target="_blank">story</a>.

# %% [markdown]
# Our first plot will present that the data using lines and points instead of bars (more on Plotly bar charts in <a href="http://nbviewer.ipython.org/github/plotly/python-user-guide/blob/master/s2_bar-charts/s2_bar-charts.ipynb" target="_blank">section 2</a>).
# As we will see, Plotly's syntax makes converting a graph from one plot type to another a breeze.
#
# So first, pull down the figure object from Plotly's servers into this IPython session using the `get_figure` function:

# %%
# Get figure object from Plotly's servers
#   Quartz is username of the graph's maker,
#   7 is the graph's unique id number
Quartz7 = py.get_figure('Quartz','7')

print Quartz7.to_string()   # print in notebook
# Out:
# Figure(
#     data=Data([
#         Bar(
#             x=['2001', '2002', '2003', '2004', '2005', '2006', '2007', '200...],
#             y=['1.1', '1.5', '2.1', '2.8', '3.4', '4.1', '5.0', '5.6', '6.1...],
#             name='China',
#             marker=Marker(
#                 color='rgb(222, 113, 88)'
#             )
#         ),
#         Bar(
#             x=['2001', '2002', '2003', '2004', '2005', '2006', '2007', '200...],
#             y=['1.3', '1.2', '1.3', '1.4', '1.5', '1.5', '1.5', '1.6', '1.6...],
#             name='U.S.',
#             marker=Marker(
#                 color='rgb(84, 172, 234)'
#             )
#         )
#     ]),
#     layout=Layout(
#         title='<br> #OF UNIVERSITY GRADUATES IN CHINA VS. U.S. (MILLIONS)',
#         xaxis=XAxis(
#             title="<i>Data: Solidiance's Analysis</i>",
#             domain=[0, 1],
#             range=[2000.5, 2012.5],
#             type='linear',
#             showline=True,
#             linecolor='#000',
# ...

# %% [markdown]
# Recall that a Plotly figure object is divided into a data object (storing data and style options associated with each trace) and a layout object (storing information associated with the axes, legend and other layout features).
#
# In this case, here, the data object contains two bar objects: one for China's numbers and one for the USA's.
#
# > Data objects are list-like, the ordering determines the order at which the individual traces are plotted. This is important to a graph's appearance if two or more traces have overlapping coordinates. By virtue of the ordering, the last trace listed in the data object appears in the foreground.
#
# So, take note that in the `Quartz7` figure object, the trace corresponding to China's numbers is the first item in the data object.
#
# Now, using the `get_data()` figure object method, retrieve the data from the figure object:

# %%
# Retrieve data from figure object (get a dictionary in return)
Quartz7_data = Quartz7.get_data()

Quartz7_data   # print in notebook
# Out:
# {'data': [{'name': 'China',
#    'x': ['2001',
#     '2002',
#     '2003',
#     '2004',
#     '2005',
#     '2006',
#     '2007',
#     '2008',
#     '2009',
#     '2010',
#     '2011',
#     '2012'],
#    'y': ['1.1',
#     '1.5',
#     '2.1',
#     '2.8',
#     '3.4',
#     '4.1',
#     '5.0',
#     '5.6',
#     '6.1',
#     '6.3',
#     '6.6',
#     '6.8']},
#   {'name': 'U.S.',
#    'x': ['2001',
#     '2002',
#     '2003',
#     '2004',
#     '2005',
#     '2006',
#     '2007',
#     '2008',
#     '2009',
#     '2010',
#     '2011',
#     '2012'],
#    'y': ['1.3',
#     '1.2',
#     '1.3',
#     '1.4',
#     '1.5',
#     '1.5',
#     '1.5',
#     '1.6',
#     '1.6',
#     '1.7',
#     '1.7',
#     '1.8']}],
#  'layout': [{}]}

# %% [markdown]
# `Quartz7_data` is a dictionary, not a Python graph object (try running `help()` on it!), ready to be placed in a different trace object such as `Scatter`, here for our next plot.
#
# Notice that both traces' `'name'` keys and their associated values are part of the `Quartz7_data` dictionary. Values linked to `'name'` are the labels in the legend. They also appear on hover next to the scatter points' coordinates.
#
# .... so ...

# %%
Quartz7_data['data'][0]   #
# Out:
# {'name': 'China',
#  'x': ['2001',
#   '2002',
#   '2003',
#   '2004',
#   '2005',
#   '2006',
#   '2007',
#   '2008',
#   '2009',
#   '2010',
#   '2011',
#   '2012'],
#  'y': ['1.1',
#   '1.5',
#   '2.1',
#   '2.8',
#   '3.4',
#   '4.1',
#   '5.0',
#   '5.6',
#   '6.1',
#   '6.3',
#   '6.6',
#   '6.8']}

# %%
Quartz7_data['data'][1]   #
# Out:
# {'name': 'U.S.',
#  'x': ['2001',
#   '2002',
#   '2003',
#   '2004',
#   '2005',
#   '2006',
#   '2007',
#   '2008',
#   '2009',
#   '2010',
#   '2011',
#   '2012'],
#  'y': ['1.3',
#   '1.2',
#   '1.3',
#   '1.4',
#   '1.5',
#   '1.5',
#   '1.5',
#   '1.6',
#   '1.6',
#   '1.7',
#   '1.7',
#   '1.8']}

# %% [markdown]
# Our task now is to placed the dictionaries associated with China's data  and the USA's data inside two different instances of the scatter object.
#
# Before doing so, we must first import `Scatter` from `plotly.graph_objs`:

# %%
# (*) Import Scatter 
from plotly.graph_objs import Scatter

help(Scatter)   # how about some documentation!
# Out:
# Help on class Scatter in module plotly.graph_objs.graph_objs:
#
# class Scatter(PlotlyTrace)
#  |  A dictionary-like object for representing a scatter plot in plotly.
#  |
#  |      Example:
#  |
#  |          py.plot([Scatter(name='tacters', x=[1,4,2,3], y=[1,6,2,1])])
#  |
#  |
#  |  Quick method reference:
#  |
#  |      Scatter.update(changes)
#  |      Scatter.strip_style()
#  |      Scatter.get_data()
#  |      Scatter.to_graph_objs()
#  |      Scatter.validate()
#  |      Scatter.to_string()
#  |      Scatter.force_clean()
#  |
#  |  Valid keys:
#  |
#  |      x [required=True] (value=array-like of numbers, strings, datetimes):
#  |          The x coordinates from the (x,y) pair on the scatter plot.
#  |
#  |      y [required=True] (value=array-like of numbers, strings, datetimes):
#  |          The y coordinates from the (x,y) pair on the scatter plot.
#  |
#  |      text [required=False] (value=array-like of strings):
# ...

# %% [markdown]
# Pay special attention to the `'mode'` key accepts as values `'lines'`, `'markers'`, `'text'` and any combination of these three, determining how the coordinates are displayed.
#
# * With `'markers'`, coordinates are display as free (or scatter, unlinked) points,
# * With `'lines'`, coordinates are linked with lines (the default behavior),
# * With `'text`', text linked to the `'text'` in `Scatter` is display on top of the coordinates (more in [subsection 1.4](#1.4-Others-types-of-scatter-plots)).
#
# Then, for instance, the combination `'lines+markers'` (or `'markers+lines'`, order is unimportant) corresponds to points at the coordinates together with lines in-between them.
#
# For our first plot, we select `'mode':'lines+markers'` for China's data and `'mode':'markers'` for the USA's data.
#
# So, the `Scatter` instance for China's data is:

# %%
# Make istance of Scatter object with ....
my_scatter_china = Scatter(Quartz7_data['data'][0], # send 
                           mode='markers+lines')    # show marker pts and lines between

print my_scatter_china.to_string()
# Out:
# Scatter(
#     x=['2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '200...],
#     y=['1.1', '1.5', '2.1', '2.8', '3.4', '4.1', '5.0', '5.6', '6.1', '6.3'...],
#     name='China',
#     mode='markers+lines'
# )

# %% [markdown]
# Correspondingly, the `Scatter` instance for USA's data is:

# %%
#
my_scatter_usa = Scatter(Quartz7_data['data'][1], #
                         mode='markers')          # show marker pts and lines between

print my_scatter_usa.to_string()
# Out:
# Scatter(
#     x=['2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '200...],
#     y=['1.3', '1.2', '1.3', '1.4', '1.5', '1.5', '1.5', '1.6', '1.6', '1.7'...],
#     name='U.S.',
#     mode='markers'
# )

# %% [markdown]
# Next, package ...

# %%
my_data = Data([my_scatter_china, my_scatter_usa])

# %% [markdown]
# Add our own title using the layout object:

# %%
my_layout = Layout(title='Fig 1: Number of university graduates [in millions]')

# %%
my_fig = Figure(data= my_data, layout= my_layout)

# %% [markdown]
# Using the `iplot()` (as opposed to `plot()`, more info in <a href="" target="_blank">section 0</a> that ...

# %%
py.iplot(my_fig, filename='s1_grad-china-usa')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~etpinard/299" height="525" width="100%"></iframe>

# %% [markdown]
# Talk about save files!!!
#
#
#  filename (string) -- the name that will be associated with this figure
#     fileopt ('new' | 'overwrite' | 'extend' | 'append') -- 'new' creates a
#         'new': create a new, unique url for this plot
#         'overwrite': overwrite the file associated with `filename` with this
#         'extend': add additional numbers (data) to existing traces
#         'append': add additional traces to existing data lists
#     world_readable (default=True) -- make this figure private/public

# %% [markdown]
# Converting a bar chart ... into ...
#
# Plotly ...
#
#
# * make comment about "any other plot type in 'data' ..."
#
# Plotly makes it easy and intuitive to *mix plot types* ...

# %% [markdown]
# Talk filenames, overwrite option ... (File setting in current doc)
#
#
#
# These features are great examples of Plotly's muscle
# and can be quite useful say for comparing say two y-coordinates for a given x.

# %% [markdown]
# ##### Import and share your plots ...

# %% [markdown]
# * Something like :
# Since your graph is online
# you can can share it with that unique url, or embed your interactive graph in a web page.
# You can also edit the graph in the plotly web-app
# I edited the graph we just made inside the plotly web-app. It's a bit more minimal and the x-axis is logarithmic. All of the options available to customize your graph in the web-app are exposed through the API. Check out my new version here: https://plot.ly/~ChrisP/21. Here's an embedded version:
#
# gif baby!

# %% [markdown]
# ### 1.2 Style and layout options

# %% [markdown]
# * Use GUI to color lines color and style legend, talk about reproducibility ...
#
# * talk about color models
#
# * Talk about XAxis and YAxis
#
# * get data back, call help on Legend and plot again  ...
#
#
#
# * Go over difference between `get_data()` and `.strip_style()`

# %%
from plotly.graph_objs import XAxis, YAxis

help(XAxis)
# Out:
# Help on class XAxis in module plotly.graph_objs.graph_objs:
#
# class XAxis(PlotlyDict)
#  |  A dictionary-like object representing an xaxis in plotly.
#  |
#  |
#  |  Quick method reference:
#  |
#  |      XAxis.update(changes)
#  |      XAxis.strip_style()
#  |      XAxis.get_data()
#  |      XAxis.to_graph_objs()
#  |      XAxis.validate()
#  |      XAxis.to_string()
#  |      XAxis.force_clean()
#  |
#  |  Valid keys:
#  |
#  |      title [required=False] (value=string):
#  |          The xaxis title.
#  |
#  |      domain [required=False] (value=number array of length 2):
#  |          Sets the domain of this axis. The available space for this axis to
#  |          live in is from 0 to 1.
#  |
#  |          Examples:
#  |              [[0, 1], [0, 0.5]]
#  |
#  |      range [required=False] (value=number array of length 2):
#  |          Defines the start and end point for the axis.
#  |
#  |          Examples:
#  |              [[-13, 20], [0, 1]]
#  |
# ...

# %%
axes_style = dict(autotick=False,
                  ticks='',
                  range=[0,5])

XAxis(axes_style,
      title='stuff')
# Out:
# {'autotick': False, 'range': [0, 5], 'ticks': '', 'title': 'stuff'}

# %%
from plotly.graph_objs import Legend

help(Legend)
# Out:
# Help on class Legend in module plotly.graph_objs.graph_objs:
#
# class Legend(PlotlyDict)
#  |  A dictionary-like object representing the legend options for a figure.
#  |
#  |
#  |  Quick method reference:
#  |
#  |      Legend.update(changes)
#  |      Legend.strip_style()
#  |      Legend.get_data()
#  |      Legend.to_graph_objs()
#  |      Legend.validate()
#  |      Legend.to_string()
#  |      Legend.force_clean()
#  |
#  |  Valid keys:
#  |
#  |      x [required=False] (value=number):
#  |          Sets the 'x' location of the legend.
#  |
#  |      y [required=False] (value=number):
#  |          Sets the 'y' location of the legend.
#  |
#  |      bgcolor [required=False] (value=str describing color):
#  |          Sets the background color for the legend.
#  |
#  |          Examples:
#  |              ["'green'", "'rgb(0, 255, 0)'", "'rgba(0, 255, 0, 0.3)'",
#  |              "'hsl(120,100%,50%)'", "'hsla(120,100%,50%,0.3)'"]
#  |
# ...

# %% [markdown]
# Layout customization is set by assigning a value to the keyword argument `layout` of Plotly's `.plot` or `.iplot` method.
# Notice also that values corresponding the to `'xaxis'`, `'yaxis'` and `'legend'` key are dictionaries; further customization can be made, such as setting the range of the axes for example.
# Legend position is assigned using normalized coordinates with respect to the axis frame.
# For example `{'x': 0, 'y': 1}` places the legend at the top-left corner; `{'x': 0, 'y': 0}` would place the legend at the bottom-left and so on.

# %%
from plotly.graph_objs import Marker, Line

help(Marker)
# Out:
# Help on class Marker in module plotly.graph_objs.graph_objs:
#
# class Marker(PlotlyDict)
#  |  A dictionary-like object representing marker(s) style in plotly.
#  |
#  |
#  |  Quick method reference:
#  |
#  |      Marker.update(changes)
#  |      Marker.strip_style()
#  |      Marker.get_data()
#  |      Marker.to_graph_objs()
#  |      Marker.validate()
#  |      Marker.to_string()
#  |      Marker.force_clean()
#  |
#  |  Valid keys:
#  |
#  |      symbol [required=False] (value='dot' | 'cross' | 'diamond' | 'square' |
#  |      'triangle-down' | 'triangle-left' | 'triangle-right' | 'triangle-up' |
#  |      'x'):
#  |          The symbol that is drawn on the plot for each marker.
#  |
#  |      line [required=False] (value=Line object | Line object | dict):
#  |          A dict-like object describing the line belonging to the marker.
#  |
#  |          For more, run `help(plotly.graph_objs.Line)`
#  |
#  |      size [required=False] (value=number):
# ...

# %% [markdown]
# long string .... rendering !

# %%
help(Line)
# Out:
# Help on class Line in module plotly.graph_objs.graph_objs:
#
# class Line(PlotlyDict)
#  |  A dictionary-like object representing the style of a line in plotly.
#  |
#  |
#  |  Quick method reference:
#  |
#  |      Line.update(changes)
#  |      Line.strip_style()
#  |      Line.get_data()
#  |      Line.to_graph_objs()
#  |      Line.validate()
#  |      Line.to_string()
#  |      Line.force_clean()
#  |
#  |  Valid keys:
#  |
#  |      dash [required=Aw, snap! Undocumented!] (value='dash' | 'dashdot' |
#  |      'dot' | 'solid'):
#  |          The style of the line.
#  |
#  |      color [required=False] (value=str describing color):
#  |          The color of the line.
#  |
#  |      width [required=False] (value=number: x >= 0):
#  |          The width of the line.
#  |
#  |      opacity [required=False] (value=number: x in [0, 1]):
#  |          Sets the opacity, or transparency, of this object. Also known as the
# ...

# %% [markdown]
# ##### Color models in Plotly

# %% [markdown]
# ### 1.3 Scatter plots with errors bars

# %% [markdown]
# * x and y error bars (contant percent, error bar come in other flavours such as ... more section 2)
#
# * Fonts in
#
# * Talk also about `zeroline` and grid lines ...
#
# * talk about numpy arrays
#
# * Annotations ...
#
# Numpy users should note: Plotly accepts 1-dimensional Numpy arrays as list arguments as well. No need to convert them! ...

# %%
from plotly.graph_objs import ErrorY

# %%
from plotly.graph_objs import ErrorX

# %%
tls.embed('andreyDim','168', width=750)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~andreyDim/168/725/500" height="525" width="750"></iframe>

# %% [markdown]
# ##### Fonts in Plotly

# %%
from plotly.graph_objs import Font

help(Font)
# Out:
# Help on class Font in module plotly.graph_objs.graph_objs:
#
# class Font(PlotlyDict)
#  |  A dictionary-like object representing details about font style.
#  |
#  |
#  |  Quick method reference:
#  |
#  |      Font.update(changes)
#  |      Font.strip_style()
#  |      Font.get_data()
#  |      Font.to_graph_objs()
#  |      Font.validate()
#  |      Font.to_string()
#  |      Font.force_clean()
#  |
#  |  Valid keys:
#  |
#  |      family [required=False] (value=Aw, snap! Undocumented!):
#  |          Setting for the font family.
#  |
#  |      size [required=False] (value=number):
#  |          Setting for the font size.
#  |
#  |      color [required=False] (value=str describing color):
#  |          Color of the text.
#  |
#  |          Examples:
#  |              ["'green'", "'rgb(0, 255, 0)'", "'rgba(0, 255, 0, 0.3)'",
#  |              "'hsl(120,100%,50%)'", "'hsla(120,100%,50%,0.3)'"]
#  |
#  |      outlinecolor [required=False] (value=str describing color):
# ...

# %% [markdown]
# <div style="float:right; \">
#     <img src="http://i.imgur.com/T6asK3R.png",
#  align=right style="float:right; margin-left:20px; margin-right:200px; margin-top:10px" />
# </div>
#
# <ul>
#     <li style="font-family:Courier New, monospace;">
#     Arial, sans-serif,
#     </li>
#     <li style="margin-top:0ex; margin-bottom:0.5ex;">
#     Arial, sans-serif,
#     </li>
#         <li style="margin-top:0ex; margin-bottom:0.5ex;">
#     Arial, sans-serif,
#     </li>
#         <li style="margin-top:0ex; margin-bottom:0.5ex;">
#     Arial, sans-serif,
#     </li>
#         <li style="margin-top:0ex; margin-bottom:0.5ex;">
#     Arial, sans-serif,
#     </li>
#         <li style="margin-top:0ex; margin-bottom:0.5ex;">
#     Arial, sans-serif,
#     </li>
#         <li style="margin-top:0ex; margin-bottom:0.5ex;">
#     Arial, sans-serif,
#     </li>
#         <li style="margin-top:0ex; margin-bottom:0.5ex;">
#     Arial, sans-serif,
#     </li>
#
#
# </ul>
#
# -
# -  *missing one* see GUI
# -  Courier New, monospace
# -  Droid Sans, sans-serif
# -  Droid Serif, serif
# -  Droid Sans Mono, sans-serif
# -  Georgia, serif
# -  Gravitas One, cursive
# -  Impact, Charcoal, sans-serif
# -  Lucida Console, Monaco, monospace
# -  Old Standard TT, serif
# -  Open Sans, sans-serif
# -  PT Sans Narrow, sans-serif
# -  Raleway, sans-serif
# -  Times New Roman, Times, serif
# -  Verdana, sans-serif

# %% [markdown]
# ### 1.4 Other types of scatter plots

# %% [markdown]
# * use  Datetime as coordinates
#
# * Area plot,  Text plots, others
#
#
# * Append and extend data! (with Datetime)
#
# In addition, if the x-coordinate and y-coordinate list do not have the same length,
# the longer list is sliced down from its last entry to match the shorter list's length. **still true**

# %%
tls.embed('Dreamshot','221', width=700) # extend to year of zero !
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~Dreamshot/221/675/500" height="525" width="700"></iframe>

# %%
tls.embed('greentechmedia','53')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~greentechmedia/53" height="525" width="100%"></iframe>

# %% [markdown]
# ### 1.5 Subplots, multiples axes and insets

# %% [markdown]
# * (1) Simple Subplot -- more complex in section 2 and 4, (2) Multiple axes and (3) Insert with more or less same data!

# %%
tls.embed('andreyDim','216')  # maybe not, this might from MATLAB
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~andreyDim/216" height="525" width="100%"></iframe>

# %%
from plotly.graph_objs import Scatter, Font

my_data = Data([Scatter(x=[0,1,2],
                        y=[1,1,1],
                        name="Lines, Markers and Text",
                        text=["Text A", "Text B", "Text C"],
                        mode="markers+text",
                        textposition=["top",'bottom','top left'],
                        textfont= Font(color="#1f77b4",
                                       family="sans serif",
                                       size=18)
                    )])

my_fig = Figure(data= my_data)
py.iplot(my_fig, filename='s1_text-chart-test')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~etpinard/194" height="525" width="100%"></iframe>

# %%
tls.embed('jackp','1427',height=740)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~jackp/1427" height="740" width="100%"></iframe>

# %% [markdown]
# "PT Sans Narrow", sans-serif",

# %% [markdown]
# *Let's make sense of the above code.* of the created dictionary ...
#
# In the `trace0` dictionary:
#
# * key `'x'` has for value the `my_x0` list (defined previously) ;
# * key `'y'` has for value the `my_y1` list (also defined previously) ;
# * key `'type'` has for value the `'scatter'` string ;
# * key `'mode'` has for value the `'markers'` string.
#
#
#
# Similarly, in the `trace1` dictionary:
#
# * keys `'x'` and `'y'` have for value the `my_x1` and `my_y1` numpy array respectively ;
# * key `'type`' has for value the `'scatter'` string, as in `trace0` ;
# * key `'mode'` has for value the `'lines'` (the default mode).
#
# So, `my_x0` and `my_y0`, the lists of our first plot, are now linked to keys in the `trace0` dictionary along with the plot type and mode.
# Python dictionaries are unordered collections of references: Plotly users need not to worry about key-value ordering. That said, please note that all dictionaries keys are case-sensitive.
# Lastly, we called the `.iplot` method by sending a list of dictionaries where `trace0` is plotted before `trace1`.
#
# Plotly plots are fully interactive:
# Users can check the x and y coordinates of every point by hovering the cursor.
# By clicking and dragging the cursor over a region, Plotly zooms in on the plot and resizes lines, points and axes (not just a static zoom, try it!).
# A double click on the plot zooms back out to the original version.
# Finally, hold the `shift` key while clicking and dragging to pan.

# %% [markdown]
# #### 1.2

# %% [markdown]
# #### 1.3

# %% [markdown]
# Let's continue customizing our plot by adding a few more features:
#
# * Set traces styles, colors and sizes
# * Add title and axis labels
# * Move the legend and make its labels more descriptive
#
#
# Add stuff about plot options here ...

# %% [markdown]
# *Not bad.*
#
# First, notice that the values corresponding to the `'line'` and `'marker'` keys (singular, unlike the `'mode'` values) in the trace dictionaries are dictionaries themselves.
# Plotly makes it easy and intuitive to group plot options by category.
#
# In the above, we assigned trace colours by name (`'name'` in `trace0`) and with the RGB colour model (`'rgb(27,158,119)'` in `trace1`, note a string).
#
# <!-- All of Plotly's built-in colour names are listed [here](to do!). -->
#
# Moreover, Plotly understands the RGBA and hexagonal colour models (more examples in later sections).
# Later in section 3 on <a href="http://nbviewer.ipython.org/github/plotly/python-user-guide/blob/master/s3_bubble-charts/s3_bubble-charts.ipynb">Bubble Charts</a>, we will see that the each of `'color`', `'symbol'` and `'size`' keys can be links to lists of values. This feature is quite useful for making vibrant Plotly Bubble Charts.
#
#
# In addition to the `'lines'` and `'markes'` modes, Plotly has a `'lines+markers'` mode which plots markers at each data points and lines in-between them. Customization is made through the `'marker'` and `'line'` separatly.

# %% [markdown]
# Plotly has many more trace and layout options available, which are all defined by reseting and/or appending key-value pairs in each trace dictionary.
# We will explore several of Plotly's line options in detail throughout the examples given this document.
# To sum up, the figures you make in Plotly are nothing more than an organized, nested dictionary.
#
# <!-- That said we invite users of the **new version** to get familiar with the `help()` -->

# %% [markdown]
# <hr>
#
# <h4 style="font-size:14pt;">Go to
#
# [Section 2 --- Bar Charts](http://nbviewer.ipython.org/github/plotly/python-user-guide/blob/master/s2_bar-charts/s2_bar-charts.ipynb) </h4>
#
# <h4 style="font-size:14pt;">Go to
#
# [Section 0 --- Getting Started with Plotly](http://nbviewer.ipython.org/github/plotly/python-user-guide/blob/master/s0_getting-started/s0_getting-started.ipynb)  </h4>
#
# <h4 style="font-size:14pt;">Go to
#
# [top of page](#Plotly's-Python-API-User-Guide) </h4>
#
# <h4 style="font-size:14pt;">Go to User Guide's
#
# [homepage](http://nbviewer.ipython.org/github/plotly/python-user-guide/blob/master/s00_homepage/s00_homepage.ipynb) </h4>
#
# <hr>

# %% [markdown]
# <div style="float:right; \">
#     <img src="http://i.imgur.com/4vwuxdJ.png"
#  align=right style="float:right; margin-left: 5px; margin-top: -10px" />
# </div>
#
# <h4>Got Questions or Feedback? </h4>
#
# About <a href="https://plot.ly" target="_blank">Plotly</a>
#
# * email: feedback@plot.ly
# * tweet:
# <a href="https://twitter.com/plotlygraphs" target="_blank">@plotlygraphs</a>
#
# About the <a href="https://github.com/plotly/python-user-guide" target="_blank">User Guide</a>
#
# * email: etienne@plot.ly
# * tweet: <a href="https://twitter.com/etpinard" target="_blank">@etpinard</a>
#
# <h4 style="margin-top:30px;">Notebook styling ideas</h4>
#
# Big thanks to
#
# * <a href="http://nbviewer.ipython.org/github/CamDavidsonPilon/Probabilistic-Programming-and-Bayesian-Methods-for-Hackers/blob/master/Prologue/Prologue.ipynb" target="_blank">Cam Davidson-Pilon</a>
# * <a href="http://lorenabarba.com/blog/announcing-aeropython/#.U1ULXdX1LJ4.google_plusone_share" target="_blank">Lorena A. Barba</a>
#
# <br>

# %%
# CSS styling within IPython notebook
from IPython.display import display, HTML
display(HTML(open('../custom.css').read()))
# Out:
# <style>
#     /*body {
#         background-color: #F5F5F5;
#     }*/
#     div.cell{
#         width: 850px;
#         margin-left: 10% !important;
#         margin-right: auto;
#     }
#     h1 {
#         font-family: "Open sans",verdana,arial,sans-serif;
#     }
#     .text_cell_render h1 {
#         font-weight: 200;
#         font-size: 40pt;
#         line-height: 100%;
#         color:#447adb;
#         margin-bottom: 0em;
#         margin-top: 0em;
#         display: block;
#         white-space: nowrap;
#     }
#     h2 {
#         font-family: "Open sans",verdana,arial,sans-serif;
#         text-indent:1em;
#     }
#     .text_cell_render h2 {
#         font-weight: 200;
#         font-size: 20pt;
#         font-style: italic;
#         line-height: 100%;
#         color:#447adb;
#         margin-bottom: 1.5em;
#         margin-top: 0.5em;
#         display: block;
#         white-space: nowrap;
#     }
#     h3 {
# ...
