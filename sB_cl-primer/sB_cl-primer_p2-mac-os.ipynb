# %% [markdown]
# # Plotly's Python API User Guide

# %% [markdown]
# ## Appendix B.2: Mac OS terminal and pip Primer

# %% [markdown]
# Welcome to Plotly's Python API User Guide.
#
# > Links to the other sections are on the User Guide's [homepage](http://nbviewer.ipython.org/github/plotly/python-user-guide/blob/master/s00_homepage/s00_homepage.ipynb#Table-of-Contents:) <br>
# The Github repository is available
# <a href="https://github.com/plotly/python-user-guide" target="_blank">here</a>

# %% [markdown]
# Appendix B is divided, into separate notebooks, as follows:
#
# * [B.0 Introduction to terminal/command prompt and pip](http://nbviewer.ipython.org/github/plotly/python-user-guide/blob/master/sB_cl-primer/sB_cl-primer.ipynb)
#
# * [B.1 Linux terminal and pip Primer](http://nbviewer.ipython.org/github/plotly/python-user-guide/blob/master/sB_cl-primer/sB_cl-primer_p1-linux.ipynb)
#
# * [B.2 Mac OS terminal and pip Primer](http://nbviewer.ipython.org/github/plotly/python-user-guide/blob/master/sB_cl-primer/sB_cl-primer_p2-mac-os.ipynb)
#
# * [B.3 Windows command prompt and pip Primer](http://nbviewer.ipython.org/github/plotly/python-user-guide/blob/master/sB_cl-primer/sB_cl-primer_p3-windows.ipynb)
#
# <hr>

# %% [markdown]
# ### Step 1

# %% [markdown]
# Instructions will be the same as for Linux (they should be at least) ...
#
# Get someone to make a video ...

# %% [markdown]
# ### Step 2

# %% [markdown]
# ....

# %% [markdown]
# In B.1, B.2 and B.3:
#
# * How to access the Terminal/Command Prompt
#
# * How to install Python (... Anaconda on Windows and Mac, maybe just mention it)
#
# * How to install pip
#
# * How to install IPython (http://ipython.org/install.html)
#
# * How to install other packages using pip ... (or sudo apt-get install ...)
#
#
# * Video
#
#     - How to install plotly with pip
#
#     - How to sign up for plotly
#
#     - How to get API key after signing in
#
#     - Open Python or IPython, sign in and make first plot
#
# * Setting credentials file, retrieving credentials ...
#
# Be brief, only include relevant info! Show only one way of doing things, links to other ways if there are any ...
#
# Let's have all steps to get going with Plotly in one place!!! Ref. with hyperlinks but duplicate content for a continuous read.

# %% [markdown]
# <hr>
#
# Sub-appendices of appendix B:
#
# * [B.0 Introduction to terminal/command prompt and pip](http://nbviewer.ipython.org/github/plotly/python-user-guide/blob/master/sB_cl-primer/sB_cl-primer.ipynb)
#
# * [B.1 Linux terminal and pip Primer](http://nbviewer.ipython.org/github/plotly/python-user-guide/blob/master/sB_cl-primer/sB_cl-primer_p1-linux.ipynb)
#
# * [B.2 Mac OS terminal and pip Primer](http://nbviewer.ipython.org/github/plotly/python-user-guide/blob/master/sB_cl-primer/sB_cl-primer_p2-mac-os.ipynb)
#
# * [B.3 Windows command prompt and pip Primer](http://nbviewer.ipython.org/github/plotly/python-user-guide/blob/master/sB_cl-primer/sB_cl-primer_p3-windows.ipynb)
#
#
# <h4 style="font-size:14pt; margin-top:1.5em">Go to
#
# [top of page](http://nbviewer.ipython.org/github/plotly/python-user-guide/blob/master/sA_python-basics/sA_python-basics.ipynb#) </h4>
#
# <h4 style="font-size:14pt;">Go to User Guide's
#
# [homepage](http://nbviewer.ipython.org/github/plotly/python-user-guide/blob/master/s00_homepage/s00_homepage.ipynb) </h4>
#
# <hr>

# %% [markdown]
# <div style="float:right; \">
#     <img src="http://i.imgur.com/4vwuxdJ.png"
#  align=right style="float:right; margin-left: 5px; margin-top: -10px" />
# </div>
#
# <h4>Got Questions or Feedback? </h4>
#
# About <a href="https://plot.ly" target="_blank">Plotly</a>
#
# * email: feedback@plot.ly
# * tweet:
# <a href="https://twitter.com/plotlygraphs" target="_blank">@plotlygraphs</a>
#
# About the <a href="https://github.com/plotly/python-user-guide" target="_blank">User Guide</a>
#
# * email: etienne@plot.ly
# * tweet: <a href="https://twitter.com/etpinard" target="_blank">@etpinard</a>
#
# <h4 style="margin-top:30px;">Notebook styling ideas</h4>
#
# Big thanks to
#
# * <a href="http://nbviewer.ipython.org/github/CamDavidsonPilon/Probabilistic-Programming-and-Bayesian-Methods-for-Hackers/blob/master/Prologue/Prologue.ipynb" target="_blank">Cam Davidson-Pilon</a>
# * <a href="http://lorenabarba.com/blog/announcing-aeropython/#.U1ULXdX1LJ4.google_plusone_share" target="_blank">Lorena A. Barba</a>
#
# <br>

# %%
# CSS styling within IPython notebook
from IPython.core.display import HTML
def css_styling():
    styles = open("../custom.css", "r").read()
    return HTML(styles)
css_styling()
# Out:
# <style>
#     /*body {
#         background-color: #F5F5F5;
#     }*/
#     div.cell{
#         width: 850px;
#         margin-left: 10% !important;
#         margin-right: auto;
#     }
#     h1 {
#         font-family: "Open sans",verdana,arial,sans-serif;
#     }
#     .text_cell_render h1 {
#         font-weight: 200;
#         font-size: 40pt;
#         line-height: 100%;
#         color:#447adb;
#         margin-bottom: 0em;
#         margin-top: 0em;
#         display: block;
#         white-space: nowrap;
#     }
#     h2 {
#         font-family: "Open sans",verdana,arial,sans-serif;
#         text-indent:1em;
#     }
#     .text_cell_render h2 {
#         font-weight: 200;
#         font-size: 20pt;
#         font-style: italic;
#         line-height: 100%;
#         color:#447adb;
#         margin-bottom: 1.5em;
#         margin-top: 0.5em;
#         display: block;
#         white-space: nowrap;
#     }
#     h3 {
# ...
